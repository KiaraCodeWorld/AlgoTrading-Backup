# %%
"""
Sell Bot v2 — Smart Position Manager
═════════════════════════════════════
Monitors open positions via IBKR + MongoDB.

EXIT STRATEGY (designed for momentum breakout plays):
─────────────────────────────────────────────────────
Phase 1 — PROTECTION (from entry until profitable):
  • Hard stop: -10% from entry (expanded from 3% to let breakouts breathe)
  • Flash crash: -5% drop in a single 30-second interval → emergency exit

Phase 2 — PARTIAL PROFIT at +50%:
  • Sell 50% of position, lock in gains
  • Remaining 50% enters "runner" mode with trailing stop

Phase 3 — RUNNER (remaining shares after partial):
  • Trailing stop tightens in tiers based on how far price has run:
      +50% to +75%  →  trail 15% from high  (give it room to consolidate)
      +75% to +100% →  trail 12% from high
      +100% to +150% → trail 10% from high
      +150%+         → trail  8% from high  (tightest — protect big win)
  • PSAR flip bearish → soft exit (only triggers if also below EMA 9)
  • EMA 9 crosses below EMA 21 → exit runner (trend is done)

Phase 4 — TIME DECAY (if stock goes nowhere):
  • If position is between -5% and +10% after 2 hours → exit
    (momentum play didn't work, free up capital)

EMERGENCY EXITS (always active, any phase):
  • Flash crash detection (configurable threshold)
  • Liquidity crisis (spread > 0.5%)
  • These use aggressive limit → market order fallback
"""

import logging
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import random
from typing import Optional
from dataclasses import dataclass

from pymongo import MongoClient
from ib_insync import *

import warnings
warnings.filterwarnings("ignore")


# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ─── IBKR ─────────────────────────────────────────────────────────────────────
IBKR_HOST      = "127.0.0.1"
IBKR_PORT      = 7497
IBKR_CLIENT_ID = random.randint(1, 1000)

# ─── Exit Thresholds ──────────────────────────────────────────────────────────
HARD_STOP_PCT          = 0.10    # 10% max loss from entry (expanded from 3%)
FLASH_CRASH_PCT        = 0.05    # 5% drop in one interval → emergency
LIQUIDITY_SPREAD_PCT   = 0.005   # 0.5% spread → liquidity crisis

# ─── Partial Profit ───────────────────────────────────────────────────────────
PARTIAL_PROFIT_PCT     = 0.50    # Take partial at +50%
PARTIAL_SELL_FRACTION  = 0.50    # Sell 50% of position

# ─── Tiered Trailing Stops (for runner after partial) ─────────────────────────
# Each tuple: (profit_threshold, trail_pct_from_high)
# Evaluated top-down — first match wins
TRAILING_TIERS = [
    (1.50, 0.08),   # +150%+ profit → trail 8% from high
    (1.00, 0.10),   # +100%+ profit → trail 10%
    (0.75, 0.12),   # +75%+  profit → trail 12%
    (0.50, 0.15),   # +50%+  profit → trail 15%
]
DEFAULT_TRAILING_PCT   = 0.20    # Before +50%, if somehow needed: 20%

# ─── Time Decay ───────────────────────────────────────────────────────────────
STALE_TRADE_HOURS      = 2      # Exit if position stagnates after this long
STALE_TRADE_MIN_PNL    = -0.05  # … and P&L is between this …
STALE_TRADE_MAX_PNL    = 0.10   # … and this (going nowhere)

# ─── Technical Exit Signals ───────────────────────────────────────────────────
# PSAR + EMA crossover used as confirmation for runner exits
EMA_FAST_PERIOD        = 9
EMA_SLOW_PERIOD        = 21

# ─── Monitoring ───────────────────────────────────────────────────────────────
MONITOR_INTERVAL       = 30     # seconds between checks
EMERGENCY_TIMEOUT      = 5      # seconds to wait for limit fill before market

# ─── MongoDB ──────────────────────────────────────────────────────────────────
mongo_client     = MongoClient("mongodb://localhost:27017/")
db               = mongo_client["breakout_db"]
trades_collection = db["trades_v2"]


# ══════════════════════════════════════════════════════════════════════════════
# LOGGING
# ══════════════════════════════════════════════════════════════════════════════

class _Utf8SafeStreamHandler(logging.StreamHandler):
    def emit(self, record):
        try:
            super().emit(record)
        except UnicodeEncodeError:
            record.msg = str(record.msg).encode("ascii", errors="replace").decode("ascii")
            record.args = ()
            try:
                super().emit(record)
            except Exception:
                self.handleError(record)

    def _try_utf8(self):
        try:
            if hasattr(self.stream, "reconfigure"):
                self.stream.reconfigure(encoding="utf-8", errors="replace")
        except Exception:
            pass


def _make_logger() -> logging.Logger:
    fmt = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
    sh  = _Utf8SafeStreamHandler(sys.stdout)
    sh._try_utf8()
    sh.setFormatter(fmt)
    fh  = logging.FileHandler("sell_bot.log", encoding="utf-8")
    fh.setFormatter(fmt)
    logger = logging.getLogger("sell_bot")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    logger.addHandler(sh)
    logger.addHandler(fh)
    logger.propagate = False
    return logger

log = _make_logger()


# ══════════════════════════════════════════════════════════════════════════════
# IBKR CLIENT
# ══════════════════════════════════════════════════════════════════════════════

class IBKRSellClient:
    def __init__(self):
        util.startLoop()
        self.ib = IB()

    def connect(self):
        self.ib.connect(IBKR_HOST, IBKR_PORT, clientId=IBKR_CLIENT_ID)
        log.info(f"IBKR connected | accounts: {self.ib.wrapper.accounts}")

    def disconnect(self):
        self.ib.disconnect()

    # ── Price helpers ─────────────────────────────────────────────────────────

    def get_last_price(self, symbol: str) -> Optional[float]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "106", False, False)
        self.ib.sleep(3)
        self.ib.cancelMktData(contract)

        for label, val in [("last", ticker.last), ("ask", ticker.ask),
                           ("bid", ticker.bid), ("close", ticker.close)]:
            if val and float(val) > 0:
                log.debug(f"{symbol}: price source='{label}' ${float(val):.4f}")
                return float(val)

        log.warning(f"{symbol}: no price available")
        return None

    def get_ticker(self, symbol: str) -> Ticker:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "", False, False)
        self.ib.sleep(2)
        return ticker

    # ── Historical bars ───────────────────────────────────────────────────────

    def get_bars(self, symbol: str, n: int = 70) -> Optional[pd.DataFrame]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)

        for what_to_show in ("TRADES", "MIDPOINT"):
            raw = self.ib.reqHistoricalData(
                contract,
                endDateTime="",
                durationStr="10 D",
                barSizeSetting="5 mins",
                whatToShow=what_to_show,
                useRTH=False,
                keepUpToDate=False,
            )
            if raw:
                df = pd.DataFrame([
                    {"open": b.open, "high": b.high, "low": b.low,
                     "close": b.close, "volume": getattr(b, "volume", 0)}
                    for b in raw
                ])
                return df.tail(n).reset_index(drop=True)

        log.warning(f"{symbol}: no bars returned")
        return None

    # ── Technical indicators ──────────────────────────────────────────────────

    def compute_exit_signals(self, symbol: str) -> dict:
        """
        Compute PSAR, EMA 9, EMA 21 for exit decisions.
        Returns dict with signal flags or empty dict on failure.
        """
        df = self.get_bars(symbol, n=70)
        if df is None or len(df) < 25:
            log.warning(f"{symbol}: not enough bars for exit signals")
            return {}

        # Parabolic SAR
        psar_vals = self._compute_psar(df["high"].values, df["low"].values,
                                       df["close"].values)

        # EMA 9 / 21
        ema_fast = df["close"].ewm(span=EMA_FAST_PERIOD, adjust=False).mean()
        ema_slow = df["close"].ewm(span=EMA_SLOW_PERIOD, adjust=False).mean()

        price     = float(df["close"].iloc[-1])
        psar_now  = float(psar_vals[-1])
        ema9_now  = float(ema_fast.iloc[-1])
        ema21_now = float(ema_slow.iloc[-1])

        # Previous bar for crossover detection
        ema9_prev  = float(ema_fast.iloc[-2])
        ema21_prev = float(ema_slow.iloc[-2])

        psar_bearish       = psar_now > price       # SAR above price = downtrend
        ema_death_cross    = (ema9_prev >= ema21_prev) and (ema9_now < ema21_now)
        ema_bearish        = ema9_now < ema21_now    # EMA 9 below 21
        price_below_ema9   = price < ema9_now

        signals = {
            "price":             price,
            "psar":              psar_now,
            "ema_9":             ema9_now,
            "ema_21":            ema21_now,
            "psar_bearish":      psar_bearish,
            "ema_death_cross":   ema_death_cross,
            "ema_bearish":       ema_bearish,
            "price_below_ema9":  price_below_ema9,
        }

        log.info(
            f"{symbol} signals: PSAR={psar_now:.4f}({'BEAR' if psar_bearish else 'BULL'}) "
            f"EMA9={ema9_now:.4f} EMA21={ema21_now:.4f} "
            f"cross={'YES' if ema_death_cross else 'no'} "
            f"below9={'YES' if price_below_ema9 else 'no'}"
        )
        return signals

    @staticmethod
    def _compute_psar(highs, lows, closes, iaf=0.02, max_af=0.2) -> np.ndarray:
        n    = len(closes)
        psar = closes.copy().astype(float)
        bull = True
        af   = iaf
        hp   = float(highs[0])
        lp   = float(lows[0])

        for i in range(2, n):
            if bull:
                psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
                psar[i] = min(psar[i], lows[i - 1], lows[i - 2])
                if lows[i] < psar[i]:
                    bull    = False
                    psar[i] = hp
                    lp      = lows[i]
                    af      = iaf
                else:
                    if highs[i] > hp:
                        hp = highs[i]
                        af = min(af + iaf, max_af)
            else:
                psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
                psar[i] = max(psar[i], highs[i - 1], highs[i - 2])
                if highs[i] > psar[i]:
                    bull    = True
                    psar[i] = lp
                    hp      = highs[i]
                    af      = iaf
                else:
                    if lows[i] < lp:
                        lp = lows[i]
                        af = min(af + iaf, max_af)
        return psar

    # ── Order execution ───────────────────────────────────────────────────────

    def get_avg_fill_price_from_broker(self, symbol: str, order_id: int) -> Optional[float]:
        for trade in self.ib.trades():
            if (trade.contract.symbol == symbol
                    and trade.order.orderId == order_id
                    and trade.orderStatus.avgFillPrice > 0):
                return float(trade.orderStatus.avgFillPrice)

        fills   = self.ib.fills()
        matched = [f for f in fills
                   if f.contract.symbol == symbol and f.execution.orderId == order_id]
        if matched:
            total_qty  = sum(f.execution.shares for f in matched)
            total_cost = sum(f.execution.shares * f.execution.price for f in matched)
            return total_cost / total_qty

        return None

    def place_limit_sell(self, symbol: str, price: float, qty: int,
                         emergency: bool = False) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)

        if emergency:
            price = price * 0.99  # 1% below for faster fill

        order = LimitOrder("SELL", qty, round(price, 2))
        order.outsideRth = True
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)

        log.info(f"SELL LIMIT {symbol} x{qty} @ ${price:.2f} "
                 f"orderId={trade.order.orderId} emergency={emergency}")
        return trade

    def place_market_sell(self, symbol: str, qty: int) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        order = MarketOrder("SELL", qty)
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL MARKET {symbol} x{qty} orderId={trade.order.orderId}")
        return trade

    def get_sell_fill_price(self, symbol: str, sell_order_id: int,
                            fallback_price: float) -> float:
        self.ib.sleep(3)
        avg = self.get_avg_fill_price_from_broker(symbol, sell_order_id)
        if avg:
            return avg
        log.warning(f"{symbol}: sell fill not confirmed, using fallback ${fallback_price:.4f}")
        return fallback_price


# ══════════════════════════════════════════════════════════════════════════════
# MONGODB HELPERS
# ══════════════════════════════════════════════════════════════════════════════

def get_open_trades() -> list:
    return list(trades_collection.find({"status": "open"}))


def get_effective_entry_price(trade: dict, ibkr: IBKRSellClient) -> float:
    """Priority: avg_fill_price (DB) → broker lookup → entry_price (DB)."""
    if trade.get("avg_fill_price"):
        return float(trade["avg_fill_price"])

    order_id = trade.get("order_id")
    symbol   = trade.get("instrument") or trade.get("symbol")

    if order_id:
        broker_avg = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if broker_avg:
            trades_collection.update_one(
                {"_id": trade["_id"]},
                {"$set": {"avg_fill_price": broker_avg, "entry_price": broker_avg}},
            )
            return broker_avg

    return float(trade["entry_price"])


def update_trade_field(trade_id, updates: dict):
    updates["updated_at"] = datetime.now(timezone.utc)
    trades_collection.update_one({"_id": trade_id}, {"$set": updates})


def close_trade(trade: dict, exit_price: float, reason: str, qty_sold: int = None):
    """Close (or partially close) a trade in MongoDB."""
    symbol      = trade.get("instrument") or trade.get("symbol")
    entry_price = float(trade.get("avg_fill_price") or trade["entry_price"])
    total_qty   = trade.get("quantity") or trade.get("qty")
    pnl_pct     = (exit_price - entry_price) / entry_price

    if qty_sold is None:
        qty_sold = total_qty

    realized_pnl = (exit_price - entry_price) * qty_sold

    if qty_sold >= total_qty:
        # Full close
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "status":           "closed",
                "exit_price":       exit_price,
                "exit_timestamp":   datetime.now(timezone.utc),
                "reason":           reason,
                "pnl_pct":          round(pnl_pct * 100, 2),
                "realized_pnl":     realized_pnl,
                "updated_at":       datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"CLOSED {symbol} | entry=${entry_price:.4f} exit=${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | reason={reason}"
        )
    else:
        # Partial close — reduce quantity, record partial exit
        remaining = total_qty - qty_sold
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "quantity":              remaining,
                "partial_exit_price":    exit_price,
                "partial_exit_qty":      qty_sold,
                "partial_exit_time":     datetime.now(timezone.utc),
                "partial_exit_reason":   reason,
                "partial_realized_pnl":  realized_pnl,
                "phase":                 "runner",
                "updated_at":            datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"PARTIAL CLOSE {symbol} | sold {qty_sold}/{total_qty} @ ${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | "
            f"remaining={remaining} shares → runner mode"
        )


# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def get_trailing_stop_pct(pnl_pct: float) -> float:
    """
    Return the trailing stop percentage based on how far price has run.
    Tighter trail as profit grows (protect bigger wins).
    """
    for threshold, trail in TRAILING_TIERS:
        if pnl_pct >= threshold:
            return trail
    return DEFAULT_TRAILING_PCT


def compute_trailing_stop(entry_price: float, highest_price: float,
                          current_pnl_pct: float) -> float:
    """Compute the effective trailing stop price."""
    trail_pct  = get_trailing_stop_pct(current_pnl_pct)
    trail_stop = highest_price * (1 - trail_pct)
    hard_stop  = entry_price * (1 - HARD_STOP_PCT)
    return max(trail_stop, hard_stop)


def check_flash_crash(symbol: str, current_price: float, trade: dict) -> Optional[str]:
    """Detect sudden price drops within a single monitoring interval."""
    last_price = trade.get("last_price")

    # Always update for next iteration
    update_trade_field(trade["_id"], {
        "last_price":      current_price,
        "last_price_time": datetime.now(timezone.utc),
    })

    if last_price and last_price > 0:
        drop_pct = (current_price - last_price) / last_price
        if drop_pct <= -FLASH_CRASH_PCT:
            log.warning(f"{symbol}: FLASH CRASH {drop_pct * 100:.2f}% in {MONITOR_INTERVAL}s")
            return f"flash_crash_{abs(drop_pct) * 100:.1f}pct"

    return None


def check_liquidity_crisis(ibkr: IBKRSellClient, symbol: str) -> bool:
    """Detect bid-ask spread blowing out."""
    try:
        ticker = ibkr.get_ticker(symbol)
        if ticker.bid and ticker.ask and ticker.bid > 0:
            mid        = (ticker.ask + ticker.bid) / 2
            spread_pct = (ticker.ask - ticker.bid) / mid
            if spread_pct > LIQUIDITY_SPREAD_PCT:
                log.warning(f"{symbol}: liquidity crisis — spread {spread_pct * 100:.2f}%")
                return True
    except Exception as e:
        log.error(f"{symbol}: liquidity check error — {e}")
    return False


def check_stale_trade(trade: dict, pnl_pct: float) -> bool:
    """
    If position has been open > STALE_TRADE_HOURS and P&L is flat,
    it's a dead momentum play — exit to free capital.
    """
    entry_time = trade.get("entry_timestamp")
    if not entry_time:
        return False

    # Handle both timezone-aware and naive datetimes
    if entry_time.tzinfo is None:
        hours_held = (datetime.now() - entry_time).total_seconds() / 3600
    else:
        hours_held = (datetime.now(timezone.utc) - entry_time).total_seconds() / 3600

    if hours_held >= STALE_TRADE_HOURS:
        if STALE_TRADE_MIN_PNL <= pnl_pct <= STALE_TRADE_MAX_PNL:
            log.info(
                f"{trade.get('instrument') or trade.get('symbol')}: "
                f"stale trade — {hours_held:.1f}h held, pnl={pnl_pct * 100:+.2f}% "
                f"(flat zone {STALE_TRADE_MIN_PNL * 100}% to {STALE_TRADE_MAX_PNL * 100}%)"
            )
            return True
    return False


# ══════════════════════════════════════════════════════════════════════════════
# EMERGENCY EXIT
# ══════════════════════════════════════════════════════════════════════════════

def emergency_exit(ibkr: IBKRSellClient, symbol: str, qty: int,
                   reason: str) -> tuple[float, str]:
    """Aggressive limit → market fallback for urgent exits."""
    log.warning(f"{symbol}: EMERGENCY EXIT — {reason}")

    ticker      = ibkr.get_ticker(symbol)
    current_bid = ticker.bid or ticker.last or ticker.close

    if not current_bid:
        log.error(f"{symbol}: no price for emergency exit!")
        return 0.0, "exit_failed_no_price"

    # Try aggressive limit first
    trade    = ibkr.place_limit_sell(symbol, current_bid, qty, emergency=True)
    order_id = trade.order.orderId

    for _ in range(EMERGENCY_TIMEOUT):
        ibkr.ib.sleep(1)
        fill = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if fill:
            log.info(f"{symbol}: emergency limit filled @ ${fill:.4f}")
            return fill, reason

    # Cancel and go market
    log.warning(f"{symbol}: limit not filled in {EMERGENCY_TIMEOUT}s → MARKET")
    try:
        ibkr.ib.cancelOrder(trade.order)
    except Exception:
        pass

    market_trade = ibkr.place_market_sell(symbol, qty)
    ibkr.ib.sleep(2)
    fill = ibkr.get_avg_fill_price_from_broker(symbol, market_trade.order.orderId)
    if fill:
        return fill, f"{reason}_market"

    return current_bid * 0.98, f"{reason}_estimated"


# ══════════════════════════════════════════════════════════════════════════════
# EXIT DECISION ENGINE
# ══════════════════════════════════════════════════════════════════════════════

@dataclass
class ExitDecision:
    """What the monitor loop should do for a given position."""
    action: str            # "hold", "partial_sell", "full_sell", "emergency_sell"
    reason: str            # human-readable reason
    qty_to_sell: int = 0   # how many shares to sell (0 = hold)


def evaluate_position(trade: dict, current_price: float, entry_price: float,
                      ibkr: IBKRSellClient) -> ExitDecision:
    """
    Master exit logic — evaluates all conditions in priority order.
    Returns an ExitDecision telling the monitor loop what to do.
    """
    symbol    = trade.get("instrument") or trade.get("symbol")
    total_qty = trade.get("quantity") or trade.get("qty")
    highest   = trade.get("highest_price", entry_price)
    phase     = trade.get("phase", "initial")  # "initial" or "runner"
    pnl_pct   = (current_price - entry_price) / entry_price

    # Track new high
    if current_price > highest:
        highest = current_price
        update_trade_field(trade["_id"], {"highest_price": highest})

    drawdown_from_high = (current_price - highest) / highest if highest > 0 else 0

    log.info(
        f"{symbol}: phase={phase} | entry=${entry_price:.4f} now=${current_price:.4f} "
        f"pnl={pnl_pct * 100:+.2f}% | high=${highest:.4f} dd={drawdown_from_high * 100:.2f}% "
        f"qty={total_qty}"
    )

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 1 — Hard stop (always active)
    # ══════════════════════════════════════════════════════════════════════
    if pnl_pct <= -HARD_STOP_PCT:
        return ExitDecision("emergency_sell", "hard_stop_10pct", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 2 — Flash crash (always active)
    # ══════════════════════════════════════════════════════════════════════
    flash = check_flash_crash(symbol, current_price, trade)
    if flash:
        return ExitDecision("emergency_sell", flash, total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 3 — Liquidity crisis (always active)
    # ══════════════════════════════════════════════════════════════════════
    if check_liquidity_crisis(ibkr, symbol):
        return ExitDecision("emergency_sell", "liquidity_crisis", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 4 — Partial profit (only in "initial" phase)
    # ══════════════════════════════════════════════════════════════════════
    if phase == "initial" and pnl_pct >= PARTIAL_PROFIT_PCT:
        sell_qty = max(1, int(total_qty * PARTIAL_SELL_FRACTION))
        if sell_qty >= total_qty:
            # Position too small to split — just sell all
            return ExitDecision("full_sell", f"profit_target_{pnl_pct * 100:.1f}pct", total_qty)
        return ExitDecision("partial_sell", f"partial_profit_{pnl_pct * 100:.1f}pct", sell_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 5 — Trailing stop (primarily for runner phase, but also
    #              protects initial phase if price ran and pulled back)
    # ══════════════════════════════════════════════════════════════════════
    stop_level = compute_trailing_stop(entry_price, highest, pnl_pct)

    # Only activate trailing stop if we've been profitable enough
    # that the trail is meaningful (above hard stop level)
    if stop_level > entry_price * (1 - HARD_STOP_PCT):
        if current_price <= stop_level:
            trail_pct = get_trailing_stop_pct(pnl_pct)
            return ExitDecision(
                "full_sell",
                f"trailing_stop_{trail_pct * 100:.0f}pct_from_high",
                total_qty,
            )

    # Update trailing stop level in DB for monitoring
    update_trade_field(trade["_id"], {"trailing_stop": stop_level})

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 6 — Technical exit signals (runner phase)
    #   PSAR bearish + price below EMA 9 → exit
    #   EMA 9 death-crosses EMA 21        → exit
    # ══════════════════════════════════════════════════════════════════════
    if phase == "runner":
        signals = ibkr.compute_exit_signals(symbol)
        if signals:
            # PSAR bearish AND price below EMA 9 = trend broken
            if signals.get("psar_bearish") and signals.get("price_below_ema9"):
                return ExitDecision(
                    "full_sell",
                    "psar_bearish_below_ema9",
                    total_qty,
                )

            # EMA 9/21 death cross = momentum dead
            if signals.get("ema_death_cross"):
                return ExitDecision(
                    "full_sell",
                    "ema_9_21_death_cross",
                    total_qty,
                )

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 7 — Stale trade (going nowhere for too long)
    # ══════════════════════════════════════════════════════════════════════
    if check_stale_trade(trade, pnl_pct):
        return ExitDecision("full_sell", "stale_trade_timeout", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # DEFAULT — Hold
    # ══════════════════════════════════════════════════════════════════════
    trail_pct = get_trailing_stop_pct(pnl_pct)
    log.info(
        f"{symbol}: HOLD | trail={trail_pct * 100:.0f}% "
        f"stop=${stop_level:.4f} | phase={phase}"
    )
    return ExitDecision("hold", "holding", 0)


# ══════════════════════════════════════════════════════════════════════════════
# MAIN MONITOR LOOP
# ══════════════════════════════════════════════════════════════════════════════

def monitor_positions(ibkr: IBKRSellClient):
    log.info("=" * 60)
    log.info("SELL BOT v2 — Smart Position Manager")
    log.info(f"Hard Stop: {HARD_STOP_PCT * 100}% | "
             f"Partial: {PARTIAL_PROFIT_PCT * 100}% ({PARTIAL_SELL_FRACTION * 100}% of qty) | "
             f"Flash: {FLASH_CRASH_PCT * 100}%")
    log.info(f"Trailing tiers: {[(f'+{t*100:.0f}%', f'{p*100:.0f}%') for t, p in TRAILING_TIERS]}")
    log.info(f"Stale exit: >{STALE_TRADE_HOURS}h if PnL in "
             f"[{STALE_TRADE_MIN_PNL * 100}%, {STALE_TRADE_MAX_PNL * 100}%]")
    log.info("=" * 60)

    while True:
        try:
            open_trades = get_open_trades()
            log.info(f"--- Checking {len(open_trades)} open trade(s) ---")

            for trade in open_trades:
                symbol    = trade.get("instrument") or trade.get("symbol")
                total_qty = trade.get("quantity") or trade.get("qty")

                if not symbol or not total_qty:
                    log.warning(f"Skipping trade {trade['_id']}: missing symbol or qty")
                    continue

                # Get entry and current price
                entry_price   = get_effective_entry_price(trade, ibkr)
                current_price = ibkr.get_last_price(symbol)
                if not current_price:
                    log.warning(f"{symbol}: no current price, skipping")
                    continue

                # Evaluate what to do
                decision = evaluate_position(trade, current_price, entry_price, ibkr)

                if decision.action == "hold":
                    continue

                # ── Execute the decision ──────────────────────────────────────

                if decision.action == "emergency_sell":
                    exit_price, final_reason = emergency_exit(
                        ibkr, symbol, decision.qty_to_sell, decision.reason
                    )
                    close_trade(trade, exit_price, final_reason, decision.qty_to_sell)

                elif decision.action == "partial_sell":
                    sell_trade   = ibkr.place_limit_sell(symbol, current_price,
                                                         decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                              current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

                elif decision.action == "full_sell":
                    sell_trade   = ibkr.place_limit_sell(symbol, current_price,
                                                         decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                              current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

        except Exception as e:
            log.error(f"Monitor error: {e}", exc_info=True)

        time.sleep(MONITOR_INTERVAL)


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY POINT
# ══════════════════════════════════════════════════════════════════════════════

def main():
    log.info("=== Sell Bot v2 Starting ===")
    ibkr = IBKRSellClient()

    try:
        ibkr.connect()
        monitor_positions(ibkr)
    except KeyboardInterrupt:
        log.info("Sell bot stopped by user.")
    except Exception as e:
        log.error(f"Fatal error: {e}", exc_info=True)
    finally:
        ibkr.disconnect()
        log.info("IBKR disconnected.")


if __name__ == "__main__":
    main()

# %%
"""
Sell Bot v2 — Smart Position Manager
═════════════════════════════════════
Monitors open positions via IBKR + MongoDB.

EXIT STRATEGY (designed for momentum breakout plays):
─────────────────────────────────────────────────────
Phase 1 — PROTECTION (from entry until profitable):
  • Hard stop: -10% from entry (expanded from 3% to let breakouts breathe)
  • Flash crash: -5% drop in a single 30-second interval → emergency exit

Phase 2 — PARTIAL PROFIT at +50%:
  • Sell 50% of position, lock in gains
  • Remaining 50% enters "runner" mode with trailing stop

Phase 3 — RUNNER (remaining shares after partial):
  • Trailing stop tightens in tiers based on how far price has run:
      +50% to +75%  →  trail 15% from high  (give it room to consolidate)
      +75% to +100% →  trail 12% from high
      +100% to +150% → trail 10% from high
      +150%+         → trail  8% from high  (tightest — protect big win)
  • TRAILING STOP CONFIRMATION: trail stop only triggers if PSAR is bearish
    OR price is below EMA 21 (prevents exiting on normal pullbacks in a trend)
  • PSAR flip bearish → soft exit (only triggers if also below EMA 9)
  • EMA 9 crosses below EMA 21 → exit runner (trend is done)

Phase 4 — TIME DECAY (if stock goes nowhere):
  • If position is between -5% and +10% after 2 hours → exit
    (momentum play didn't work, free up capital)

EMERGENCY EXITS (always active, any phase):
  • Flash crash detection (configurable threshold)
  • Liquidity crisis (spread > 0.5%)
  • These use aggressive limit → market order fallback

RE-ENTRY COOLDOWN:
  • After closing a position, a cooldown period is recorded in MongoDB
  • Buy bot should check cooldown before re-entering the same symbol
"""

import logging
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import random
from typing import Optional
from dataclasses import dataclass

from pymongo import MongoClient
from ib_insync import *

import warnings
warnings.filterwarnings("ignore")


# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ─── IBKR ─────────────────────────────────────────────────────────────────────
IBKR_HOST      = "127.0.0.1"
IBKR_PORT      = 7497
IBKR_CLIENT_ID = random.randint(1, 1000)

# ─── Exit Thresholds ──────────────────────────────────────────────────────────
HARD_STOP_PCT          = 0.10    # 10% max loss from entry (expanded from 3%)
FLASH_CRASH_PCT        = 0.05    # 5% drop in one interval → emergency
LIQUIDITY_SPREAD_PCT   = 0.005   # 0.5% spread → liquidity crisis

# ─── Partial Profit ───────────────────────────────────────────────────────────
PARTIAL_PROFIT_PCT     = 0.50    # Take partial at +50%
PARTIAL_SELL_FRACTION  = 0.50    # Sell 50% of position

# ─── Tiered Trailing Stops (for runner after partial) ─────────────────────────
# Each tuple: (profit_threshold, trail_pct_from_high)
# Evaluated top-down — first match wins
TRAILING_TIERS = [
    (1.50, 0.08),   # +150%+ profit → trail 8% from high
    (1.00, 0.10),   # +100%+ profit → trail 10%
    (0.75, 0.12),   # +75%+  profit → trail 12%
    (0.50, 0.15),   # +50%+  profit → trail 15%
]
DEFAULT_TRAILING_PCT   = 0.20    # Before +50%, if somehow needed: 20%

# ─── Time Decay ───────────────────────────────────────────────────────────────
STALE_TRADE_HOURS      = 2      # Exit if position stagnates after this long
STALE_TRADE_MIN_PNL    = -0.05  # … and P&L is between this …
STALE_TRADE_MAX_PNL    = 0.10   # … and this (going nowhere)

# ─── Technical Exit Signals ───────────────────────────────────────────────────
# PSAR + EMA crossover used as confirmation for runner exits
EMA_FAST_PERIOD        = 9
EMA_SLOW_PERIOD        = 21

# ─── Re-entry Cooldown ───────────────────────────────────────────────────────
REENTRY_COOLDOWN_MIN   = 30     # Minutes to wait before re-entering same symbol

# ─── Monitoring ───────────────────────────────────────────────────────────────
MONITOR_INTERVAL       = 30     # seconds between checks
EMERGENCY_TIMEOUT      = 5      # seconds to wait for limit fill before market

# ─── MongoDB ──────────────────────────────────────────────────────────────────
mongo_client       = MongoClient("mongodb://localhost:27017/")
db                 = mongo_client["breakout_db"]
trades_collection  = db["trades_v2"]
cooldown_collection = db["cooldowns"]   # NEW: tracks re-entry cooldowns


# ══════════════════════════════════════════════════════════════════════════════
# LOGGING
# ══════════════════════════════════════════════════════════════════════════════

class _Utf8SafeStreamHandler(logging.StreamHandler):
    def emit(self, record):
        try:
            super().emit(record)
        except UnicodeEncodeError:
            record.msg = str(record.msg).encode("ascii", errors="replace").decode("ascii")
            record.args = ()
            try:
                super().emit(record)
            except Exception:
                self.handleError(record)

    def _try_utf8(self):
        try:
            if hasattr(self.stream, "reconfigure"):
                self.stream.reconfigure(encoding="utf-8", errors="replace")
        except Exception:
            pass


def _make_logger() -> logging.Logger:
    fmt = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
    sh  = _Utf8SafeStreamHandler(sys.stdout)
    sh._try_utf8()
    sh.setFormatter(fmt)
    fh  = logging.FileHandler("sell_bot.log", encoding="utf-8")
    fh.setFormatter(fmt)
    logger = logging.getLogger("sell_bot")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    logger.addHandler(sh)
    logger.addHandler(fh)
    logger.propagate = False
    return logger

log = _make_logger()


# ══════════════════════════════════════════════════════════════════════════════
# IBKR CLIENT
# ══════════════════════════════════════════════════════════════════════════════

class IBKRSellClient:
    def __init__(self):
        util.startLoop()
        self.ib = IB()

    def connect(self):
        self.ib.connect(IBKR_HOST, IBKR_PORT, clientId=IBKR_CLIENT_ID)
        log.info(f"IBKR connected | accounts: {self.ib.wrapper.accounts}")

    def disconnect(self):
        self.ib.disconnect()

    # ── Price helpers ─────────────────────────────────────────────────────────

    def get_last_price(self, symbol: str) -> Optional[float]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "106", False, False)
        self.ib.sleep(3)
        self.ib.cancelMktData(contract)

        for label, val in [("last", ticker.last), ("ask", ticker.ask),
                           ("bid", ticker.bid), ("close", ticker.close)]:
            if val and float(val) > 0:
                log.debug(f"{symbol}: price source='{label}' ${float(val):.4f}")
                return float(val)

        log.warning(f"{symbol}: no price available")
        return None

    def get_ticker(self, symbol: str) -> Ticker:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "", False, False)
        self.ib.sleep(2)
        return ticker

    # ── Historical bars ───────────────────────────────────────────────────────

    def get_bars(self, symbol: str, n: int = 70) -> Optional[pd.DataFrame]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)

        for what_to_show in ("TRADES", "MIDPOINT"):
            raw = self.ib.reqHistoricalData(
                contract,
                endDateTime="",
                durationStr="10 D",
                barSizeSetting="5 mins",
                whatToShow=what_to_show,
                useRTH=False,
                keepUpToDate=False,
            )
            if raw:
                df = pd.DataFrame([
                    {"open": b.open, "high": b.high, "low": b.low,
                     "close": b.close, "volume": getattr(b, "volume", 0)}
                    for b in raw
                ])
                return df.tail(n).reset_index(drop=True)

        log.warning(f"{symbol}: no bars returned")
        return None

    # ── Technical indicators ──────────────────────────────────────────────────

    def compute_exit_signals(self, symbol: str) -> dict:
        """
        Compute PSAR, EMA 9, EMA 21 for exit decisions.
        Returns dict with signal flags or empty dict on failure.
        """
        df = self.get_bars(symbol, n=70)
        if df is None or len(df) < 25:
            log.warning(f"{symbol}: not enough bars for exit signals")
            return {}

        # Parabolic SAR
        psar_vals = self._compute_psar(df["high"].values, df["low"].values,
                                       df["close"].values)

        # EMA 9 / 21
        ema_fast = df["close"].ewm(span=EMA_FAST_PERIOD, adjust=False).mean()
        ema_slow = df["close"].ewm(span=EMA_SLOW_PERIOD, adjust=False).mean()

        price     = float(df["close"].iloc[-1])
        psar_now  = float(psar_vals[-1])
        ema9_now  = float(ema_fast.iloc[-1])
        ema21_now = float(ema_slow.iloc[-1])

        # Previous bar for crossover detection
        ema9_prev  = float(ema_fast.iloc[-2])
        ema21_prev = float(ema_slow.iloc[-2])

        psar_bearish       = psar_now > price       # SAR above price = downtrend
        ema_death_cross    = (ema9_prev >= ema21_prev) and (ema9_now < ema21_now)
        ema_bearish        = ema9_now < ema21_now    # EMA 9 below 21
        price_below_ema9   = price < ema9_now
        price_below_ema21  = price < ema21_now       # NEW: for trailing stop confirmation

        signals = {
            "price":              price,
            "psar":               psar_now,
            "ema_9":              ema9_now,
            "ema_21":             ema21_now,
            "psar_bearish":       psar_bearish,
            "ema_death_cross":    ema_death_cross,
            "ema_bearish":        ema_bearish,
            "price_below_ema9":   price_below_ema9,
            "price_below_ema21":  price_below_ema21,
        }

        log.info(
            f"{symbol} signals: PSAR={psar_now:.4f}({'BEAR' if psar_bearish else 'BULL'}) "
            f"EMA9={ema9_now:.4f} EMA21={ema21_now:.4f} "
            f"cross={'YES' if ema_death_cross else 'no'} "
            f"below9={'YES' if price_below_ema9 else 'no'} "
            f"below21={'YES' if price_below_ema21 else 'no'}"
        )
        return signals

    @staticmethod
    def _compute_psar(highs, lows, closes, iaf=0.02, max_af=0.2) -> np.ndarray:
        n    = len(closes)
        psar = closes.copy().astype(float)
        bull = True
        af   = iaf
        hp   = float(highs[0])
        lp   = float(lows[0])

        for i in range(2, n):
            if bull:
                psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
                psar[i] = min(psar[i], lows[i - 1], lows[i - 2])
                if lows[i] < psar[i]:
                    bull    = False
                    psar[i] = hp
                    lp      = lows[i]
                    af      = iaf
                else:
                    if highs[i] > hp:
                        hp = highs[i]
                        af = min(af + iaf, max_af)
            else:
                psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
                psar[i] = max(psar[i], highs[i - 1], highs[i - 2])
                if highs[i] > psar[i]:
                    bull    = True
                    psar[i] = lp
                    hp      = highs[i]
                    af      = iaf
                else:
                    if lows[i] < lp:
                        lp = lows[i]
                        af = min(af + iaf, max_af)
        return psar

    # ── Order execution ───────────────────────────────────────────────────────

    def get_avg_fill_price_from_broker(self, symbol: str, order_id: int) -> Optional[float]:
        for trade in self.ib.trades():
            if (trade.contract.symbol == symbol
                    and trade.order.orderId == order_id
                    and trade.orderStatus.avgFillPrice > 0):
                return float(trade.orderStatus.avgFillPrice)

        fills   = self.ib.fills()
        matched = [f for f in fills
                   if f.contract.symbol == symbol and f.execution.orderId == order_id]
        if matched:
            total_qty  = sum(f.execution.shares for f in matched)
            total_cost = sum(f.execution.shares * f.execution.price for f in matched)
            return total_cost / total_qty

        return None

    def place_limit_sell(self, symbol: str, price: float, qty: int,
                         emergency: bool = False) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)

        if emergency:
            price = price * 0.99  # 1% below for faster fill

        order = LimitOrder("SELL", qty, round(price, 2))
        order.outsideRth = True
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)

        log.info(f"SELL LIMIT {symbol} x{qty} @ ${price:.2f} "
                 f"orderId={trade.order.orderId} emergency={emergency}")
        return trade

    def place_market_sell(self, symbol: str, qty: int) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        order = MarketOrder("SELL", qty)
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL MARKET {symbol} x{qty} orderId={trade.order.orderId}")
        return trade

    def get_sell_fill_price(self, symbol: str, sell_order_id: int,
                            fallback_price: float) -> float:
        self.ib.sleep(3)
        avg = self.get_avg_fill_price_from_broker(symbol, sell_order_id)
        if avg:
            return avg
        log.warning(f"{symbol}: sell fill not confirmed, using fallback ${fallback_price:.4f}")
        return fallback_price


# ══════════════════════════════════════════════════════════════════════════════
# MONGODB HELPERS
# ══════════════════════════════════════════════════════════════════════════════

def get_open_trades() -> list:
    return list(trades_collection.find({"status": "open"}))


def get_effective_entry_price(trade: dict, ibkr: IBKRSellClient) -> float:
    """Priority: avg_fill_price (DB) → broker lookup → entry_price (DB)."""
    if trade.get("avg_fill_price"):
        return float(trade["avg_fill_price"])

    order_id = trade.get("order_id")
    symbol   = trade.get("instrument") or trade.get("symbol")

    if order_id:
        broker_avg = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if broker_avg:
            trades_collection.update_one(
                {"_id": trade["_id"]},
                {"$set": {"avg_fill_price": broker_avg, "entry_price": broker_avg}},
            )
            return broker_avg

    return float(trade["entry_price"])


def update_trade_field(trade_id, updates: dict):
    updates["updated_at"] = datetime.now(timezone.utc)
    trades_collection.update_one({"_id": trade_id}, {"$set": updates})


def close_trade(trade: dict, exit_price: float, reason: str, qty_sold: int = None):
    """Close (or partially close) a trade in MongoDB."""
    symbol      = trade.get("instrument") or trade.get("symbol")
    entry_price = float(trade.get("avg_fill_price") or trade["entry_price"])
    total_qty   = trade.get("quantity") or trade.get("qty")
    pnl_pct     = (exit_price - entry_price) / entry_price

    if qty_sold is None:
        qty_sold = total_qty

    realized_pnl = (exit_price - entry_price) * qty_sold

    if qty_sold >= total_qty:
        # Full close
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "status":           "closed",
                "exit_price":       exit_price,
                "exit_timestamp":   datetime.now(timezone.utc),
                "reason":           reason,
                "pnl_pct":          round(pnl_pct * 100, 2),
                "realized_pnl":     realized_pnl,
                "updated_at":       datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"CLOSED {symbol} | entry=${entry_price:.4f} exit=${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | reason={reason}"
        )
        # ── Set re-entry cooldown ─────────────────────────────────────────
        set_cooldown(symbol, reason)
    else:
        # Partial close — reduce quantity, record partial exit
        remaining = total_qty - qty_sold
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "quantity":              remaining,
                "partial_exit_price":    exit_price,
                "partial_exit_qty":      qty_sold,
                "partial_exit_time":     datetime.now(timezone.utc),
                "partial_exit_reason":   reason,
                "partial_realized_pnl":  realized_pnl,
                "phase":                 "runner",
                "updated_at":            datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"PARTIAL CLOSE {symbol} | sold {qty_sold}/{total_qty} @ ${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | "
            f"remaining={remaining} shares → runner mode"
        )


# ══════════════════════════════════════════════════════════════════════════════
# RE-ENTRY COOLDOWN
# ══════════════════════════════════════════════════════════════════════════════

def set_cooldown(symbol: str, reason: str):
    """
    After closing a position, set a cooldown to prevent immediate re-entry.
    The buy bot should call is_in_cooldown() before opening a new position.
    """
    expires_at = datetime.now(timezone.utc) + timedelta(minutes=REENTRY_COOLDOWN_MIN)
    cooldown_collection.update_one(
        {"symbol": symbol},
        {"$set": {
            "symbol":       symbol,
            "reason":       reason,
            "closed_at":    datetime.now(timezone.utc),
            "expires_at":   expires_at,
            "cooldown_min": REENTRY_COOLDOWN_MIN,
        }},
        upsert=True,
    )
    log.info(
        f"{symbol}: COOLDOWN SET — no re-entry for {REENTRY_COOLDOWN_MIN} min "
        f"(until {expires_at.strftime('%H:%M:%S')} UTC) | close reason: {reason}"
    )


def is_in_cooldown(symbol: str) -> bool:
    """
    Check if a symbol is in cooldown (call this from the BUY bot before entering).
    Returns True if the symbol should NOT be traded yet.
    """
    record = cooldown_collection.find_one({"symbol": symbol})
    if not record:
        return False

    expires_at = record.get("expires_at")
    if not expires_at:
        return False

    now = datetime.now(timezone.utc)
    if expires_at.tzinfo is None:
        # Handle naive datetime from DB
        in_cooldown = datetime.now() < expires_at
    else:
        in_cooldown = now < expires_at

    if in_cooldown:
        remaining = (expires_at - now).total_seconds() / 60
        log.info(f"{symbol}: IN COOLDOWN — {remaining:.1f} min remaining "
                 f"(closed for: {record.get('reason', 'unknown')})")
    else:
        # Cooldown expired — clean up
        cooldown_collection.delete_one({"symbol": symbol})

    return in_cooldown


def clear_cooldown(symbol: str):
    """Manually clear a cooldown (e.g., if conditions change dramatically)."""
    cooldown_collection.delete_one({"symbol": symbol})
    log.info(f"{symbol}: cooldown manually cleared")


# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def get_trailing_stop_pct(pnl_pct: float) -> float:
    """
    Return the trailing stop percentage based on how far price has run.
    Tighter trail as profit grows (protect bigger wins).
    """
    for threshold, trail in TRAILING_TIERS:
        if pnl_pct >= threshold:
            return trail
    return DEFAULT_TRAILING_PCT


def compute_trailing_stop(entry_price: float, highest_price: float,
                          current_pnl_pct: float) -> float:
    """Compute the effective trailing stop price."""
    trail_pct  = get_trailing_stop_pct(current_pnl_pct)
    trail_stop = highest_price * (1 - trail_pct)
    hard_stop  = entry_price * (1 - HARD_STOP_PCT)
    return max(trail_stop, hard_stop)


def check_flash_crash(symbol: str, current_price: float, trade: dict) -> Optional[str]:
    """Detect sudden price drops within a single monitoring interval."""
    last_price = trade.get("last_price")

    # Always update for next iteration
    update_trade_field(trade["_id"], {
        "last_price":      current_price,
        "last_price_time": datetime.now(timezone.utc),
    })

    if last_price and last_price > 0:
        drop_pct = (current_price - last_price) / last_price
        if drop_pct <= -FLASH_CRASH_PCT:
            log.warning(f"{symbol}: FLASH CRASH {drop_pct * 100:.2f}% in {MONITOR_INTERVAL}s")
            return f"flash_crash_{abs(drop_pct) * 100:.1f}pct"

    return None


def check_liquidity_crisis(ibkr: IBKRSellClient, symbol: str) -> bool:
    """Detect bid-ask spread blowing out."""
    try:
        ticker = ibkr.get_ticker(symbol)
        if ticker.bid and ticker.ask and ticker.bid > 0:
            mid        = (ticker.ask + ticker.bid) / 2
            spread_pct = (ticker.ask - ticker.bid) / mid
            if spread_pct > LIQUIDITY_SPREAD_PCT:
                log.warning(f"{symbol}: liquidity crisis — spread {spread_pct * 100:.2f}%")
                return True
    except Exception as e:
        log.error(f"{symbol}: liquidity check error — {e}")
    return False


def check_stale_trade(trade: dict, pnl_pct: float) -> bool:
    """
    If position has been open > STALE_TRADE_HOURS and P&L is flat,
    it's a dead momentum play — exit to free capital.
    """
    entry_time = trade.get("entry_timestamp")
    if not entry_time:
        return False

    # Handle both timezone-aware and naive datetimes
    if entry_time.tzinfo is None:
        hours_held = (datetime.now() - entry_time).total_seconds() / 3600
    else:
        hours_held = (datetime.now(timezone.utc) - entry_time).total_seconds() / 3600

    if hours_held >= STALE_TRADE_HOURS:
        if STALE_TRADE_MIN_PNL <= pnl_pct <= STALE_TRADE_MAX_PNL:
            log.info(
                f"{trade.get('instrument') or trade.get('symbol')}: "
                f"stale trade — {hours_held:.1f}h held, pnl={pnl_pct * 100:+.2f}% "
                f"(flat zone {STALE_TRADE_MIN_PNL * 100}% to {STALE_TRADE_MAX_PNL * 100}%)"
            )
            return True
    return False


# ══════════════════════════════════════════════════════════════════════════════
# EMERGENCY EXIT
# ══════════════════════════════════════════════════════════════════════════════

def emergency_exit(ibkr: IBKRSellClient, symbol: str, qty: int,
                   reason: str) -> tuple[float, str]:
    """Aggressive limit → market fallback for urgent exits."""
    log.warning(f"{symbol}: EMERGENCY EXIT — {reason}")

    ticker      = ibkr.get_ticker(symbol)
    current_bid = ticker.bid or ticker.last or ticker.close

    if not current_bid:
        log.error(f"{symbol}: no price for emergency exit!")
        return 0.0, "exit_failed_no_price"

    # Try aggressive limit first
    trade    = ibkr.place_limit_sell(symbol, current_bid, qty, emergency=True)
    order_id = trade.order.orderId

    for _ in range(EMERGENCY_TIMEOUT):
        ibkr.ib.sleep(1)
        fill = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if fill:
            log.info(f"{symbol}: emergency limit filled @ ${fill:.4f}")
            return fill, reason

    # Cancel and go market
    log.warning(f"{symbol}: limit not filled in {EMERGENCY_TIMEOUT}s → MARKET")
    try:
        ibkr.ib.cancelOrder(trade.order)
    except Exception:
        pass

    market_trade = ibkr.place_market_sell(symbol, qty)
    ibkr.ib.sleep(2)
    fill = ibkr.get_avg_fill_price_from_broker(symbol, market_trade.order.orderId)
    if fill:
        return fill, f"{reason}_market"

    return current_bid * 0.98, f"{reason}_estimated"


# ══════════════════════════════════════════════════════════════════════════════
# EXIT DECISION ENGINE
# ══════════════════════════════════════════════════════════════════════════════

@dataclass
class ExitDecision:
    """What the monitor loop should do for a given position."""
    action: str            # "hold", "partial_sell", "full_sell", "emergency_sell"
    reason: str            # human-readable reason
    qty_to_sell: int = 0   # how many shares to sell (0 = hold)


def evaluate_position(trade: dict, current_price: float, entry_price: float,
                      ibkr: IBKRSellClient) -> ExitDecision:
    """
    Master exit logic — evaluates all conditions in priority order.
    Returns an ExitDecision telling the monitor loop what to do.
    """
    symbol    = trade.get("instrument") or trade.get("symbol")
    total_qty = trade.get("quantity") or trade.get("qty")
    highest   = trade.get("highest_price", entry_price)
    phase     = trade.get("phase", "initial")  # "initial" or "runner"
    pnl_pct   = (current_price - entry_price) / entry_price

    # Track new high
    if current_price > highest:
        highest = current_price
        update_trade_field(trade["_id"], {"highest_price": highest})

    drawdown_from_high = (current_price - highest) / highest if highest > 0 else 0

    log.info(
        f"{symbol}: phase={phase} | entry=${entry_price:.4f} now=${current_price:.4f} "
        f"pnl={pnl_pct * 100:+.2f}% | high=${highest:.4f} dd={drawdown_from_high * 100:.2f}% "
        f"qty={total_qty}"
    )

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 1 — Hard stop (always active)
    # ══════════════════════════════════════════════════════════════════════
    if pnl_pct <= -HARD_STOP_PCT:
        return ExitDecision("emergency_sell", "hard_stop_10pct", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 2 — Flash crash (always active)
    # ══════════════════════════════════════════════════════════════════════
    flash = check_flash_crash(symbol, current_price, trade)
    if flash:
        return ExitDecision("emergency_sell", flash, total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 3 — Liquidity crisis (always active)
    # ══════════════════════════════════════════════════════════════════════
    if check_liquidity_crisis(ibkr, symbol):
        return ExitDecision("emergency_sell", "liquidity_crisis", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 4 — Partial profit (only in "initial" phase)
    # ══════════════════════════════════════════════════════════════════════
    if phase == "initial" and pnl_pct >= PARTIAL_PROFIT_PCT:
        sell_qty = max(1, int(total_qty * PARTIAL_SELL_FRACTION))
        if sell_qty >= total_qty:
            # Position too small to split — just sell all
            return ExitDecision("full_sell", f"profit_target_{pnl_pct * 100:.1f}pct", total_qty)
        return ExitDecision("partial_sell", f"partial_profit_{pnl_pct * 100:.1f}pct", sell_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 5 — Trailing stop WITH CONFIRMATION
    #   Trail stop level is still computed, but it only triggers if
    #   PSAR is bearish OR price is below EMA 21.
    #   This prevents exiting on normal pullbacks during a strong trend.
    # ══════════════════════════════════════════════════════════════════════
    stop_level = compute_trailing_stop(entry_price, highest, pnl_pct)

    # Only activate trailing stop if we've been profitable enough
    # that the trail is meaningful (above hard stop level)
    if stop_level > entry_price * (1 - HARD_STOP_PCT):
        if current_price <= stop_level:
            # ── NEW: Require technical confirmation before triggering ──
            signals = ibkr.compute_exit_signals(symbol)
            trend_broken = False

            if signals:
                psar_bearish      = signals.get("psar_bearish", False)
                price_below_ema21 = signals.get("price_below_ema21", False)

                if psar_bearish or price_below_ema21:
                    trend_broken = True
                    confirm_reason = (
                        "psar_bearish" if psar_bearish else "below_ema21"
                    )
                    log.info(
                        f"{symbol}: trailing stop CONFIRMED by {confirm_reason} "
                        f"(PSAR_bear={psar_bearish}, below_EMA21={price_below_ema21})"
                    )
                else:
                    log.info(
                        f"{symbol}: trailing stop level breached (${stop_level:.4f}) "
                        f"but PSAR bullish & above EMA21 — HOLDING through pullback"
                    )
            else:
                # No signals available (bars failed) — fall back to triggering
                # the trailing stop without confirmation for safety
                trend_broken = True
                log.warning(
                    f"{symbol}: trailing stop breached & no signal data — "
                    f"triggering stop as safety fallback"
                )

            if trend_broken:
                trail_pct = get_trailing_stop_pct(pnl_pct)
                return ExitDecision(
                    "full_sell",
                    f"trailing_stop_{trail_pct * 100:.0f}pct_confirmed",
                    total_qty,
                )

    # Update trailing stop level in DB for monitoring
    update_trade_field(trade["_id"], {"trailing_stop": stop_level})

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 6 — Technical exit signals (runner phase)
    #   PSAR bearish + price below EMA 9 → exit
    #   EMA 9 death-crosses EMA 21        → exit
    # ══════════════════════════════════════════════════════════════════════
    if phase == "runner":
        signals = ibkr.compute_exit_signals(symbol)
        if signals:
            # PSAR bearish AND price below EMA 9 = trend broken
            if signals.get("psar_bearish") and signals.get("price_below_ema9"):
                return ExitDecision(
                    "full_sell",
                    "psar_bearish_below_ema9",
                    total_qty,
                )

            # EMA 9/21 death cross = momentum dead
            if signals.get("ema_death_cross"):
                return ExitDecision(
                    "full_sell",
                    "ema_9_21_death_cross",
                    total_qty,
                )

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 7 — Stale trade (going nowhere for too long)
    # ══════════════════════════════════════════════════════════════════════
    if check_stale_trade(trade, pnl_pct):
        return ExitDecision("full_sell", "stale_trade_timeout", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # DEFAULT — Hold
    # ══════════════════════════════════════════════════════════════════════
    trail_pct = get_trailing_stop_pct(pnl_pct)
    log.info(
        f"{symbol}: HOLD | trail={trail_pct * 100:.0f}% "
        f"stop=${stop_level:.4f} | phase={phase}"
    )
    return ExitDecision("hold", "holding", 0)


# ══════════════════════════════════════════════════════════════════════════════
# MAIN MONITOR LOOP
# ══════════════════════════════════════════════════════════════════════════════

def monitor_positions(ibkr: IBKRSellClient):
    log.info("=" * 60)
    log.info("SELL BOT v2.1 — Smart Position Manager (PSAR-confirmed trails)")
    log.info(f"Hard Stop: {HARD_STOP_PCT * 100}% | "
             f"Partial: {PARTIAL_PROFIT_PCT * 100}% ({PARTIAL_SELL_FRACTION * 100}% of qty) | "
             f"Flash: {FLASH_CRASH_PCT * 100}%")
    log.info(f"Trailing tiers: {[(f'+{t*100:.0f}%', f'{p*100:.0f}%') for t, p in TRAILING_TIERS]}")
    log.info(f"Trail confirmation: PSAR bearish OR price < EMA 21")
    log.info(f"Re-entry cooldown: {REENTRY_COOLDOWN_MIN} min")
    log.info(f"Stale exit: >{STALE_TRADE_HOURS}h if PnL in "
             f"[{STALE_TRADE_MIN_PNL * 100}%, {STALE_TRADE_MAX_PNL * 100}%]")
    log.info("=" * 60)

    while True:
        try:
            open_trades = get_open_trades()
            log.info(f"--- Checking {len(open_trades)} open trade(s) ---")

            for trade in open_trades:
                symbol    = trade.get("instrument") or trade.get("symbol")
                total_qty = trade.get("quantity") or trade.get("qty")

                if not symbol or not total_qty:
                    log.warning(f"Skipping trade {trade['_id']}: missing symbol or qty")
                    continue

                # Get entry and current price
                entry_price   = get_effective_entry_price(trade, ibkr)
                current_price = ibkr.get_last_price(symbol)
                if not current_price:
                    log.warning(f"{symbol}: no current price, skipping")
                    continue

                # Evaluate what to do
                decision = evaluate_position(trade, current_price, entry_price, ibkr)

                if decision.action == "hold":
                    continue

                # ── Execute the decision ──────────────────────────────────────

                if decision.action == "emergency_sell":
                    exit_price, final_reason = emergency_exit(
                        ibkr, symbol, decision.qty_to_sell, decision.reason
                    )
                    close_trade(trade, exit_price, final_reason, decision.qty_to_sell)

                elif decision.action == "partial_sell":
                    sell_trade   = ibkr.place_limit_sell(symbol, current_price,
                                                         decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                              current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

                elif decision.action == "full_sell":
                    sell_trade   = ibkr.place_limit_sell(symbol, current_price,
                                                         decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                              current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

        except Exception as e:
            log.error(f"Monitor error: {e}", exc_info=True)

        time.sleep(MONITOR_INTERVAL)


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY POINT
# ══════════════════════════════════════════════════════════════════════════════

def main():
    log.info("=== Sell Bot v2.1 Starting ===")
    ibkr = IBKRSellClient()

    try:
        ibkr.connect()
        monitor_positions(ibkr)
    except KeyboardInterrupt:
        log.info("Sell bot stopped by user.")
    except Exception as e:
        log.error(f"Fatal error: {e}", exc_info=True)
    finally:
        ibkr.disconnect()
        log.info("IBKR disconnected.")


if __name__ == "__main__":
    main()

# %%
"""
Sell Bot v2.3 — Smart Position Manager
═══════════════════════════════════════
Monitors open positions via IBKR + MongoDB.

CHANGES from v2.1:
─────────────────
1. REMOVED liquidity crisis check entirely (was causing false exits on
   low-priced stocks where wide spreads are normal).
2. Profitable exits now rely on PSAR confirmation — trailing stop only
   triggers when PSAR is bearish (not EMA21 alone).
3. Duplicate position consolidation added — merges multiple open trades
   for the same symbol into one so exit logic works on full position.

EXIT STRATEGY (designed for momentum breakout plays):
─────────────────────────────────────────────────────
Phase 1 — PROTECTION (from entry until profitable):
  • Hard stop: -10% from entry
  • Flash crash: -5% drop in a single 30-second interval → emergency exit

Phase 2 — PARTIAL PROFIT at +50%:
  • Sell 50% of position, lock in gains
  • Remaining 50% enters "runner" mode with trailing stop

Phase 3 — RUNNER (remaining shares after partial):
  • Trailing stop tightens in tiers based on how far price has run:
      +50% to +75%  →  trail 15% from high
      +75% to +100% →  trail 12% from high
      +100% to +150% → trail 10% from high
      +150%+         → trail  8% from high
  • TRAILING STOP CONFIRMATION: trail stop only triggers if PSAR is bearish
    (prevents exiting on normal pullbacks in a trend)
  • PSAR flip bearish + price below EMA 9 → exit runner
  • EMA 9 crosses below EMA 21 → exit runner (trend is done)

Phase 4 — TIME DECAY (if stock goes nowhere):
  • If position is between -5% and +10% after 2 hours → exit

EMERGENCY EXITS (always active, any phase):
  • Hard stop (-10%)
  • Flash crash detection

RE-ENTRY COOLDOWN:
  • After closing a position, a cooldown period is recorded in MongoDB
  • Buy bot should check cooldown before re-entering the same symbol
"""

import logging
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import random
from typing import Optional
from dataclasses import dataclass
from collections import defaultdict

from pymongo import MongoClient
from ib_insync import *

import warnings
warnings.filterwarnings("ignore")


# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ─── IBKR ─────────────────────────────────────────────────────────────────────
IBKR_HOST      = "127.0.0.1"
IBKR_PORT      = 7497
IBKR_CLIENT_ID = random.randint(1, 1000)

# ─── Exit Thresholds ──────────────────────────────────────────────────────────
HARD_STOP_PCT          = 0.10    # 10% max loss from entry
FLASH_CRASH_PCT        = 0.05    # 5% drop in one interval → emergency

# ─── Partial Profit ───────────────────────────────────────────────────────────
PARTIAL_PROFIT_PCT     = 0.50    # Take partial at +50%
PARTIAL_SELL_FRACTION  = 0.50    # Sell 50% of position

# ─── Tiered Trailing Stops (for runner after partial) ─────────────────────────
TRAILING_TIERS = [
    (1.50, 0.08),   # +150%+ profit → trail 8% from high
    (1.00, 0.10),   # +100%+ profit → trail 10%
    (0.75, 0.12),   # +75%+  profit → trail 12%
    (0.50, 0.15),   # +50%+  profit → trail 15%
]
DEFAULT_TRAILING_PCT   = 0.20    # Before +50%, if somehow needed: 20%

# ─── Time Decay ───────────────────────────────────────────────────────────────
STALE_TRADE_HOURS      = 2      # Exit if position stagnates after this long
STALE_TRADE_MIN_PNL    = -0.05  # … and P&L is between this …
STALE_TRADE_MAX_PNL    = 0.10   # … and this (going nowhere)

# ─── Technical Exit Signals ───────────────────────────────────────────────────
EMA_FAST_PERIOD        = 9
EMA_SLOW_PERIOD        = 21

# ─── Re-entry Cooldown ───────────────────────────────────────────────────────
REENTRY_COOLDOWN_MIN   = 30     # Minutes to wait before re-entering same symbol

# ─── Monitoring ───────────────────────────────────────────────────────────────
MONITOR_INTERVAL       = 30     # seconds between checks
EMERGENCY_TIMEOUT      = 5      # seconds to wait for limit fill before market

# ─── MongoDB ──────────────────────────────────────────────────────────────────
mongo_client       = MongoClient("mongodb://localhost:27017/")
db                 = mongo_client["breakout_db"]
trades_collection  = db["trades_v2"]
cooldown_collection = db["cooldowns"]


# ══════════════════════════════════════════════════════════════════════════════
# LOGGING
# ══════════════════════════════════════════════════════════════════════════════

class _Utf8SafeStreamHandler(logging.StreamHandler):
    def emit(self, record):
        try:
            super().emit(record)
        except UnicodeEncodeError:
            record.msg = str(record.msg).encode("ascii", errors="replace").decode("ascii")
            record.args = ()
            try:
                super().emit(record)
            except Exception:
                self.handleError(record)

    def _try_utf8(self):
        try:
            if hasattr(self.stream, "reconfigure"):
                self.stream.reconfigure(encoding="utf-8", errors="replace")
        except Exception:
            pass


def _make_logger() -> logging.Logger:
    fmt = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
    sh  = _Utf8SafeStreamHandler(sys.stdout)
    sh._try_utf8()
    sh.setFormatter(fmt)
    fh  = logging.FileHandler("sell_bot.log", encoding="utf-8")
    fh.setFormatter(fmt)
    logger = logging.getLogger("sell_bot")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    logger.addHandler(sh)
    logger.addHandler(fh)
    logger.propagate = False
    return logger

log = _make_logger()


# ══════════════════════════════════════════════════════════════════════════════
# IBKR CLIENT
# ══════════════════════════════════════════════════════════════════════════════

class IBKRSellClient:
    def __init__(self):
        util.startLoop()
        self.ib = IB()

    def connect(self):
        self.ib.connect(IBKR_HOST, IBKR_PORT, clientId=IBKR_CLIENT_ID)
        log.info(f"IBKR connected | accounts: {self.ib.wrapper.accounts}")

    def disconnect(self):
        self.ib.disconnect()

    # ── Price helpers ─────────────────────────────────────────────────────────

    def get_last_price(self, symbol: str) -> Optional[float]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "106", False, False)
        self.ib.sleep(3)
        self.ib.cancelMktData(contract)

        for label, val in [("last", ticker.last), ("ask", ticker.ask),
                           ("bid", ticker.bid), ("close", ticker.close)]:
            if val and float(val) > 0:
                log.debug(f"{symbol}: price source='{label}' ${float(val):.4f}")
                return float(val)

        log.warning(f"{symbol}: no price available")
        return None

    def get_ticker(self, symbol: str) -> Ticker:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "", False, False)
        self.ib.sleep(2)
        return ticker

    # ── Historical bars ───────────────────────────────────────────────────────

    def get_bars(self, symbol: str, n: int = 70) -> Optional[pd.DataFrame]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)

        for what_to_show in ("TRADES", "MIDPOINT"):
            raw = self.ib.reqHistoricalData(
                contract,
                endDateTime="",
                durationStr="10 D",
                barSizeSetting="5 mins",
                whatToShow=what_to_show,
                useRTH=False,
                keepUpToDate=False,
            )
            if raw:
                df = pd.DataFrame([
                    {"open": b.open, "high": b.high, "low": b.low,
                     "close": b.close, "volume": getattr(b, "volume", 0)}
                    for b in raw
                ])
                return df.tail(n).reset_index(drop=True)

        log.warning(f"{symbol}: no bars returned")
        return None

    # ── Technical indicators ──────────────────────────────────────────────────

    def compute_exit_signals(self, symbol: str) -> dict:
        """
        Compute PSAR, EMA 9, EMA 21 for exit decisions.
        Returns dict with signal flags or empty dict on failure.
        """
        df = self.get_bars(symbol, n=70)
        if df is None or len(df) < 25:
            log.warning(f"{symbol}: not enough bars for exit signals")
            return {}

        # Parabolic SAR
        psar_vals = self._compute_psar(df["high"].values, df["low"].values,
                                       df["close"].values)

        # EMA 9 / 21
        ema_fast = df["close"].ewm(span=EMA_FAST_PERIOD, adjust=False).mean()
        ema_slow = df["close"].ewm(span=EMA_SLOW_PERIOD, adjust=False).mean()

        price     = float(df["close"].iloc[-1])
        psar_now  = float(psar_vals[-1])
        ema9_now  = float(ema_fast.iloc[-1])
        ema21_now = float(ema_slow.iloc[-1])

        # Previous bar for crossover detection
        ema9_prev  = float(ema_fast.iloc[-2])
        ema21_prev = float(ema_slow.iloc[-2])

        psar_bearish       = psar_now > price       # SAR above price = downtrend
        ema_death_cross    = (ema9_prev >= ema21_prev) and (ema9_now < ema21_now)
        ema_bearish        = ema9_now < ema21_now
        price_below_ema9   = price < ema9_now
        price_below_ema21  = price < ema21_now

        signals = {
            "price":              price,
            "psar":               psar_now,
            "ema_9":              ema9_now,
            "ema_21":             ema21_now,
            "psar_bearish":       psar_bearish,
            "ema_death_cross":    ema_death_cross,
            "ema_bearish":        ema_bearish,
            "price_below_ema9":   price_below_ema9,
            "price_below_ema21":  price_below_ema21,
        }

        log.info(
            f"{symbol} signals: PSAR={psar_now:.4f}({'BEAR' if psar_bearish else 'BULL'}) "
            f"EMA9={ema9_now:.4f} EMA21={ema21_now:.4f} "
            f"cross={'YES' if ema_death_cross else 'no'} "
            f"below9={'YES' if price_below_ema9 else 'no'} "
            f"below21={'YES' if price_below_ema21 else 'no'}"
        )
        return signals

    @staticmethod
    def _compute_psar(highs, lows, closes, iaf=0.02, max_af=0.2) -> np.ndarray:
        n    = len(closes)
        psar = closes.copy().astype(float)
        bull = True
        af   = iaf
        hp   = float(highs[0])
        lp   = float(lows[0])

        for i in range(2, n):
            if bull:
                psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
                psar[i] = min(psar[i], lows[i - 1], lows[i - 2])
                if lows[i] < psar[i]:
                    bull    = False
                    psar[i] = hp
                    lp      = lows[i]
                    af      = iaf
                else:
                    if highs[i] > hp:
                        hp = highs[i]
                        af = min(af + iaf, max_af)
            else:
                psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
                psar[i] = max(psar[i], highs[i - 1], highs[i - 2])
                if highs[i] > psar[i]:
                    bull    = True
                    psar[i] = lp
                    hp      = highs[i]
                    af      = iaf
                else:
                    if lows[i] < lp:
                        lp = lows[i]
                        af = min(af + iaf, max_af)
        return psar

    # ── Order execution ───────────────────────────────────────────────────────

    def get_avg_fill_price_from_broker(self, symbol: str, order_id: int) -> Optional[float]:
        for trade in self.ib.trades():
            if (trade.contract.symbol == symbol
                    and trade.order.orderId == order_id
                    and trade.orderStatus.avgFillPrice > 0):
                return float(trade.orderStatus.avgFillPrice)

        fills   = self.ib.fills()
        matched = [f for f in fills
                   if f.contract.symbol == symbol and f.execution.orderId == order_id]
        if matched:
            total_qty  = sum(f.execution.shares for f in matched)
            total_cost = sum(f.execution.shares * f.execution.price for f in matched)
            return total_cost / total_qty

        return None

    def place_limit_sell(self, symbol: str, price: float, qty: int,
                         emergency: bool = False) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)

        if emergency:
            price = price * 0.99  # 1% below for faster fill

        order = LimitOrder("SELL", qty, round(price, 2))
        order.outsideRth = True
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)

        log.info(f"SELL LIMIT {symbol} x{qty} @ ${price:.2f} "
                 f"orderId={trade.order.orderId} emergency={emergency}")
        return trade

    def place_market_sell(self, symbol: str, qty: int) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        order = MarketOrder("SELL", qty)
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL MARKET {symbol} x{qty} orderId={trade.order.orderId}")
        return trade

    def get_sell_fill_price(self, symbol: str, sell_order_id: int,
                            fallback_price: float) -> float:
        self.ib.sleep(3)
        avg = self.get_avg_fill_price_from_broker(symbol, sell_order_id)
        if avg:
            return avg
        log.warning(f"{symbol}: sell fill not confirmed, using fallback ${fallback_price:.4f}")
        return fallback_price


# ══════════════════════════════════════════════════════════════════════════════
# MONGODB HELPERS
# ══════════════════════════════════════════════════════════════════════════════

def get_open_trades() -> list:
    return list(trades_collection.find({"status": "open"}))


def get_effective_entry_price(trade: dict, ibkr: IBKRSellClient) -> float:
    """Priority: avg_fill_price (DB) → broker lookup → entry_price (DB)."""
    if trade.get("avg_fill_price"):
        return float(trade["avg_fill_price"])

    order_id = trade.get("order_id")
    symbol   = trade.get("instrument") or trade.get("symbol")

    if order_id:
        broker_avg = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if broker_avg:
            trades_collection.update_one(
                {"_id": trade["_id"]},
                {"$set": {"avg_fill_price": broker_avg, "entry_price": broker_avg}},
            )
            return broker_avg

    return float(trade["entry_price"])


def update_trade_field(trade_id, updates: dict):
    updates["updated_at"] = datetime.now(timezone.utc)
    trades_collection.update_one({"_id": trade_id}, {"$set": updates})


def close_trade(trade: dict, exit_price: float, reason: str, qty_sold: int = None):
    """Close (or partially close) a trade in MongoDB."""
    symbol      = trade.get("instrument") or trade.get("symbol")
    entry_price = float(trade.get("avg_fill_price") or trade["entry_price"])
    total_qty   = trade.get("quantity") or trade.get("qty")
    pnl_pct     = (exit_price - entry_price) / entry_price

    if qty_sold is None:
        qty_sold = total_qty

    realized_pnl = (exit_price - entry_price) * qty_sold

    if qty_sold >= total_qty:
        # Full close
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "status":           "closed",
                "exit_price":       exit_price,
                "exit_timestamp":   datetime.now(timezone.utc),
                "reason":           reason,
                "pnl_pct":          round(pnl_pct * 100, 2),
                "realized_pnl":     realized_pnl,
                "updated_at":       datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"CLOSED {symbol} | entry=${entry_price:.4f} exit=${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | reason={reason}"
        )
        set_cooldown(symbol, reason)
    else:
        # Partial close — reduce quantity, record partial exit
        remaining = total_qty - qty_sold
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "quantity":              remaining,
                "partial_exit_price":    exit_price,
                "partial_exit_qty":      qty_sold,
                "partial_exit_time":     datetime.now(timezone.utc),
                "partial_exit_reason":   reason,
                "partial_realized_pnl":  realized_pnl,
                "phase":                 "runner",
                "updated_at":            datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"PARTIAL CLOSE {symbol} | sold {qty_sold}/{total_qty} @ ${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | "
            f"remaining={remaining} shares → runner mode"
        )


# ══════════════════════════════════════════════════════════════════════════════
# POSITION CONSOLIDATION
# ══════════════════════════════════════════════════════════════════════════════

def consolidate_duplicate_positions(open_trades: list) -> list:
    """
    If the buy bot opened multiple trades for the same symbol,
    merge them into a single trade record in MongoDB so the exit
    logic operates on the full position size.

    Returns the deduplicated list of trades.
    """
    by_symbol = defaultdict(list)
    for t in open_trades:
        sym = t.get("instrument") or t.get("symbol")
        if sym:
            by_symbol[sym].append(t)

    consolidated = []
    for sym, trades in by_symbol.items():
        if len(trades) == 1:
            consolidated.append(trades[0])
            continue

        log.warning(
            f"{sym}: CONSOLIDATING {len(trades)} duplicate open trades into 1"
        )

        total_qty   = 0
        total_cost  = 0.0
        earliest_ts = None
        highest     = 0.0
        keep_trade  = None

        for t in trades:
            qty   = t.get("quantity") or t.get("qty") or 0
            entry = float(t.get("avg_fill_price") or t.get("entry_price") or 0)
            total_qty  += qty
            total_cost += qty * entry

            ts = t.get("entry_timestamp")
            if ts and (earliest_ts is None or ts < earliest_ts):
                earliest_ts = ts

            h = t.get("highest_price", entry)
            if h > highest:
                highest = h

            if keep_trade is None:
                keep_trade = t
            else:
                trades_collection.update_one(
                    {"_id": t["_id"]},
                    {"$set": {
                        "status":     "merged",
                        "merged_into": keep_trade["_id"],
                        "updated_at": datetime.now(timezone.utc),
                    }},
                )
                log.info(f"{sym}: merged trade {t['_id']} into {keep_trade['_id']}")

        avg_entry = total_cost / total_qty if total_qty > 0 else 0
        updates = {
            "quantity":           total_qty,
            "avg_fill_price":     avg_entry,
            "entry_price":        avg_entry,
            "highest_price":      highest,
            "consolidated":       True,
            "consolidated_count": len(trades),
        }
        if earliest_ts:
            updates["entry_timestamp"] = earliest_ts

        update_trade_field(keep_trade["_id"], updates)

        keep_trade["quantity"]       = total_qty
        keep_trade["avg_fill_price"] = avg_entry
        keep_trade["entry_price"]    = avg_entry
        keep_trade["highest_price"]  = highest

        log.info(
            f"{sym}: CONSOLIDATED → {total_qty} shares @ avg ${avg_entry:.4f} "
            f"(was {len(trades)} separate trades)"
        )
        consolidated.append(keep_trade)

    return consolidated


# ══════════════════════════════════════════════════════════════════════════════
# RE-ENTRY COOLDOWN
# ══════════════════════════════════════════════════════════════════════════════

def set_cooldown(symbol: str, reason: str):
    expires_at = datetime.now(timezone.utc) + timedelta(minutes=REENTRY_COOLDOWN_MIN)
    cooldown_collection.update_one(
        {"symbol": symbol},
        {"$set": {
            "symbol":       symbol,
            "reason":       reason,
            "closed_at":    datetime.now(timezone.utc),
            "expires_at":   expires_at,
            "cooldown_min": REENTRY_COOLDOWN_MIN,
        }},
        upsert=True,
    )
    log.info(
        f"{symbol}: COOLDOWN SET — no re-entry for {REENTRY_COOLDOWN_MIN} min "
        f"(until {expires_at.strftime('%H:%M:%S')} UTC) | close reason: {reason}"
    )


def is_in_cooldown(symbol: str) -> bool:
    record = cooldown_collection.find_one({"symbol": symbol})
    if not record:
        return False

    expires_at = record.get("expires_at")
    if not expires_at:
        return False

    now = datetime.now(timezone.utc)
    if expires_at.tzinfo is None:
        in_cooldown = datetime.now() < expires_at
    else:
        in_cooldown = now < expires_at

    if in_cooldown:
        remaining = (expires_at - now).total_seconds() / 60
        log.info(f"{symbol}: IN COOLDOWN — {remaining:.1f} min remaining "
                 f"(closed for: {record.get('reason', 'unknown')})")
    else:
        cooldown_collection.delete_one({"symbol": symbol})

    return in_cooldown


def clear_cooldown(symbol: str):
    cooldown_collection.delete_one({"symbol": symbol})
    log.info(f"{symbol}: cooldown manually cleared")


# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def get_trailing_stop_pct(pnl_pct: float) -> float:
    for threshold, trail in TRAILING_TIERS:
        if pnl_pct >= threshold:
            return trail
    return DEFAULT_TRAILING_PCT


def compute_trailing_stop(entry_price: float, highest_price: float,
                          current_pnl_pct: float) -> float:
    trail_pct  = get_trailing_stop_pct(current_pnl_pct)
    trail_stop = highest_price * (1 - trail_pct)
    hard_stop  = entry_price * (1 - HARD_STOP_PCT)
    return max(trail_stop, hard_stop)


def check_flash_crash(symbol: str, current_price: float, trade: dict) -> Optional[str]:
    """Detect sudden price drops within a single monitoring interval."""
    last_price = trade.get("last_price")

    update_trade_field(trade["_id"], {
        "last_price":      current_price,
        "last_price_time": datetime.now(timezone.utc),
    })

    if last_price and last_price > 0:
        drop_pct = (current_price - last_price) / last_price
        if drop_pct <= -FLASH_CRASH_PCT:
            log.warning(f"{symbol}: FLASH CRASH {drop_pct * 100:.2f}% in {MONITOR_INTERVAL}s")
            return f"flash_crash_{abs(drop_pct) * 100:.1f}pct"

    return None


def check_stale_trade(trade: dict, pnl_pct: float) -> bool:
    entry_time = trade.get("entry_timestamp")
    if not entry_time:
        return False

    if entry_time.tzinfo is None:
        hours_held = (datetime.now() - entry_time).total_seconds() / 3600
    else:
        hours_held = (datetime.now(timezone.utc) - entry_time).total_seconds() / 3600

    if hours_held >= STALE_TRADE_HOURS:
        if STALE_TRADE_MIN_PNL <= pnl_pct <= STALE_TRADE_MAX_PNL:
            log.info(
                f"{trade.get('instrument') or trade.get('symbol')}: "
                f"stale trade — {hours_held:.1f}h held, pnl={pnl_pct * 100:+.2f}% "
                f"(flat zone {STALE_TRADE_MIN_PNL * 100}% to {STALE_TRADE_MAX_PNL * 100}%)"
            )
            return True
    return False


# ══════════════════════════════════════════════════════════════════════════════
# EMERGENCY EXIT
# ══════════════════════════════════════════════════════════════════════════════

def emergency_exit(ibkr: IBKRSellClient, symbol: str, qty: int,
                   reason: str) -> tuple[float, str]:
    """Aggressive limit → market fallback for urgent exits."""
    log.warning(f"{symbol}: EMERGENCY EXIT — {reason}")

    ticker      = ibkr.get_ticker(symbol)
    current_bid = ticker.bid or ticker.last or ticker.close

    if not current_bid:
        log.error(f"{symbol}: no price for emergency exit!")
        return 0.0, "exit_failed_no_price"

    trade    = ibkr.place_limit_sell(symbol, current_bid, qty, emergency=True)
    order_id = trade.order.orderId

    for _ in range(EMERGENCY_TIMEOUT):
        ibkr.ib.sleep(1)
        fill = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if fill:
            log.info(f"{symbol}: emergency limit filled @ ${fill:.4f}")
            return fill, reason

    log.warning(f"{symbol}: limit not filled in {EMERGENCY_TIMEOUT}s → MARKET")
    try:
        ibkr.ib.cancelOrder(trade.order)
    except Exception:
        pass

    market_trade = ibkr.place_market_sell(symbol, qty)
    ibkr.ib.sleep(2)
    fill = ibkr.get_avg_fill_price_from_broker(symbol, market_trade.order.orderId)
    if fill:
        return fill, f"{reason}_market"

    return current_bid * 0.98, f"{reason}_estimated"


# ══════════════════════════════════════════════════════════════════════════════
# EXIT DECISION ENGINE
# ══════════════════════════════════════════════════════════════════════════════

@dataclass
class ExitDecision:
    action: str            # "hold", "partial_sell", "full_sell", "emergency_sell"
    reason: str
    qty_to_sell: int = 0


def evaluate_position(trade: dict, current_price: float, entry_price: float,
                      ibkr: IBKRSellClient) -> ExitDecision:
    """
    Master exit logic — evaluates all conditions in priority order.

    v2.3 CHANGES:
    - Liquidity crisis check REMOVED entirely
    - Trailing stop confirmation requires PSAR bearish ONLY
    - When profitable, only PSAR-based signals trigger exits
    """
    symbol    = trade.get("instrument") or trade.get("symbol")
    total_qty = trade.get("quantity") or trade.get("qty")
    highest   = trade.get("highest_price", entry_price)
    phase     = trade.get("phase", "initial")
    pnl_pct   = (current_price - entry_price) / entry_price

    # Track new high
    if current_price > highest:
        highest = current_price
        update_trade_field(trade["_id"], {"highest_price": highest})

    drawdown_from_high = (current_price - highest) / highest if highest > 0 else 0

    log.info(
        f"{symbol}: phase={phase} | entry=${entry_price:.4f} now=${current_price:.4f} "
        f"pnl={pnl_pct * 100:+.2f}% | high=${highest:.4f} dd={drawdown_from_high * 100:.2f}% "
        f"qty={total_qty}"
    )

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 1 — Hard stop (always active, loss protection)
    # ══════════════════════════════════════════════════════════════════════
    if pnl_pct <= -HARD_STOP_PCT:
        return ExitDecision("emergency_sell", "hard_stop_10pct", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 2 — Flash crash (always active)
    # ══════════════════════════════════════════════════════════════════════
    flash = check_flash_crash(symbol, current_price, trade)
    if flash:
        return ExitDecision("emergency_sell", flash, total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 3 — Partial profit (only in "initial" phase)
    # ══════════════════════════════════════════════════════════════════════
    if phase == "initial" and pnl_pct >= PARTIAL_PROFIT_PCT:
        sell_qty = max(1, int(total_qty * PARTIAL_SELL_FRACTION))
        if sell_qty >= total_qty:
            return ExitDecision("full_sell", f"profit_target_{pnl_pct * 100:.1f}pct", total_qty)
        return ExitDecision("partial_sell", f"partial_profit_{pnl_pct * 100:.1f}pct", sell_qty)

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 4 — Trailing stop (PSAR-confirmed ONLY)
    #   The trailing stop level is computed from tiers, but it ONLY
    #   triggers if PSAR is bearish. This keeps you in strong uptrends
    #   that pull back but maintain bullish PSAR structure.
    # ══════════════════════════════════════════════════════════════════════
    stop_level = compute_trailing_stop(entry_price, highest, pnl_pct)

    if stop_level > entry_price * (1 - HARD_STOP_PCT):
        if current_price <= stop_level:
            signals = ibkr.compute_exit_signals(symbol)
            psar_confirmed = False

            if signals:
                psar_bearish = signals.get("psar_bearish", False)

                if psar_bearish:
                    psar_confirmed = True
                    log.info(
                        f"{symbol}: trailing stop CONFIRMED — PSAR bearish "
                        f"(PSAR={signals.get('psar', 0):.4f} > price={current_price:.4f})"
                    )
                else:
                    log.info(
                        f"{symbol}: trailing stop level breached (${stop_level:.4f}) "
                        f"but PSAR still bullish — HOLDING through pullback"
                    )
            else:
                # No signal data (bars failed) — trigger stop as safety fallback
                psar_confirmed = True
                log.warning(
                    f"{symbol}: trailing stop breached & no signal data — "
                    f"triggering stop as safety fallback"
                )

            if psar_confirmed:
                trail_pct = get_trailing_stop_pct(pnl_pct)
                return ExitDecision(
                    "full_sell",
                    f"trailing_stop_{trail_pct * 100:.0f}pct_psar_confirmed",
                    total_qty,
                )

    update_trade_field(trade["_id"], {"trailing_stop": stop_level})

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 5 — Technical exit signals (runner phase)
    #   PSAR bearish + price below EMA 9 → exit
    #   EMA 9 death-crosses EMA 21       → exit
    # ══════════════════════════════════════════════════════════════════════
    if phase == "runner":
        signals = ibkr.compute_exit_signals(symbol)
        if signals:
            if signals.get("psar_bearish") and signals.get("price_below_ema9"):
                return ExitDecision(
                    "full_sell",
                    "psar_bearish_below_ema9",
                    total_qty,
                )
            if signals.get("ema_death_cross"):
                return ExitDecision(
                    "full_sell",
                    "ema_9_21_death_cross",
                    total_qty,
                )

    # ══════════════════════════════════════════════════════════════════════
    # PRIORITY 6 — Stale trade (going nowhere for too long)
    # ══════════════════════════════════════════════════════════════════════
    if check_stale_trade(trade, pnl_pct):
        return ExitDecision("full_sell", "stale_trade_timeout", total_qty)

    # ══════════════════════════════════════════════════════════════════════
    # DEFAULT — Hold
    # ══════════════════════════════════════════════════════════════════════
    trail_pct = get_trailing_stop_pct(pnl_pct)
    log.info(
        f"{symbol}: HOLD | trail={trail_pct * 100:.0f}% "
        f"stop=${stop_level:.4f} | phase={phase}"
    )
    return ExitDecision("hold", "holding", 0)


# ══════════════════════════════════════════════════════════════════════════════
# MAIN MONITOR LOOP
# ══════════════════════════════════════════════════════════════════════════════

def monitor_positions(ibkr: IBKRSellClient):
    log.info("=" * 60)
    log.info("SELL BOT v2.3 — Smart Position Manager")
    log.info("  Liquidity crisis: DISABLED (removed)")
    log.info("  Exit confirmation: PSAR bearish only")
    log.info("  Duplicate positions: auto-consolidated")
    log.info(f"Hard Stop: {HARD_STOP_PCT * 100}% | "
             f"Partial: {PARTIAL_PROFIT_PCT * 100}% ({PARTIAL_SELL_FRACTION * 100}% of qty) | "
             f"Flash: {FLASH_CRASH_PCT * 100}%")
    log.info(f"Trailing tiers: {[(f'+{t*100:.0f}%', f'{p*100:.0f}%') for t, p in TRAILING_TIERS]}")
    log.info(f"Trail confirmation: PSAR bearish ONLY")
    log.info(f"Re-entry cooldown: {REENTRY_COOLDOWN_MIN} min")
    log.info(f"Stale exit: >{STALE_TRADE_HOURS}h if PnL in "
             f"[{STALE_TRADE_MIN_PNL * 100}%, {STALE_TRADE_MAX_PNL * 100}%]")
    log.info("=" * 60)

    while True:
        try:
            open_trades = get_open_trades()

            # ── Consolidate duplicate positions before processing ─────────
            open_trades = consolidate_duplicate_positions(open_trades)

            log.info(f"--- Checking {len(open_trades)} open position(s) ---")

            for trade in open_trades:
                symbol    = trade.get("instrument") or trade.get("symbol")
                total_qty = trade.get("quantity") or trade.get("qty")

                if not symbol or not total_qty:
                    log.warning(f"Skipping trade {trade['_id']}: missing symbol or qty")
                    continue

                entry_price   = get_effective_entry_price(trade, ibkr)
                current_price = ibkr.get_last_price(symbol)
                if not current_price:
                    log.warning(f"{symbol}: no current price, skipping")
                    continue

                decision = evaluate_position(trade, current_price, entry_price, ibkr)

                if decision.action == "hold":
                    continue

                # ── Execute the decision ──────────────────────────────────

                if decision.action == "emergency_sell":
                    exit_price, final_reason = emergency_exit(
                        ibkr, symbol, decision.qty_to_sell, decision.reason
                    )
                    close_trade(trade, exit_price, final_reason, decision.qty_to_sell)

                elif decision.action == "partial_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                               current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

                elif decision.action == "full_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                               current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

        except Exception as e:
            log.error(f"Monitor error: {e}", exc_info=True)

        time.sleep(MONITOR_INTERVAL)


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY POINT
# ══════════════════════════════════════════════════════════════════════════════

def main():
    log.info("=== Sell Bot v2.3 Starting ===")
    ibkr = IBKRSellClient()

    try:
        ibkr.connect()
        monitor_positions(ibkr)
    except KeyboardInterrupt:
        log.info("Sell bot stopped by user.")
    except Exception as e:
        log.error(f"Fatal error: {e}", exc_info=True)
    finally:
        ibkr.disconnect()
        log.info("IBKR disconnected.")


if __name__ == "__main__":
    main()

# %%
"""
Sell Bot v3.0 — Smart Position Manager
═══════════════════════════════════════════════════════════════════════════════
Monitors open positions via IBKR + MongoDB and exits them intelligently
using PSAR-confirmed trailing stops, tiered profit-taking, and emergency exits.

CHANGES from sell_bot_v2.3:
────────────────────────────
1. ENTRY-TYPE AWARE PROFIT SCHEDULE (Kimi proposal — PositionManager)
   - "standard"  (SMX/AIXI) : partial at +50%, runner with tiered trail
   - "momentum"  (FCUV)     : partial at +30%, partial at +60%, small runner
   - "pullback"  (KPRX)     : partial at +25%, partial at +50%, small runner

2. MULTI-PARTIAL TRACKING
   - partial_1_taken / partial_2_taken flags per trade doc
   - Remaining quantity correctly maintained across partial exits

3. RUNNER PROTECTION IMPROVEMENTS
   - Momentum runner: tighter trailing (10% tiers max)
   - Standard runner: existing PSAR-confirmed tiers

4. PRESERVED FROM v2.3:
   - Hard stop: -10% from entry
   - Flash crash: -5% drop in one interval → emergency exit
   - Tiered trailing: 8%–15% from high, PSAR-confirmed
   - Stale trade exit: >2h, PnL between -5% and +10%
   - Duplicate position consolidation
   - Re-entry cooldown (shared with buy bot)
   - Liquidity crisis check: REMOVED (was causing false exits)

EXIT STRATEGY SUMMARY:
──────────────────────
Phase 1 — PROTECTION (always active):
  Hard stop -10% | Flash crash -5%/interval

Phase 2 — PARTIAL PROFIT (by entry type):
  standard : +50% → sell 50%
  momentum : +30% → sell 33%, then +60% → sell 50% of remaining
  pullback : +25% → sell 40%, then +50% → sell 33% of remaining

Phase 3 — RUNNER (remaining shares):
  Trailing stop tiers (PSAR-confirmed):
    standard/pullback: +50-75→15%, +75-100→12%, +100-150→10%, +150+→8%
    momentum:          tighter — +50-75→12%, +75-100→10%, +100+→8%
  PSAR bearish + price below EMA9 → exit runner
  EMA9 death-crosses EMA21 → exit runner

Phase 4 — TIME DECAY:
  Position in [-5%, +10%] after 2h → exit
"""

import logging
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import random
from typing import Optional
from dataclasses import dataclass
from collections import defaultdict

from pymongo import MongoClient
from ib_insync import *

import warnings
warnings.filterwarnings("ignore")


# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ─── IBKR ────────────────────────────────────────────────────────────────────
IBKR_HOST      = "127.0.0.1"
IBKR_PORT      = 7497
IBKR_CLIENT_ID = random.randint(3000, 3999)   # Different range from scanner/buy bots

# ─── Emergency / Hard Protection ─────────────────────────────────────────────
HARD_STOP_PCT    = 0.10   # -10% from entry: always exit
FLASH_CRASH_PCT  = 0.05   # -5% in one 30s interval: emergency

# ─── Profit Schedules by Entry Type (Kimi proposal) ──────────────────────────
PROFIT_SCHEDULE = {
    "standard": {
        # SMX/AIXI: let it run, single partial at 50%
        "partial_1": {"threshold": 0.50, "fraction": 0.50},
        "partial_2": None,
        "runner_trail_tiers": [
            (1.50, 0.08),   # +150%+  → trail 8%
            (1.00, 0.10),   # +100%+  → trail 10%
            (0.75, 0.12),   # +75%+   → trail 12%
            (0.50, 0.15),   # +50%+   → trail 15%
        ],
    },
    "momentum": {
        # FCUV: fast movers — take quick partials
        "partial_1": {"threshold": 0.30, "fraction": 0.33},
        "partial_2": {"threshold": 0.60, "fraction": 0.50},
        "runner_trail_tiers": [
            (1.00, 0.08),   # Tighter: +100%+ → 8%
            (0.75, 0.10),   # +75%+   → 10%
            (0.50, 0.12),   # +50%+   → 12%
        ],
    },
    "pullback": {
        # KPRX: conservative recovery play — quick initial profits
        "partial_1": {"threshold": 0.25, "fraction": 0.40},
        "partial_2": {"threshold": 0.50, "fraction": 0.33},
        "runner_trail_tiers": [
            (1.50, 0.08),
            (1.00, 0.10),
            (0.75, 0.12),
            (0.50, 0.15),
        ],
    },
}
DEFAULT_SCHEDULE    = PROFIT_SCHEDULE["standard"]
DEFAULT_TRAILING_PCT = 0.20    # Before first partial if somehow needed

# ─── Time Decay ───────────────────────────────────────────────────────────────
STALE_TRADE_HOURS   = 2
STALE_TRADE_MIN_PNL = -0.05
STALE_TRADE_MAX_PNL = 0.10

# ─── Technical Exit Signals ───────────────────────────────────────────────────
EMA_FAST_PERIOD = 9
EMA_SLOW_PERIOD = 21

# ─── Re-entry Cooldown ────────────────────────────────────────────────────────
REENTRY_COOLDOWN_MIN = 30

# ─── Monitoring ───────────────────────────────────────────────────────────────
MONITOR_INTERVAL  = 30   # seconds between position checks
EMERGENCY_TIMEOUT = 5    # seconds to wait for limit fill before market

# ─── MongoDB ──────────────────────────────────────────────────────────────────
MONGO_URI           = "mongodb://localhost:27017/"
DB_NAME             = "breakout_db"
TRADES_COL          = "trades_v2"
COOLDOWN_COL        = "cooldowns"


# ══════════════════════════════════════════════════════════════════════════════
# LOGGING
# ══════════════════════════════════════════════════════════════════════════════

class _Utf8SafeStreamHandler(logging.StreamHandler):
    def emit(self, record):
        try:
            super().emit(record)
        except UnicodeEncodeError:
            record.msg  = str(record.msg).encode("ascii", errors="replace").decode("ascii")
            record.args = ()
            try:
                super().emit(record)
            except Exception:
                self.handleError(record)

    def _try_utf8(self):
        try:
            if hasattr(self.stream, "reconfigure"):
                self.stream.reconfigure(encoding="utf-8", errors="replace")
        except Exception:
            pass


def _make_logger() -> logging.Logger:
    fmt = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
    sh  = _Utf8SafeStreamHandler(sys.stdout)
    sh._try_utf8()
    sh.setFormatter(fmt)
    fh  = logging.FileHandler("sell_bot.log", encoding="utf-8")
    fh.setFormatter(fmt)
    logger = logging.getLogger("sell_bot")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    logger.addHandler(sh)
    logger.addHandler(fh)
    logger.propagate = False
    return logger

log = _make_logger()


# ══════════════════════════════════════════════════════════════════════════════
# IBKR CLIENT
# ══════════════════════════════════════════════════════════════════════════════

class IBKRSellClient:
    def __init__(self):
        util.startLoop()
        self.ib = IB()

    def connect(self):
        self.ib.connect(IBKR_HOST, IBKR_PORT, clientId=IBKR_CLIENT_ID)
        log.info(f"IBKR connected | accounts: {self.ib.wrapper.accounts}")

    def disconnect(self):
        self.ib.disconnect()

    # ── Price helpers ─────────────────────────────────────────────────────────

    def get_last_price(self, symbol: str) -> Optional[float]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "106", False, False)
        self.ib.sleep(3)
        self.ib.cancelMktData(contract)
        for label, val in [("last", ticker.last), ("ask", ticker.ask),
                           ("bid", ticker.bid), ("close", ticker.close)]:
            if val and float(val) > 0:
                log.debug(f"{symbol}: price source='{label}' ${float(val):.4f}")
                return float(val)
        log.warning(f"{symbol}: no price available")
        return None

    def get_ticker(self, symbol: str) -> Ticker:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "", False, False)
        self.ib.sleep(2)
        return ticker

    # ── Historical bars ───────────────────────────────────────────────────────

    def get_bars(self, symbol: str, n: int = 70) -> Optional[pd.DataFrame]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        for what_to_show in ("TRADES", "MIDPOINT"):
            raw = self.ib.reqHistoricalData(
                contract,
                endDateTime="",
                durationStr="10 D",
                barSizeSetting="5 mins",
                whatToShow=what_to_show,
                useRTH=False,
                keepUpToDate=False,
            )
            if raw:
                df = pd.DataFrame([
                    {"open": b.open, "high": b.high, "low": b.low,
                     "close": b.close, "volume": getattr(b, "volume", 0)}
                    for b in raw
                ])
                return df.tail(n).reset_index(drop=True)
        log.warning(f"{symbol}: no bars returned")
        return None

    # ── Technical exit signals ────────────────────────────────────────────────

    def compute_exit_signals(self, symbol: str) -> dict:
        df = self.get_bars(symbol, n=70)
        if df is None or len(df) < 25:
            log.warning(f"{symbol}: not enough bars for exit signals")
            return {}

        psar_vals = self._compute_psar(df["high"].values, df["low"].values,
                                       df["close"].values)
        ema_fast = df["close"].ewm(span=EMA_FAST_PERIOD, adjust=False).mean()
        ema_slow = df["close"].ewm(span=EMA_SLOW_PERIOD, adjust=False).mean()

        price     = float(df["close"].iloc[-1])
        psar_now  = float(psar_vals[-1])
        ema9_now  = float(ema_fast.iloc[-1])
        ema21_now = float(ema_slow.iloc[-1])
        ema9_prev  = float(ema_fast.iloc[-2])
        ema21_prev = float(ema_slow.iloc[-2])

        psar_bearish     = psar_now > price
        ema_death_cross  = (ema9_prev >= ema21_prev) and (ema9_now < ema21_now)
        price_below_ema9 = price < ema9_now

        signals = {
            "price":             price,
            "psar":              psar_now,
            "ema_9":             ema9_now,
            "ema_21":            ema21_now,
            "psar_bearish":      psar_bearish,
            "ema_death_cross":   ema_death_cross,
            "price_below_ema9":  price_below_ema9,
        }

        log.info(
            f"{symbol} exit signals: PSAR={psar_now:.4f}({'BEAR' if psar_bearish else 'BULL'}) "
            f"EMA9={ema9_now:.4f} EMA21={ema21_now:.4f} "
            f"cross={'YES' if ema_death_cross else 'no'} "
            f"below9={'YES' if price_below_ema9 else 'no'}"
        )
        return signals

    @staticmethod
    def _compute_psar(highs, lows, closes, iaf=0.02, max_af=0.2) -> np.ndarray:
        n    = len(closes)
        psar = closes.copy().astype(float)
        bull = True
        af   = iaf
        hp   = float(highs[0])
        lp   = float(lows[0])

        for i in range(2, n):
            if bull:
                psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
                psar[i] = min(psar[i], lows[i - 1], lows[i - 2])
                if lows[i] < psar[i]:
                    bull = False; psar[i] = hp; lp = lows[i]; af = iaf
                else:
                    if highs[i] > hp:
                        hp = highs[i]; af = min(af + iaf, max_af)
            else:
                psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
                psar[i] = max(psar[i], highs[i - 1], highs[i - 2])
                if highs[i] > psar[i]:
                    bull = True; psar[i] = lp; hp = highs[i]; af = iaf
                else:
                    if lows[i] < lp:
                        lp = lows[i]; af = min(af + iaf, max_af)
        return psar

    # ── Order execution ───────────────────────────────────────────────────────

    def get_avg_fill_price_from_broker(self, symbol: str, order_id: int) -> Optional[float]:
        for trade in self.ib.trades():
            if (trade.contract.symbol == symbol
                    and trade.order.orderId == order_id
                    and trade.orderStatus.avgFillPrice > 0):
                return float(trade.orderStatus.avgFillPrice)

        fills   = self.ib.fills()
        matched = [f for f in fills
                   if f.contract.symbol == symbol and f.execution.orderId == order_id]
        if matched:
            total_qty  = sum(f.execution.shares for f in matched)
            total_cost = sum(f.execution.shares * f.execution.price for f in matched)
            return total_cost / total_qty

        return None

    def place_limit_sell(self, symbol: str, price: float, qty: int,
                         emergency: bool = False) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        if emergency:
            price = price * 0.99
        order = LimitOrder("SELL", qty, round(price, 2))
        order.outsideRth = True
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL LIMIT {symbol} x{qty} @ ${price:.2f} "
                 f"orderId={trade.order.orderId} emergency={emergency}")
        return trade

    def place_market_sell(self, symbol: str, qty: int) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        order = MarketOrder("SELL", qty)
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL MARKET {symbol} x{qty} orderId={trade.order.orderId}")
        return trade

    def get_sell_fill_price(self, symbol: str, sell_order_id: int,
                            fallback_price: float) -> float:
        self.ib.sleep(3)
        avg = self.get_avg_fill_price_from_broker(symbol, sell_order_id)
        if avg:
            return avg
        log.warning(f"{symbol}: sell fill not confirmed, using fallback ${fallback_price:.4f}")
        return fallback_price


# ══════════════════════════════════════════════════════════════════════════════
# MONGODB HELPERS
# ══════════════════════════════════════════════════════════════════════════════

mongo_client       = MongoClient(MONGO_URI)
db                 = mongo_client[DB_NAME]
trades_collection  = db[TRADES_COL]
cooldown_collection = db[COOLDOWN_COL]


def get_open_trades() -> list:
    return list(trades_collection.find({"status": "open"}))


def get_effective_entry_price(trade: dict, ibkr: IBKRSellClient) -> float:
    if trade.get("avg_fill_price"):
        return float(trade["avg_fill_price"])
    order_id = trade.get("order_id")
    symbol   = trade.get("instrument") or trade.get("symbol")
    if order_id:
        try:
            broker_avg = ibkr.get_avg_fill_price_from_broker(symbol, int(order_id))
        except (ValueError, TypeError):
            broker_avg = None
        if broker_avg:
            trades_collection.update_one(
                {"_id": trade["_id"]},
                {"$set": {"avg_fill_price": broker_avg, "entry_price": broker_avg}},
            )
            return broker_avg
    return float(trade["entry_price"])


def update_trade_field(trade_id, updates: dict):
    updates["updated_at"] = datetime.now(timezone.utc)
    trades_collection.update_one({"_id": trade_id}, {"$set": updates})


def get_profit_schedule(trade: dict) -> dict:
    """Return the correct profit schedule based on entry_type."""
    entry_type = trade.get("entry_type", "standard")
    return PROFIT_SCHEDULE.get(entry_type, DEFAULT_SCHEDULE)


def close_trade(trade: dict, exit_price: float, reason: str, qty_sold: int = None):
    symbol      = trade.get("instrument") or trade.get("symbol")
    entry_price = float(trade.get("avg_fill_price") or trade["entry_price"])
    total_qty   = trade.get("quantity") or trade.get("qty")
    pnl_pct     = (exit_price - entry_price) / (entry_price + 1e-9)

    if qty_sold is None:
        qty_sold = total_qty

    realized_pnl = (exit_price - entry_price) * qty_sold

    if qty_sold >= total_qty:
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "status":         "closed",
                "exit_price":     exit_price,
                "exit_timestamp": datetime.now(timezone.utc),
                "reason":         reason,
                "pnl_pct":        round(pnl_pct * 100, 2),
                "realized_pnl":   realized_pnl,
                "updated_at":     datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"CLOSED {symbol} | entry=${entry_price:.4f} exit=${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | reason={reason}"
        )
        set_cooldown(symbol, reason)
    else:
        remaining = total_qty - qty_sold
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "quantity":              remaining,
                "partial_exit_price":    exit_price,
                "partial_exit_qty":      qty_sold,
                "partial_exit_time":     datetime.now(timezone.utc),
                "partial_exit_reason":   reason,
                "partial_realized_pnl":  realized_pnl,
                "phase":                 "runner",
                "updated_at":            datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"PARTIAL CLOSE {symbol} | sold {qty_sold}/{total_qty} @ ${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | "
            f"remaining={remaining} shares → runner mode"
        )


# ══════════════════════════════════════════════════════════════════════════════
# POSITION CONSOLIDATION  (preserved from v2.3)
# ══════════════════════════════════════════════════════════════════════════════

def consolidate_duplicate_positions(open_trades: list) -> list:
    by_symbol = defaultdict(list)
    for t in open_trades:
        sym = t.get("instrument") or t.get("symbol")
        if sym:
            by_symbol[sym].append(t)

    consolidated = []
    for sym, trades in by_symbol.items():
        if len(trades) == 1:
            consolidated.append(trades[0])
            continue

        log.warning(f"{sym}: CONSOLIDATING {len(trades)} duplicate open trades into 1")

        total_qty  = 0
        total_cost = 0.0
        earliest_ts = None
        highest     = 0.0
        keep_trade  = None

        for t in trades:
            qty   = t.get("quantity") or t.get("qty") or 0
            entry = float(t.get("avg_fill_price") or t.get("entry_price") or 0)
            total_qty  += qty
            total_cost += qty * entry

            ts = t.get("entry_timestamp")
            if ts and (earliest_ts is None or ts < earliest_ts):
                earliest_ts = ts

            h = t.get("highest_price", entry)
            if h > highest:
                highest = h

            if keep_trade is None:
                keep_trade = t
            else:
                trades_collection.update_one(
                    {"_id": t["_id"]},
                    {"$set": {"status": "merged", "merged_into": keep_trade["_id"],
                              "updated_at": datetime.now(timezone.utc)}},
                )
                log.info(f"{sym}: merged trade {t['_id']} into {keep_trade['_id']}")

        avg_entry = total_cost / total_qty if total_qty > 0 else 0
        updates = {
            "quantity":           total_qty,
            "avg_fill_price":     avg_entry,
            "entry_price":        avg_entry,
            "highest_price":      highest,
            "consolidated":       True,
            "consolidated_count": len(trades),
        }
        if earliest_ts:
            updates["entry_timestamp"] = earliest_ts

        update_trade_field(keep_trade["_id"], updates)
        keep_trade["quantity"]       = total_qty
        keep_trade["avg_fill_price"] = avg_entry
        keep_trade["entry_price"]    = avg_entry
        keep_trade["highest_price"]  = highest

        log.info(f"{sym}: CONSOLIDATED → {total_qty} shares @ avg ${avg_entry:.4f}")
        consolidated.append(keep_trade)

    return consolidated


# ══════════════════════════════════════════════════════════════════════════════
# RE-ENTRY COOLDOWN
# ══════════════════════════════════════════════════════════════════════════════

def set_cooldown(symbol: str, reason: str):
    expires_at = datetime.now(timezone.utc) + timedelta(minutes=REENTRY_COOLDOWN_MIN)
    cooldown_collection.update_one(
        {"symbol": symbol},
        {"$set": {
            "symbol":       symbol,
            "reason":       reason,
            "closed_at":    datetime.now(timezone.utc),
            "expires_at":   expires_at,
            "cooldown_min": REENTRY_COOLDOWN_MIN,
        }},
        upsert=True,
    )
    log.info(
        f"{symbol}: COOLDOWN SET — no re-entry for {REENTRY_COOLDOWN_MIN} min "
        f"(until {expires_at.strftime('%H:%M:%S')} UTC) | close reason: {reason}"
    )


# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def get_trailing_stop_pct(pnl_pct: float, tiers: list) -> float:
    for threshold, trail in tiers:
        if pnl_pct >= threshold:
            return trail
    return DEFAULT_TRAILING_PCT


def compute_trailing_stop(entry_price: float, highest_price: float,
                          current_pnl_pct: float, tiers: list) -> float:
    trail_pct  = get_trailing_stop_pct(current_pnl_pct, tiers)
    trail_stop = highest_price * (1 - trail_pct)
    hard_stop  = entry_price * (1 - HARD_STOP_PCT)
    return max(trail_stop, hard_stop)


def check_flash_crash(symbol: str, current_price: float, trade: dict) -> Optional[str]:
    last_price = trade.get("last_price")
    update_trade_field(trade["_id"], {
        "last_price":      current_price,
        "last_price_time": datetime.now(timezone.utc),
    })
    if last_price and last_price > 0:
        drop_pct = (current_price - last_price) / last_price
        if drop_pct <= -FLASH_CRASH_PCT:
            log.warning(f"{symbol}: FLASH CRASH {drop_pct * 100:.2f}% in {MONITOR_INTERVAL}s")
            return f"flash_crash_{abs(drop_pct) * 100:.1f}pct"
    return None


def check_stale_trade(trade: dict, pnl_pct: float) -> bool:
    entry_time = trade.get("entry_timestamp")
    if not entry_time:
        return False
    if entry_time.tzinfo is None:
        hours_held = (datetime.now() - entry_time).total_seconds() / 3600
    else:
        hours_held = (datetime.now(timezone.utc) - entry_time).total_seconds() / 3600

    if hours_held >= STALE_TRADE_HOURS:
        if STALE_TRADE_MIN_PNL <= pnl_pct <= STALE_TRADE_MAX_PNL:
            log.info(
                f"{trade.get('instrument') or trade.get('symbol')}: "
                f"stale trade — {hours_held:.1f}h held, pnl={pnl_pct * 100:+.2f}%"
            )
            return True
    return False


# ══════════════════════════════════════════════════════════════════════════════
# EMERGENCY EXIT
# ══════════════════════════════════════════════════════════════════════════════

def emergency_exit(ibkr: IBKRSellClient, symbol: str, qty: int,
                   reason: str) -> tuple[float, str]:
    log.warning(f"{symbol}: EMERGENCY EXIT — {reason}")
    ticker      = ibkr.get_ticker(symbol)
    current_bid = ticker.bid or ticker.last or ticker.close

    if not current_bid:
        log.error(f"{symbol}: no price for emergency exit!")
        return 0.0, "exit_failed_no_price"

    trade    = ibkr.place_limit_sell(symbol, current_bid, qty, emergency=True)
    order_id = trade.order.orderId

    for _ in range(EMERGENCY_TIMEOUT):
        ibkr.ib.sleep(1)
        fill = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if fill:
            log.info(f"{symbol}: emergency limit filled @ ${fill:.4f}")
            return fill, reason

    log.warning(f"{symbol}: limit not filled in {EMERGENCY_TIMEOUT}s → MARKET")
    try:
        ibkr.ib.cancelOrder(trade.order)
    except Exception:
        pass

    market_trade = ibkr.place_market_sell(symbol, qty)
    ibkr.ib.sleep(2)
    fill = ibkr.get_avg_fill_price_from_broker(symbol, market_trade.order.orderId)
    if fill:
        return fill, f"{reason}_market"

    return current_bid * 0.98, f"{reason}_estimated"


# ══════════════════════════════════════════════════════════════════════════════
# EXIT DECISION ENGINE
# ══════════════════════════════════════════════════════════════════════════════

@dataclass
class ExitDecision:
    action:      str   # "hold" | "partial_sell" | "full_sell" | "emergency_sell"
    reason:      str
    qty_to_sell: int = 0
    partial_key: str = ""  # "partial_1" | "partial_2" (for flag tracking)


def evaluate_position(trade: dict, current_price: float, entry_price: float,
                      ibkr: IBKRSellClient) -> ExitDecision:
    """
    Master exit logic — evaluates all conditions in priority order.
    v3.0: entry-type aware profit schedule.
    """
    symbol    = trade.get("instrument") or trade.get("symbol")
    total_qty = trade.get("quantity") or trade.get("qty")
    highest   = trade.get("highest_price", entry_price)
    phase     = trade.get("phase", "initial")
    pnl_pct   = (current_price - entry_price) / (entry_price + 1e-9)

    # Track new high
    if current_price > highest:
        highest = current_price
        update_trade_field(trade["_id"], {"highest_price": highest})

    drawdown_from_high = (current_price - highest) / (highest + 1e-9)
    schedule = get_profit_schedule(trade)
    tiers    = schedule["runner_trail_tiers"]

    log.info(
        f"{symbol}: phase={phase} | entry=${entry_price:.4f} now=${current_price:.4f} "
        f"pnl={pnl_pct * 100:+.2f}% | high=${highest:.4f} dd={drawdown_from_high * 100:.2f}% "
        f"qty={total_qty} | type={trade.get('entry_type','standard')}"
    )

    # ── PRIORITY 1: Hard stop ─────────────────────────────────────────────────
    if pnl_pct <= -HARD_STOP_PCT:
        return ExitDecision("emergency_sell", "hard_stop_10pct", total_qty)

    # ── PRIORITY 2: Flash crash ───────────────────────────────────────────────
    flash = check_flash_crash(symbol, current_price, trade)
    if flash:
        return ExitDecision("emergency_sell", flash, total_qty)

    # ── PRIORITY 3: Partial profit — level 1 ─────────────────────────────────
    p1 = schedule.get("partial_1")
    if p1 and not trade.get("partial_1_taken", False):
        if pnl_pct >= p1["threshold"]:
            sell_qty = max(1, int(total_qty * p1["fraction"]))
            if sell_qty >= total_qty:
                return ExitDecision("full_sell", f"full_profit_p1_{pnl_pct*100:.1f}pct",
                                    total_qty, "partial_1")
            return ExitDecision("partial_sell", f"partial_1_{pnl_pct*100:.1f}pct",
                                sell_qty, "partial_1")

    # ── PRIORITY 4: Partial profit — level 2 (momentum/pullback) ─────────────
    p2 = schedule.get("partial_2")
    if p2 and not trade.get("partial_2_taken", False) and trade.get("partial_1_taken", False):
        if pnl_pct >= p2["threshold"]:
            sell_qty = max(1, int(total_qty * p2["fraction"]))
            if sell_qty >= total_qty:
                return ExitDecision("full_sell", f"full_profit_p2_{pnl_pct*100:.1f}pct",
                                    total_qty, "partial_2")
            return ExitDecision("partial_sell", f"partial_2_{pnl_pct*100:.1f}pct",
                                sell_qty, "partial_2")

    # ── PRIORITY 5: Trailing stop (PSAR-confirmed) ────────────────────────────
    stop_level = compute_trailing_stop(entry_price, highest, pnl_pct, tiers)

    if stop_level > entry_price * (1 - HARD_STOP_PCT):
        if current_price <= stop_level:
            signals       = ibkr.compute_exit_signals(symbol)
            psar_confirmed = False

            if signals:
                if signals.get("psar_bearish"):
                    psar_confirmed = True
                    log.info(
                        f"{symbol}: trailing stop CONFIRMED — PSAR bearish "
                        f"(PSAR={signals.get('psar', 0):.4f} > price={current_price:.4f})"
                    )
                else:
                    log.info(
                        f"{symbol}: trailing stop breached (${stop_level:.4f}) "
                        f"but PSAR still bullish — HOLDING through pullback"
                    )
            else:
                psar_confirmed = True
                log.warning(f"{symbol}: trailing stop breached, no signal data — safety exit")

            if psar_confirmed:
                trail_pct = get_trailing_stop_pct(pnl_pct, tiers)
                return ExitDecision(
                    "full_sell",
                    f"trailing_stop_{trail_pct*100:.0f}pct_psar_confirmed",
                    total_qty,
                )

    update_trade_field(trade["_id"], {"trailing_stop": stop_level})

    # ── PRIORITY 6: Technical exits (runner phase) ────────────────────────────
    if phase == "runner":
        signals = ibkr.compute_exit_signals(symbol)
        if signals:
            if signals.get("psar_bearish") and signals.get("price_below_ema9"):
                return ExitDecision("full_sell", "psar_bearish_below_ema9", total_qty)
            if signals.get("ema_death_cross"):
                return ExitDecision("full_sell", "ema_9_21_death_cross", total_qty)

    # ── PRIORITY 7: Stale trade ───────────────────────────────────────────────
    if check_stale_trade(trade, pnl_pct):
        return ExitDecision("full_sell", "stale_trade_timeout", total_qty)

    # ── DEFAULT: Hold ─────────────────────────────────────────────────────────
    trail_pct = get_trailing_stop_pct(pnl_pct, tiers)
    log.info(
        f"{symbol}: HOLD | trail={trail_pct*100:.0f}% "
        f"stop=${stop_level:.4f} | phase={phase}"
    )
    return ExitDecision("hold", "holding", 0)


# ══════════════════════════════════════════════════════════════════════════════
# MAIN MONITOR LOOP
# ══════════════════════════════════════════════════════════════════════════════

def monitor_positions(ibkr: IBKRSellClient):
    log.info("=" * 60)
    log.info("SELL BOT v3.0 — Smart Position Manager")
    log.info("  Entry-type aware profit schedules: standard / momentum / pullback")
    log.info("  Liquidity crisis check: DISABLED")
    log.info("  Trail confirmation: PSAR bearish only")
    log.info("  Duplicate positions: auto-consolidated")
    log.info(f"Hard Stop: {HARD_STOP_PCT*100}% | Flash: {FLASH_CRASH_PCT*100}%")
    log.info(f"Schedules:")
    for etype, sched in PROFIT_SCHEDULE.items():
        p1 = sched.get("partial_1")
        p2 = sched.get("partial_2")
        p2_label = (f"{p2['threshold']*100:.0f}%→{p2['fraction']*100:.0f}% sell"
                    if p2 else "none")
        log.info(
            f"  {etype:10s}: "
            f"P1={p1['threshold']*100:.0f}%→{p1['fraction']*100:.0f}% sell | "
            f"P2={p2_label} | "
            f"trail={sched['runner_trail_tiers']}"
        )
    log.info(f"Cooldown: {REENTRY_COOLDOWN_MIN} min | "
             f"Stale: >{STALE_TRADE_HOURS}h in "
             f"[{STALE_TRADE_MIN_PNL*100}%,{STALE_TRADE_MAX_PNL*100}%]")
    log.info("=" * 60)

    while True:
        try:
            open_trades = get_open_trades()
            open_trades = consolidate_duplicate_positions(open_trades)
            log.info(f"--- Checking {len(open_trades)} open position(s) ---")

            for trade in open_trades:
                symbol    = trade.get("instrument") or trade.get("symbol")
                total_qty = trade.get("quantity") or trade.get("qty")

                if not symbol or not total_qty:
                    log.warning(f"Skipping trade {trade['_id']}: missing symbol or qty")
                    continue

                entry_price   = get_effective_entry_price(trade, ibkr)
                current_price = ibkr.get_last_price(symbol)
                if not current_price:
                    log.warning(f"{symbol}: no current price, skipping")
                    continue

                decision = evaluate_position(trade, current_price, entry_price, ibkr)

                if decision.action == "hold":
                    continue

                # ── Execute the decision ──────────────────────────────────────

                if decision.action == "emergency_sell":
                    exit_price, final_reason = emergency_exit(
                        ibkr, symbol, decision.qty_to_sell, decision.reason
                    )
                    close_trade(trade, exit_price, final_reason, decision.qty_to_sell)

                elif decision.action == "partial_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                             current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)
                    # Mark partial as taken so we don't re-trigger
                    if decision.partial_key:
                        update_trade_field(trade["_id"], {
                            f"{decision.partial_key}_taken": True,
                        })

                elif decision.action == "full_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                             current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

        except Exception as e:
            log.error(f"Monitor error: {e}", exc_info=True)

        time.sleep(MONITOR_INTERVAL)


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY POINT
# ══════════════════════════════════════════════════════════════════════════════

def main():
    log.info("=== Sell Bot v3.0 Starting ===")
    ibkr = IBKRSellClient()

    try:
        ibkr.connect()
        monitor_positions(ibkr)
    except KeyboardInterrupt:
        log.info("Sell bot stopped by user.")
    except Exception as e:
        log.error(f"Fatal error: {e}", exc_info=True)
    finally:
        ibkr.disconnect()
        log.info("IBKR disconnected.")


if __name__ == "__main__":
    main()
# Out:
# 2026-04-08 06:55:21,922 [INFO] === Sell Bot v3.0 Starting ===
# 2026-04-08 06:55:22,075 [INFO] IBKR connected | accounts: ['DUD087866']
# 2026-04-08 06:55:22,076 [INFO] ============================================================
# 2026-04-08 06:55:22,077 [INFO] SELL BOT v3.0 — Smart Position Manager
# 2026-04-08 06:55:22,078 [INFO]   Entry-type aware profit schedules: standard / momentum / pullback
# 2026-04-08 06:55:22,080 [INFO]   Liquidity crisis check: DISABLED
# 2026-04-08 06:55:22,081 [INFO]   Trail confirmation: PSAR bearish only
# 2026-04-08 06:55:22,082 [INFO]   Duplicate positions: auto-consolidated
# 2026-04-08 06:55:22,084 [INFO] Hard Stop: 10.0% | Flash: 5.0%
# 2026-04-08 06:55:22,085 [INFO] Schedules:
# 2026-04-08 06:55:22,086 [INFO]   standard  : P1=50%→50% sell | P2=none | trail=[(1.5, 0.08), (1.0, 0.1), (0.75, 0.12), (0.5, 0.15)]
# 2026-04-08 06:55:22,087 [INFO]   momentum  : P1=30%→33% sell | P2=60%→50% sell | trail=[(1.0, 0.08), (0.75, 0.1), (0.5, 0.12)]
# 2026-04-08 06:55:22,088 [INFO]   pullback  : P1=25%→40% sell | P2=50%→33% sell | trail=[(1.5, 0.08), (1.0, 0.1), (0.75, 0.12), (0.5, 0.15)]
# 2026-04-08 06:55:22,089 [INFO] Cooldown: 30 min | Stale: >2h in [-5.0%,10.0%]
# 2026-04-08 06:55:22,090 [INFO] ============================================================
# 2026-04-08 06:55:22,098 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:55:52,102 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:56:22,105 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:56:52,108 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:57:22,112 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:57:52,116 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:58:22,119 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:58:52,122 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:59:22,125 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 06:59:52,130 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:00:22,133 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:00:52,136 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:01:22,140 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:01:52,142 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:02:22,146 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:02:52,148 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:03:22,152 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:03:52,156 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:04:22,160 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:04:52,165 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:05:22,168 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:05:52,172 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:06:22,175 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:06:52,178 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:07:22,181 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:07:52,184 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:08:22,187 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:08:52,191 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:09:22,194 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:09:52,196 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:10:22,199 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:10:52,202 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:11:22,205 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:11:52,208 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:12:22,211 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:12:52,214 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:13:22,217 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:13:52,220 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:14:22,223 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:14:52,226 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:15:22,228 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:15:52,231 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:16:22,235 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:16:52,237 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:17:22,241 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:17:52,244 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:18:22,247 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:18:52,250 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:19:22,253 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:19:52,258 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:20:22,262 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:20:52,266 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:21:22,269 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:21:52,272 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:22:22,275 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:22:52,278 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:23:22,281 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:23:52,284 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:24:22,287 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:24:52,291 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:25:22,295 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:25:52,300 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:26:22,303 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:26:52,307 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:27:22,310 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:27:52,313 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:28:22,317 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:28:52,320 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:29:22,324 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:29:52,326 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:30:22,329 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:30:52,333 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:31:22,337 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:31:52,340 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:32:22,344 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:32:52,346 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:33:22,351 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:33:52,354 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:34:22,359 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:34:52,364 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:35:22,373 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:35:52,377 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:36:22,381 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:36:52,384 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:37:22,390 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:37:52,393 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:38:22,397 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:38:52,401 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:39:22,409 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:39:52,414 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:40:22,419 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:40:52,421 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:41:22,426 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:41:52,430 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:42:22,433 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:42:52,441 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:43:22,443 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:43:52,447 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:44:22,454 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:44:52,457 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:45:22,461 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:45:52,464 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:46:22,467 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:46:52,471 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:47:22,475 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:47:52,478 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:48:22,481 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:48:52,485 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:49:22,489 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:49:52,492 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:50:22,496 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:50:52,501 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:51:22,504 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:51:52,509 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:52:22,517 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:52:52,521 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:53:22,524 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:53:52,528 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:54:22,532 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:54:52,534 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:55:22,537 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:55:52,539 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:56:22,544 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:56:52,548 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:57:22,552 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:57:52,555 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:58:22,559 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:58:52,564 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:59:22,568 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 07:59:52,571 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:00:22,573 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:00:52,577 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:01:22,582 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:01:52,586 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:02:22,590 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:02:52,594 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:03:22,597 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:03:52,601 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:04:22,604 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:04:52,608 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:05:22,611 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:05:52,614 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:06:22,618 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:06:52,621 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:07:22,623 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:07:52,626 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:08:22,630 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:08:52,634 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:09:22,640 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:09:52,644 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:10:22,648 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:10:52,653 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:11:22,657 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:11:52,661 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:12:22,664 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:12:52,666 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:13:22,670 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:13:52,673 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:14:22,678 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:14:52,680 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:15:22,682 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:15:52,686 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:16:22,689 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:16:52,695 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:17:22,699 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:17:52,703 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:18:22,706 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:18:52,709 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:19:22,712 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:19:52,716 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:20:22,722 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:20:52,726 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:21:22,729 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:21:52,733 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:22:22,736 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:22:52,739 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:23:22,742 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:23:52,748 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:24:22,753 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:24:52,756 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:25:22,761 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:25:52,766 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:26:22,770 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:26:52,773 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:27:22,777 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:27:52,782 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:28:22,786 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:28:52,791 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:29:22,794 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:29:52,797 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:30:22,800 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:30:52,804 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:31:22,807 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:31:52,812 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:32:22,817 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:32:52,819 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:33:22,823 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:33:52,826 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:34:22,830 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:34:52,834 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:35:22,838 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:35:52,841 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:36:22,845 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:36:52,848 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:37:22,854 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:37:52,857 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:38:22,861 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:38:52,864 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:39:22,868 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:39:52,870 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:40:22,874 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:40:52,877 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:41:22,880 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:41:52,882 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:42:22,886 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:42:52,888 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:43:22,891 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:43:52,894 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:44:22,900 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:44:52,904 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:45:22,908 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:45:52,911 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:46:22,913 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:46:52,916 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:47:22,920 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:47:52,923 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:48:22,926 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:48:52,930 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:49:22,933 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:49:52,936 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:50:22,939 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:50:52,943 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:51:22,945 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:51:52,949 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:52:22,952 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:52:52,954 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:53:22,958 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:53:52,961 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:54:22,966 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:54:52,970 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:55:22,973 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:55:52,976 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:56:22,981 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:56:52,986 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:57:22,989 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:57:52,993 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:58:22,997 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:58:53,004 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:59:23,009 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 08:59:53,012 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:00:23,016 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:00:53,018 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:01:23,025 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:01:53,029 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:02:23,034 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:02:53,039 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:03:23,044 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:03:53,046 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:04:23,051 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:04:53,055 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:05:23,058 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:05:53,060 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:06:23,063 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:06:53,067 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:07:23,070 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:07:53,072 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:08:23,076 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:08:53,081 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:09:23,083 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:09:53,086 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:10:23,090 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:10:53,092 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:11:23,096 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:11:53,099 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:12:23,101 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:12:53,105 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:13:23,107 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:13:53,110 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:14:23,113 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:14:53,119 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:15:23,122 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:15:53,125 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:16:23,128 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:16:53,132 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:17:23,134 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:17:53,137 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:18:23,140 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:18:53,143 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:19:23,146 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:19:53,150 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:20:23,153 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:20:53,156 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:21:23,158 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:21:53,162 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:22:23,166 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:22:53,169 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:23:23,172 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:23:53,175 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:24:23,178 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:24:53,183 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:25:23,186 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:25:53,188 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:26:23,192 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:26:53,195 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:27:23,199 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:27:53,202 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:28:23,205 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:28:53,210 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:29:23,217 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:29:53,222 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:30:23,228 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:30:53,239 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:31:23,244 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:31:53,248 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:32:23,253 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:32:53,258 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:33:23,263 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:33:53,269 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:34:23,274 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:34:53,279 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:35:23,284 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:35:53,289 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:36:23,295 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:36:53,301 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:37:23,305 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:37:53,310 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:38:23,316 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:38:53,322 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:39:23,327 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:39:53,332 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:40:23,337 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:40:53,343 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:41:23,348 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:41:53,354 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:42:23,359 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:42:53,364 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:43:23,369 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:43:53,375 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:44:23,381 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:44:53,386 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:45:23,391 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:45:53,398 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:46:23,403 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:46:53,409 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:47:23,418 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:47:53,424 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:48:23,428 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:48:53,433 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:49:23,439 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:49:53,444 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:50:23,451 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:50:53,456 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:51:23,462 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:51:53,468 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:52:23,473 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:52:53,480 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:53:23,485 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:53:53,490 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:54:23,495 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:54:53,501 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:55:23,507 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:55:53,513 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:56:23,519 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:56:53,525 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:57:23,530 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:57:53,535 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:58:23,541 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:58:53,546 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:59:23,552 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 09:59:53,556 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:00:23,561 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:00:53,567 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:01:23,575 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:01:53,580 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:02:23,585 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:02:53,590 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:03:23,595 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:03:53,599 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:04:23,603 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:04:53,608 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:05:23,613 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:05:53,618 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:06:23,622 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:06:53,626 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:07:23,631 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:07:53,635 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:08:23,640 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:08:53,645 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:09:23,650 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:09:53,655 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:10:23,659 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:10:53,664 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:11:23,668 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:11:53,672 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:12:23,677 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:12:53,681 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:13:23,685 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:13:53,689 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:14:23,693 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:14:53,697 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:15:23,702 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:15:53,707 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:16:23,710 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:16:53,715 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:17:23,718 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:17:53,723 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:18:23,728 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:18:53,733 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:19:23,737 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:19:53,741 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:20:23,745 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:20:53,748 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:21:23,752 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:21:53,756 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:22:23,760 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:22:53,764 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:23:23,768 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:23:53,771 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:24:23,775 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:24:53,780 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:25:23,783 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:25:53,787 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:26:23,792 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:26:53,796 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:27:23,800 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:27:53,806 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:28:23,810 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:28:53,814 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:29:23,819 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:29:53,823 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:30:23,828 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:30:53,832 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:31:23,836 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:31:53,840 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:32:23,844 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:32:53,848 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:33:23,853 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:33:53,857 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:34:23,860 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:34:53,865 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:35:23,868 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:35:53,873 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:36:23,879 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:36:53,883 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:37:23,887 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:37:53,890 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:38:23,894 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:38:53,897 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:39:23,901 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:39:53,904 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:40:23,908 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:40:53,911 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:41:23,915 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:41:53,918 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:42:23,921 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:42:53,924 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:43:23,927 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:43:53,931 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:44:23,935 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:44:53,939 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:46:23,948 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:46:53,952 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:47:23,955 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:47:53,959 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:48:23,963 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:48:53,967 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:49:23,970 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:49:53,973 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:50:23,977 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:50:53,980 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:51:23,984 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:51:53,988 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:52:23,992 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:52:53,996 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:53:24,000 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:53:54,003 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:54:24,008 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:54:54,013 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:55:24,016 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:55:54,020 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:56:24,024 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:56:54,027 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:57:24,031 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:57:54,035 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:58:24,038 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:58:54,043 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:59:24,047 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 10:59:54,049 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:00:24,053 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:00:54,057 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:01:24,060 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:01:54,064 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:02:24,068 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:02:54,072 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:03:24,076 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:03:54,080 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:04:24,084 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:04:54,087 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:05:24,091 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:05:54,095 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:06:24,099 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:06:54,103 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:07:24,107 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:07:54,111 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:08:24,117 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:08:54,120 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:09:24,123 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:09:54,126 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:10:24,129 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:10:54,132 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:11:24,135 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:11:54,140 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:12:24,143 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:12:54,147 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:13:24,150 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:13:54,154 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:14:24,158 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:14:54,161 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:15:24,164 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:15:54,168 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:16:24,174 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:16:54,177 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:17:24,180 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:17:54,184 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:18:24,188 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:18:54,191 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:19:24,195 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:19:54,200 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:20:24,203 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:20:54,207 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:21:24,211 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:21:54,215 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:22:24,218 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:22:54,221 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:23:24,225 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:23:54,229 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:24:24,232 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:24:54,236 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:25:24,240 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:25:54,243 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:26:24,247 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:26:54,249 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:27:24,252 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:27:54,255 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:28:24,258 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:28:54,261 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:29:24,265 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:29:54,268 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:30:24,271 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:30:54,274 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:31:24,277 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:31:54,281 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:32:24,283 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:32:54,287 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:33:24,291 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:33:54,294 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:34:24,297 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:34:54,299 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:35:24,302 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:35:54,304 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:36:24,308 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:36:54,312 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:37:24,315 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:37:54,318 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:38:24,322 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:38:54,325 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:39:24,328 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:39:54,331 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:40:24,335 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:40:54,339 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:41:24,342 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:41:54,346 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:42:24,350 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:42:54,352 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:43:24,356 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:43:54,358 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:44:24,363 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:44:54,366 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:45:24,369 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:45:54,373 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:46:24,376 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:46:54,379 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:47:24,382 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:47:54,385 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:48:24,388 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:48:54,392 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:49:24,395 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:49:54,398 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:50:24,402 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:50:54,406 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:51:24,410 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:51:54,412 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:52:24,415 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:52:54,419 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:53:24,422 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:53:54,425 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:54:24,430 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:54:54,433 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:55:24,436 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:55:54,440 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:56:24,444 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:56:54,448 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:57:24,451 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:57:54,455 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:58:24,459 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:58:54,462 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:59:24,466 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 11:59:54,470 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:00:24,472 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:00:54,475 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:01:24,479 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:01:54,481 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:02:24,484 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:02:54,487 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:03:24,490 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:03:54,493 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:04:24,497 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:04:54,500 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:05:24,503 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:05:54,506 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:06:24,510 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:06:54,513 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:07:24,516 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:07:54,520 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:08:24,525 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:08:54,528 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:09:24,531 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:09:54,533 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:10:24,536 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:10:54,539 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:11:24,543 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:11:54,546 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:12:24,550 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:12:54,554 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:13:24,557 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:13:54,559 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:14:24,563 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:14:54,566 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:15:24,569 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:15:54,572 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:16:24,576 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:16:54,579 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:17:24,582 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:17:54,585 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:18:24,587 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:18:54,591 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:19:24,595 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:19:54,599 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:20:24,602 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:20:54,605 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:21:24,608 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:21:54,611 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:22:24,615 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:22:54,618 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:23:24,620 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:23:54,623 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:24:24,627 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:24:54,630 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:25:24,633 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:25:54,636 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:26:24,639 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:26:54,642 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:27:24,645 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:27:54,648 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:28:24,651 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:28:54,656 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:29:24,660 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:29:54,663 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:30:24,666 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:30:54,670 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:31:24,674 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:31:54,677 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:32:24,679 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:32:54,683 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:33:24,686 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:33:54,689 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:34:24,693 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:34:54,698 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:35:24,701 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:35:54,704 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:36:24,729 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:36:54,733 [INFO] --- Checking 0 open position(s) ---

# %%
"""
Sell Bot v3.0 — Smart Position Manager
═══════════════════════════════════════════════════════════════════════════════
Monitors open positions via IBKR + MongoDB and exits them intelligently
using PSAR-confirmed trailing stops, tiered profit-taking, and emergency exits.

CHANGES from sell_bot_v2.3:
────────────────────────────
1. ENTRY-TYPE AWARE PROFIT SCHEDULE (Kimi proposal — PositionManager)
   - "standard"  (SMX/AIXI) : partial at +50%, runner with tiered trail
   - "momentum"  (FCUV)     : partial at +30%, partial at +60%, small runner
   - "pullback"  (KPRX)     : partial at +25%, partial at +50%, small runner

2. MULTI-PARTIAL TRACKING
   - partial_1_taken / partial_2_taken flags per trade doc
   - Remaining quantity correctly maintained across partial exits

3. RUNNER PROTECTION IMPROVEMENTS
   - Momentum runner: tighter trailing (10% tiers max)
   - Standard runner: existing PSAR-confirmed tiers

4. PRESERVED FROM v2.3:
   - Hard stop: -10% from entry
   - Flash crash: -5% drop in one interval → emergency exit
   - Tiered trailing: 8%–15% from high, PSAR-confirmed
   - Stale trade exit: >2h, PnL between -5% and +10%
   - Duplicate position consolidation
   - Re-entry cooldown (shared with buy bot)
   - Liquidity crisis check: REMOVED (was causing false exits)

EXIT STRATEGY SUMMARY:
──────────────────────
Phase 1 — PROTECTION (always active):
  Hard stop -10% | Flash crash -5%/interval

Phase 2 — PARTIAL PROFIT (by entry type):
  standard : +50% → sell 50%
  momentum : +30% → sell 33%, then +60% → sell 50% of remaining
  pullback : +25% → sell 40%, then +50% → sell 33% of remaining

Phase 3 — RUNNER (remaining shares):
  Trailing stop tiers (PSAR-confirmed):
    standard/pullback: +50-75→15%, +75-100→12%, +100-150→10%, +150+→8%
    momentum:          tighter — +50-75→12%, +75-100→10%, +100+→8%
  PSAR bearish + price below EMA9 → exit runner
  EMA9 death-crosses EMA21 → exit runner

Phase 4 — TIME DECAY:
  Position in [-5%, +10%] after 2h → exit
"""

import logging
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import random
from typing import Optional
from dataclasses import dataclass
from collections import defaultdict

from pymongo import MongoClient
from ib_insync import *

import warnings
warnings.filterwarnings("ignore")


# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ─── IBKR ────────────────────────────────────────────────────────────────────
IBKR_HOST      = "127.0.0.1"
IBKR_PORT      = 7497
IBKR_CLIENT_ID = random.randint(3000, 3999)   # Different range from scanner/buy bots

# ─── Emergency / Hard Protection ─────────────────────────────────────────────
HARD_STOP_PCT    = 0.12   # -12% from entry: wider stop in paper mode (was 0.10)
FLASH_CRASH_PCT  = 0.05   # -5% in one 30s interval: emergency
ENABLE_FLASH_CRASH_EXIT = False  # Disabled in paper mode — fewer premature exits

# ─── Profit Schedules by Entry Type (Kimi proposal) ──────────────────────────
PROFIT_SCHEDULE = {
    "standard": {
        # SMX/AIXI: let it run, single partial at 50%
        "partial_1": {"threshold": 0.50, "fraction": 0.50},
        "partial_2": None,
        "runner_trail_tiers": [
            (1.50, 0.08),   # +150%+  → trail 8%
            (1.00, 0.10),   # +100%+  → trail 10%
            (0.75, 0.12),   # +75%+   → trail 12%
            (0.50, 0.15),   # +50%+   → trail 15%
        ],
    },
    "momentum": {
        # FCUV: fast movers — take quick partials
        "partial_1": {"threshold": 0.30, "fraction": 0.33},
        "partial_2": {"threshold": 0.60, "fraction": 0.50},
        "runner_trail_tiers": [
            (1.00, 0.08),   # Tighter: +100%+ → 8%
            (0.75, 0.10),   # +75%+   → 10%
            (0.50, 0.12),   # +50%+   → 12%
        ],
    },
    "pullback": {
        # KPRX: conservative recovery play — quick initial profits
        "partial_1": {"threshold": 0.25, "fraction": 0.40},
        "partial_2": {"threshold": 0.50, "fraction": 0.33},
        "runner_trail_tiers": [
            (1.50, 0.08),
            (1.00, 0.10),
            (0.75, 0.12),
            (0.50, 0.15),
        ],
    },
}
DEFAULT_SCHEDULE    = PROFIT_SCHEDULE["standard"]
DEFAULT_TRAILING_PCT = 0.20    # Before first partial if somehow needed

# ─── Time Decay ───────────────────────────────────────────────────────────────
STALE_TRADE_HOURS   = 3    # Paper mode: give runners more room (was 2)
STALE_TRADE_MIN_PNL = -0.05
STALE_TRADE_MAX_PNL = 0.10

# ─── Technical Exit Signals ───────────────────────────────────────────────────
EMA_FAST_PERIOD = 9
EMA_SLOW_PERIOD = 21

# ─── Re-entry Cooldown ────────────────────────────────────────────────────────
REENTRY_COOLDOWN_MIN = 30

# ─── Monitoring ───────────────────────────────────────────────────────────────
MONITOR_INTERVAL  = 30   # seconds between position checks
EMERGENCY_TIMEOUT = 5    # seconds to wait for limit fill before market

# ─── MongoDB ──────────────────────────────────────────────────────────────────
MONGO_URI           = "mongodb://localhost:27017/"
DB_NAME             = "breakout_db"
TRADES_COL          = "trades_v2"
COOLDOWN_COL        = "cooldowns"


# ══════════════════════════════════════════════════════════════════════════════
# LOGGING
# ══════════════════════════════════════════════════════════════════════════════

class _Utf8SafeStreamHandler(logging.StreamHandler):
    def emit(self, record):
        try:
            super().emit(record)
        except UnicodeEncodeError:
            record.msg  = str(record.msg).encode("ascii", errors="replace").decode("ascii")
            record.args = ()
            try:
                super().emit(record)
            except Exception:
                self.handleError(record)

    def _try_utf8(self):
        try:
            if hasattr(self.stream, "reconfigure"):
                self.stream.reconfigure(encoding="utf-8", errors="replace")
        except Exception:
            pass


def _make_logger() -> logging.Logger:
    fmt = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
    sh  = _Utf8SafeStreamHandler(sys.stdout)
    sh._try_utf8()
    sh.setFormatter(fmt)
    fh  = logging.FileHandler("sell_bot.log", encoding="utf-8")
    fh.setFormatter(fmt)
    logger = logging.getLogger("sell_bot")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    logger.addHandler(sh)
    logger.addHandler(fh)
    logger.propagate = False
    return logger

log = _make_logger()


# ══════════════════════════════════════════════════════════════════════════════
# IBKR CLIENT
# ══════════════════════════════════════════════════════════════════════════════

class IBKRSellClient:
    def __init__(self):
        util.startLoop()
        self.ib = IB()

    def connect(self):
        self.ib.connect(IBKR_HOST, IBKR_PORT, clientId=IBKR_CLIENT_ID)
        log.info(f"IBKR connected | accounts: {self.ib.wrapper.accounts}")

    def disconnect(self):
        self.ib.disconnect()

    # ── Price helpers ─────────────────────────────────────────────────────────

    def get_last_price(self, symbol: str) -> Optional[float]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "106", False, False)
        self.ib.sleep(3)
        self.ib.cancelMktData(contract)
        for label, val in [("last", ticker.last), ("ask", ticker.ask),
                           ("bid", ticker.bid), ("close", ticker.close)]:
            if val and float(val) > 0:
                log.debug(f"{symbol}: price source='{label}' ${float(val):.4f}")
                return float(val)
        log.warning(f"{symbol}: no price available")
        return None

    def get_ticker(self, symbol: str) -> Ticker:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "", False, False)
        self.ib.sleep(2)
        return ticker

    # ── Historical bars ───────────────────────────────────────────────────────

    def get_bars(self, symbol: str, n: int = 70) -> Optional[pd.DataFrame]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        for what_to_show in ("TRADES", "MIDPOINT"):
            raw = self.ib.reqHistoricalData(
                contract,
                endDateTime="",
                durationStr="10 D",
                barSizeSetting="5 mins",
                whatToShow=what_to_show,
                useRTH=False,
                keepUpToDate=False,
            )
            if raw:
                df = pd.DataFrame([
                    {"open": b.open, "high": b.high, "low": b.low,
                     "close": b.close, "volume": getattr(b, "volume", 0)}
                    for b in raw
                ])
                return df.tail(n).reset_index(drop=True)
        log.warning(f"{symbol}: no bars returned")
        return None

    # ── Technical exit signals ────────────────────────────────────────────────

    def compute_exit_signals(self, symbol: str) -> dict:
        df = self.get_bars(symbol, n=70)
        if df is None or len(df) < 25:
            log.warning(f"{symbol}: not enough bars for exit signals")
            return {}

        psar_vals = self._compute_psar(df["high"].values, df["low"].values,
                                       df["close"].values)
        ema_fast = df["close"].ewm(span=EMA_FAST_PERIOD, adjust=False).mean()
        ema_slow = df["close"].ewm(span=EMA_SLOW_PERIOD, adjust=False).mean()

        price     = float(df["close"].iloc[-1])
        psar_now  = float(psar_vals[-1])
        ema9_now  = float(ema_fast.iloc[-1])
        ema21_now = float(ema_slow.iloc[-1])
        ema9_prev  = float(ema_fast.iloc[-2])
        ema21_prev = float(ema_slow.iloc[-2])

        psar_bearish     = psar_now > price
        ema_death_cross  = (ema9_prev >= ema21_prev) and (ema9_now < ema21_now)
        price_below_ema9 = price < ema9_now

        signals = {
            "price":             price,
            "psar":              psar_now,
            "ema_9":             ema9_now,
            "ema_21":            ema21_now,
            "psar_bearish":      psar_bearish,
            "ema_death_cross":   ema_death_cross,
            "price_below_ema9":  price_below_ema9,
        }

        log.info(
            f"{symbol} exit signals: PSAR={psar_now:.4f}({'BEAR' if psar_bearish else 'BULL'}) "
            f"EMA9={ema9_now:.4f} EMA21={ema21_now:.4f} "
            f"cross={'YES' if ema_death_cross else 'no'} "
            f"below9={'YES' if price_below_ema9 else 'no'}"
        )
        return signals

    @staticmethod
    def _compute_psar(highs, lows, closes, iaf=0.02, max_af=0.2) -> np.ndarray:
        n    = len(closes)
        psar = closes.copy().astype(float)
        bull = True
        af   = iaf
        hp   = float(highs[0])
        lp   = float(lows[0])

        for i in range(2, n):
            if bull:
                psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
                psar[i] = min(psar[i], lows[i - 1], lows[i - 2])
                if lows[i] < psar[i]:
                    bull = False; psar[i] = hp; lp = lows[i]; af = iaf
                else:
                    if highs[i] > hp:
                        hp = highs[i]; af = min(af + iaf, max_af)
            else:
                psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
                psar[i] = max(psar[i], highs[i - 1], highs[i - 2])
                if highs[i] > psar[i]:
                    bull = True; psar[i] = lp; hp = highs[i]; af = iaf
                else:
                    if lows[i] < lp:
                        lp = lows[i]; af = min(af + iaf, max_af)
        return psar

    # ── Order execution ───────────────────────────────────────────────────────

    def get_avg_fill_price_from_broker(self, symbol: str, order_id: int) -> Optional[float]:
        for trade in self.ib.trades():
            if (trade.contract.symbol == symbol
                    and trade.order.orderId == order_id
                    and trade.orderStatus.avgFillPrice > 0):
                return float(trade.orderStatus.avgFillPrice)

        fills   = self.ib.fills()
        matched = [f for f in fills
                   if f.contract.symbol == symbol and f.execution.orderId == order_id]
        if matched:
            total_qty  = sum(f.execution.shares for f in matched)
            total_cost = sum(f.execution.shares * f.execution.price for f in matched)
            return total_cost / total_qty

        return None

    def place_limit_sell(self, symbol: str, price: float, qty: int,
                         emergency: bool = False) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        if emergency:
            price = price * 0.99
        order = LimitOrder("SELL", qty, round(price, 2))
        order.outsideRth = True
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL LIMIT {symbol} x{qty} @ ${price:.2f} "
                 f"orderId={trade.order.orderId} emergency={emergency}")
        return trade

    def place_market_sell(self, symbol: str, qty: int) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        order = MarketOrder("SELL", qty)
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL MARKET {symbol} x{qty} orderId={trade.order.orderId}")
        return trade

    def get_sell_fill_price(self, symbol: str, sell_order_id: int,
                            fallback_price: float) -> float:
        self.ib.sleep(3)
        avg = self.get_avg_fill_price_from_broker(symbol, sell_order_id)
        if avg:
            return avg
        log.warning(f"{symbol}: sell fill not confirmed, using fallback ${fallback_price:.4f}")
        return fallback_price


# ══════════════════════════════════════════════════════════════════════════════
# MONGODB HELPERS
# ══════════════════════════════════════════════════════════════════════════════

mongo_client       = MongoClient(MONGO_URI)
db                 = mongo_client[DB_NAME]
trades_collection  = db[TRADES_COL]
cooldown_collection = db[COOLDOWN_COL]


def get_open_trades() -> list:
    return list(trades_collection.find({"status": "open"}))


def get_effective_entry_price(trade: dict, ibkr: IBKRSellClient) -> float:
    if trade.get("avg_fill_price"):
        return float(trade["avg_fill_price"])
    order_id = trade.get("order_id")
    symbol   = trade.get("instrument") or trade.get("symbol")
    if order_id:
        try:
            broker_avg = ibkr.get_avg_fill_price_from_broker(symbol, int(order_id))
        except (ValueError, TypeError):
            broker_avg = None
        if broker_avg:
            trades_collection.update_one(
                {"_id": trade["_id"]},
                {"$set": {"avg_fill_price": broker_avg, "entry_price": broker_avg}},
            )
            return broker_avg
    return float(trade["entry_price"])


def update_trade_field(trade_id, updates: dict):
    updates["updated_at"] = datetime.now(timezone.utc)
    trades_collection.update_one({"_id": trade_id}, {"$set": updates})


def get_profit_schedule(trade: dict) -> dict:
    """Return the correct profit schedule based on entry_type."""
    entry_type = trade.get("entry_type", "standard")
    return PROFIT_SCHEDULE.get(entry_type, DEFAULT_SCHEDULE)


def close_trade(trade: dict, exit_price: float, reason: str, qty_sold: int = None):
    symbol      = trade.get("instrument") or trade.get("symbol")
    entry_price = float(trade.get("avg_fill_price") or trade["entry_price"])
    total_qty   = trade.get("quantity") or trade.get("qty")
    pnl_pct     = (exit_price - entry_price) / (entry_price + 1e-9)

    if qty_sold is None:
        qty_sold = total_qty

    realized_pnl = (exit_price - entry_price) * qty_sold

    if qty_sold >= total_qty:
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "status":         "closed",
                "exit_price":     exit_price,
                "exit_timestamp": datetime.now(timezone.utc),
                "reason":         reason,
                "pnl_pct":        round(pnl_pct * 100, 2),
                "realized_pnl":   realized_pnl,
                "updated_at":     datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"CLOSED {symbol} | entry=${entry_price:.4f} exit=${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | reason={reason}"
        )
        set_cooldown(symbol, reason)
    else:
        remaining = total_qty - qty_sold
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "quantity":              remaining,
                "partial_exit_price":    exit_price,
                "partial_exit_qty":      qty_sold,
                "partial_exit_time":     datetime.now(timezone.utc),
                "partial_exit_reason":   reason,
                "partial_realized_pnl":  realized_pnl,
                "phase":                 "runner",
                "updated_at":            datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"PARTIAL CLOSE {symbol} | sold {qty_sold}/{total_qty} @ ${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | "
            f"remaining={remaining} shares → runner mode"
        )


# ══════════════════════════════════════════════════════════════════════════════
# POSITION CONSOLIDATION  (preserved from v2.3)
# ══════════════════════════════════════════════════════════════════════════════

def consolidate_duplicate_positions(open_trades: list) -> list:
    by_symbol = defaultdict(list)
    for t in open_trades:
        sym = t.get("instrument") or t.get("symbol")
        if sym:
            by_symbol[sym].append(t)

    consolidated = []
    for sym, trades in by_symbol.items():
        if len(trades) == 1:
            consolidated.append(trades[0])
            continue

        log.warning(f"{sym}: CONSOLIDATING {len(trades)} duplicate open trades into 1")

        total_qty  = 0
        total_cost = 0.0
        earliest_ts = None
        highest     = 0.0
        keep_trade  = None

        for t in trades:
            qty   = t.get("quantity") or t.get("qty") or 0
            entry = float(t.get("avg_fill_price") or t.get("entry_price") or 0)
            total_qty  += qty
            total_cost += qty * entry

            ts = t.get("entry_timestamp")
            if ts and (earliest_ts is None or ts < earliest_ts):
                earliest_ts = ts

            h = t.get("highest_price", entry)
            if h > highest:
                highest = h

            if keep_trade is None:
                keep_trade = t
            else:
                trades_collection.update_one(
                    {"_id": t["_id"]},
                    {"$set": {"status": "merged", "merged_into": keep_trade["_id"],
                              "updated_at": datetime.now(timezone.utc)}},
                )
                log.info(f"{sym}: merged trade {t['_id']} into {keep_trade['_id']}")

        avg_entry = total_cost / total_qty if total_qty > 0 else 0
        updates = {
            "quantity":           total_qty,
            "avg_fill_price":     avg_entry,
            "entry_price":        avg_entry,
            "highest_price":      highest,
            "consolidated":       True,
            "consolidated_count": len(trades),
        }
        if earliest_ts:
            updates["entry_timestamp"] = earliest_ts

        update_trade_field(keep_trade["_id"], updates)
        keep_trade["quantity"]       = total_qty
        keep_trade["avg_fill_price"] = avg_entry
        keep_trade["entry_price"]    = avg_entry
        keep_trade["highest_price"]  = highest

        log.info(f"{sym}: CONSOLIDATED → {total_qty} shares @ avg ${avg_entry:.4f}")
        consolidated.append(keep_trade)

    return consolidated


# ══════════════════════════════════════════════════════════════════════════════
# RE-ENTRY COOLDOWN
# ══════════════════════════════════════════════════════════════════════════════

def set_cooldown(symbol: str, reason: str):
    expires_at = datetime.now(timezone.utc) + timedelta(minutes=REENTRY_COOLDOWN_MIN)
    cooldown_collection.update_one(
        {"symbol": symbol},
        {"$set": {
            "symbol":       symbol,
            "reason":       reason,
            "closed_at":    datetime.now(timezone.utc),
            "expires_at":   expires_at,
            "cooldown_min": REENTRY_COOLDOWN_MIN,
        }},
        upsert=True,
    )
    log.info(
        f"{symbol}: COOLDOWN SET — no re-entry for {REENTRY_COOLDOWN_MIN} min "
        f"(until {expires_at.strftime('%H:%M:%S')} UTC) | close reason: {reason}"
    )


# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def get_trailing_stop_pct(pnl_pct: float, tiers: list) -> float:
    for threshold, trail in tiers:
        if pnl_pct >= threshold:
            return trail
    return DEFAULT_TRAILING_PCT


def compute_trailing_stop(entry_price: float, highest_price: float,
                          current_pnl_pct: float, tiers: list) -> float:
    trail_pct  = get_trailing_stop_pct(current_pnl_pct, tiers)
    trail_stop = highest_price * (1 - trail_pct)
    hard_stop  = entry_price * (1 - HARD_STOP_PCT)
    return max(trail_stop, hard_stop)


def check_flash_crash(symbol: str, current_price: float, trade: dict) -> Optional[str]:
    last_price = trade.get("last_price")
    update_trade_field(trade["_id"], {
        "last_price":      current_price,
        "last_price_time": datetime.now(timezone.utc),
    })
    if last_price and last_price > 0:
        drop_pct = (current_price - last_price) / last_price
        if drop_pct <= -FLASH_CRASH_PCT:
            log.warning(f"{symbol}: FLASH CRASH {drop_pct * 100:.2f}% in {MONITOR_INTERVAL}s")
            return f"flash_crash_{abs(drop_pct) * 100:.1f}pct"
    return None


def check_stale_trade(trade: dict, pnl_pct: float) -> bool:
    entry_time = trade.get("entry_timestamp")
    if not entry_time:
        return False
    if entry_time.tzinfo is None:
        hours_held = (datetime.now() - entry_time).total_seconds() / 3600
    else:
        hours_held = (datetime.now(timezone.utc) - entry_time).total_seconds() / 3600

    if hours_held >= STALE_TRADE_HOURS:
        if STALE_TRADE_MIN_PNL <= pnl_pct <= STALE_TRADE_MAX_PNL:
            log.info(
                f"{trade.get('instrument') or trade.get('symbol')}: "
                f"stale trade — {hours_held:.1f}h held, pnl={pnl_pct * 100:+.2f}%"
            )
            return True
    return False


# ══════════════════════════════════════════════════════════════════════════════
# EMERGENCY EXIT
# ══════════════════════════════════════════════════════════════════════════════

def emergency_exit(ibkr: IBKRSellClient, symbol: str, qty: int,
                   reason: str) -> tuple[float, str]:
    log.warning(f"{symbol}: EMERGENCY EXIT — {reason}")
    ticker      = ibkr.get_ticker(symbol)
    current_bid = ticker.bid or ticker.last or ticker.close

    if not current_bid:
        log.error(f"{symbol}: no price for emergency exit!")
        return 0.0, "exit_failed_no_price"

    trade    = ibkr.place_limit_sell(symbol, current_bid, qty, emergency=True)
    order_id = trade.order.orderId

    for _ in range(EMERGENCY_TIMEOUT):
        ibkr.ib.sleep(1)
        fill = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if fill:
            log.info(f"{symbol}: emergency limit filled @ ${fill:.4f}")
            return fill, reason

    log.warning(f"{symbol}: limit not filled in {EMERGENCY_TIMEOUT}s → MARKET")
    try:
        ibkr.ib.cancelOrder(trade.order)
    except Exception:
        pass

    market_trade = ibkr.place_market_sell(symbol, qty)
    ibkr.ib.sleep(2)
    fill = ibkr.get_avg_fill_price_from_broker(symbol, market_trade.order.orderId)
    if fill:
        return fill, f"{reason}_market"

    return current_bid * 0.98, f"{reason}_estimated"


# ══════════════════════════════════════════════════════════════════════════════
# EXIT DECISION ENGINE
# ══════════════════════════════════════════════════════════════════════════════

@dataclass
class ExitDecision:
    action:      str   # "hold" | "partial_sell" | "full_sell" | "emergency_sell"
    reason:      str
    qty_to_sell: int = 0
    partial_key: str = ""  # "partial_1" | "partial_2" (for flag tracking)


def evaluate_position(trade: dict, current_price: float, entry_price: float,
                      ibkr: IBKRSellClient) -> ExitDecision:
    """
    Master exit logic — evaluates all conditions in priority order.
    v3.0: entry-type aware profit schedule.
    """
    symbol    = trade.get("instrument") or trade.get("symbol")
    total_qty = trade.get("quantity") or trade.get("qty")
    highest   = trade.get("highest_price", entry_price)
    phase     = trade.get("phase", "initial")
    pnl_pct   = (current_price - entry_price) / (entry_price + 1e-9)

    # Track new high
    if current_price > highest:
        highest = current_price
        update_trade_field(trade["_id"], {"highest_price": highest})

    drawdown_from_high = (current_price - highest) / (highest + 1e-9)
    schedule = get_profit_schedule(trade)
    tiers    = schedule["runner_trail_tiers"]

    log.info(
        f"{symbol}: phase={phase} | entry=${entry_price:.4f} now=${current_price:.4f} "
        f"pnl={pnl_pct * 100:+.2f}% | high=${highest:.4f} dd={drawdown_from_high * 100:.2f}% "
        f"qty={total_qty} | type={trade.get('entry_type','standard')}"
    )

    # ── PRIORITY 1: Hard stop ─────────────────────────────────────────────────
    if pnl_pct <= -HARD_STOP_PCT:
        return ExitDecision("emergency_sell", "hard_stop_10pct", total_qty)

    # ── PRIORITY 2: Flash crash ───────────────────────────────────────────────
    if ENABLE_FLASH_CRASH_EXIT:
        flash = check_flash_crash(symbol, current_price, trade)
        if flash:
            return ExitDecision("emergency_sell", flash, total_qty)
    else:
        # Still track last_price even when flash exit is disabled
        check_flash_crash(symbol, current_price, trade)

    # ── PRIORITY 3: Partial profit — level 1 ─────────────────────────────────
    p1 = schedule.get("partial_1")
    if p1 and not trade.get("partial_1_taken", False):
        if pnl_pct >= p1["threshold"]:
            sell_qty = max(1, int(total_qty * p1["fraction"]))
            if sell_qty >= total_qty:
                return ExitDecision("full_sell", f"full_profit_p1_{pnl_pct*100:.1f}pct",
                                    total_qty, "partial_1")
            return ExitDecision("partial_sell", f"partial_1_{pnl_pct*100:.1f}pct",
                                sell_qty, "partial_1")

    # ── PRIORITY 4: Partial profit — level 2 (momentum/pullback) ─────────────
    p2 = schedule.get("partial_2")
    if p2 and not trade.get("partial_2_taken", False) and trade.get("partial_1_taken", False):
        if pnl_pct >= p2["threshold"]:
            sell_qty = max(1, int(total_qty * p2["fraction"]))
            if sell_qty >= total_qty:
                return ExitDecision("full_sell", f"full_profit_p2_{pnl_pct*100:.1f}pct",
                                    total_qty, "partial_2")
            return ExitDecision("partial_sell", f"partial_2_{pnl_pct*100:.1f}pct",
                                sell_qty, "partial_2")

    # ── PRIORITY 5: Trailing stop (PSAR-confirmed) ────────────────────────────
    stop_level = compute_trailing_stop(entry_price, highest, pnl_pct, tiers)

    if stop_level > entry_price * (1 - HARD_STOP_PCT):
        if current_price <= stop_level:
            signals       = ibkr.compute_exit_signals(symbol)
            psar_confirmed = False

            if signals:
                if signals.get("psar_bearish"):
                    psar_confirmed = True
                    log.info(
                        f"{symbol}: trailing stop CONFIRMED — PSAR bearish "
                        f"(PSAR={signals.get('psar', 0):.4f} > price={current_price:.4f})"
                    )
                else:
                    log.info(
                        f"{symbol}: trailing stop breached (${stop_level:.4f}) "
                        f"but PSAR still bullish — HOLDING through pullback"
                    )
            else:
                psar_confirmed = True
                log.warning(f"{symbol}: trailing stop breached, no signal data — safety exit")

            if psar_confirmed:
                trail_pct = get_trailing_stop_pct(pnl_pct, tiers)
                return ExitDecision(
                    "full_sell",
                    f"trailing_stop_{trail_pct*100:.0f}pct_psar_confirmed",
                    total_qty,
                )

    update_trade_field(trade["_id"], {"trailing_stop": stop_level})

    # ── PRIORITY 6: Technical exits (runner phase) ────────────────────────────
    if phase == "runner":
        signals = ibkr.compute_exit_signals(symbol)
        if signals:
            if signals.get("psar_bearish") and signals.get("price_below_ema9"):
                return ExitDecision("full_sell", "psar_bearish_below_ema9", total_qty)
            if signals.get("ema_death_cross"):
                return ExitDecision("full_sell", "ema_9_21_death_cross", total_qty)

    # ── PRIORITY 7: Stale trade ───────────────────────────────────────────────
    if check_stale_trade(trade, pnl_pct):
        return ExitDecision("full_sell", "stale_trade_timeout", total_qty)

    # ── DEFAULT: Hold ─────────────────────────────────────────────────────────
    trail_pct = get_trailing_stop_pct(pnl_pct, tiers)
    log.info(
        f"{symbol}: HOLD | trail={trail_pct*100:.0f}% "
        f"stop=${stop_level:.4f} | phase={phase}"
    )
    return ExitDecision("hold", "holding", 0)


# ══════════════════════════════════════════════════════════════════════════════
# MAIN MONITOR LOOP
# ══════════════════════════════════════════════════════════════════════════════

def monitor_positions(ibkr: IBKRSellClient):
    log.info("=" * 60)
    log.info("SELL BOT v3.0 — Smart Position Manager")
    log.info("  Entry-type aware profit schedules: standard / momentum / pullback")
    log.info("  Liquidity crisis check: DISABLED")
    log.info("  Trail confirmation: PSAR bearish only")
    log.info("  Duplicate positions: auto-consolidated")
    log.info(f"Hard Stop: {HARD_STOP_PCT*100}% | Flash Exit: {'ENABLED' if ENABLE_FLASH_CRASH_EXIT else 'DISABLED (paper mode)'}")
    log.info(f"Schedules:")
    for etype, sched in PROFIT_SCHEDULE.items():
        p1 = sched.get("partial_1")
        p2 = sched.get("partial_2")
        p2_label = (f"{p2['threshold']*100:.0f}%→{p2['fraction']*100:.0f}% sell"
                    if p2 else "none")
        log.info(
            f"  {etype:10s}: "
            f"P1={p1['threshold']*100:.0f}%→{p1['fraction']*100:.0f}% sell | "
            f"P2={p2_label} | "
            f"trail={sched['runner_trail_tiers']}"
        )
    log.info(f"Cooldown: {REENTRY_COOLDOWN_MIN} min | "
             f"Stale: >{STALE_TRADE_HOURS}h in "
             f"[{STALE_TRADE_MIN_PNL*100}%,{STALE_TRADE_MAX_PNL*100}%]")
    log.info("=" * 60)

    while True:
        try:
            open_trades = get_open_trades()
            open_trades = consolidate_duplicate_positions(open_trades)
            log.info(f"--- Checking {len(open_trades)} open position(s) ---")

            for trade in open_trades:
                symbol    = trade.get("instrument") or trade.get("symbol")
                total_qty = trade.get("quantity") or trade.get("qty")

                if not symbol or not total_qty:
                    log.warning(f"Skipping trade {trade['_id']}: missing symbol or qty")
                    continue

                entry_price   = get_effective_entry_price(trade, ibkr)
                current_price = ibkr.get_last_price(symbol)
                if not current_price:
                    log.warning(f"{symbol}: no current price, skipping")
                    continue

                decision = evaluate_position(trade, current_price, entry_price, ibkr)

                if decision.action == "hold":
                    continue

                # ── Execute the decision ──────────────────────────────────────

                if decision.action == "emergency_sell":
                    exit_price, final_reason = emergency_exit(
                        ibkr, symbol, decision.qty_to_sell, decision.reason
                    )
                    close_trade(trade, exit_price, final_reason, decision.qty_to_sell)

                elif decision.action == "partial_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                             current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)
                    # Mark partial as taken so we don't re-trigger
                    if decision.partial_key:
                        update_trade_field(trade["_id"], {
                            f"{decision.partial_key}_taken": True,
                        })

                elif decision.action == "full_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                             current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

        except Exception as e:
            log.error(f"Monitor error: {e}", exc_info=True)

        time.sleep(MONITOR_INTERVAL)


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY POINT
# ══════════════════════════════════════════════════════════════════════════════

def main():
    log.info("=== Sell Bot v3.0 Starting ===")
    ibkr = IBKRSellClient()

    try:
        ibkr.connect()
        monitor_positions(ibkr)
    except KeyboardInterrupt:
        log.info("Sell bot stopped by user.")
    except Exception as e:
        log.error(f"Fatal error: {e}", exc_info=True)
    finally:
        ibkr.disconnect()
        log.info("IBKR disconnected.")


if __name__ == "__main__":
    main()
# Out:
# 2026-04-08 12:40:49,990 [INFO] === Sell Bot v3.0 Starting ===
# 2026-04-08 12:40:50,213 [INFO] IBKR connected | accounts: ['DUD087866']
# 2026-04-08 12:40:50,214 [INFO] ============================================================
# 2026-04-08 12:40:50,216 [INFO] SELL BOT v3.0 — Smart Position Manager
# 2026-04-08 12:40:50,217 [INFO]   Entry-type aware profit schedules: standard / momentum / pullback
# 2026-04-08 12:40:50,218 [INFO]   Liquidity crisis check: DISABLED
# 2026-04-08 12:40:50,219 [INFO]   Trail confirmation: PSAR bearish only
# 2026-04-08 12:40:50,220 [INFO]   Duplicate positions: auto-consolidated
# 2026-04-08 12:40:50,221 [INFO] Hard Stop: 12.0% | Flash Exit: DISABLED (paper mode)
# 2026-04-08 12:40:50,222 [INFO] Schedules:
# 2026-04-08 12:40:50,223 [INFO]   standard  : P1=50%→50% sell | P2=none | trail=[(1.5, 0.08), (1.0, 0.1), (0.75, 0.12), (0.5, 0.15)]
# 2026-04-08 12:40:50,224 [INFO]   momentum  : P1=30%→33% sell | P2=60%→50% sell | trail=[(1.0, 0.08), (0.75, 0.1), (0.5, 0.12)]
# 2026-04-08 12:40:50,225 [INFO]   pullback  : P1=25%→40% sell | P2=50%→33% sell | trail=[(1.5, 0.08), (1.0, 0.1), (0.75, 0.12), (0.5, 0.15)]
# 2026-04-08 12:40:50,225 [INFO] Cooldown: 30 min | Stale: >3h in [-5.0%,10.0%]
# 2026-04-08 12:40:50,226 [INFO] ============================================================
# 2026-04-08 12:40:50,232 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:41:20,236 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:41:50,239 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:42:20,242 [INFO] --- Checking 0 open position(s) ---
# 2026-04-08 12:42:50,245 [INFO] Sell bot stopped by user.
# 2026-04-08 12:42:50,248 [INFO] IBKR disconnected.

# %%
"""
Sell Bot v3.0 — Smart Position Manager
═══════════════════════════════════════════════════════════════════════════════
Monitors open positions via IBKR + MongoDB and exits them intelligently
using PSAR-confirmed trailing stops, tiered profit-taking, and emergency exits.

CHANGES from sell_bot_v2.3:
────────────────────────────
1. ENTRY-TYPE AWARE PROFIT SCHEDULE (Kimi proposal — PositionManager)
   - "standard"  (SMX/AIXI) : partial at +50%, runner with tiered trail
   - "momentum"  (FCUV)     : partial at +30%, partial at +60%, small runner
   - "pullback"  (KPRX)     : partial at +25%, partial at +50%, small runner

2. MULTI-PARTIAL TRACKING
   - partial_1_taken / partial_2_taken flags per trade doc
   - Remaining quantity correctly maintained across partial exits

3. RUNNER PROTECTION IMPROVEMENTS
   - Momentum runner: tighter trailing (10% tiers max)
   - Standard runner: existing PSAR-confirmed tiers

4. PRESERVED FROM v2.3:
   - Hard stop: -10% from entry
   - Flash crash: -5% drop in one interval → emergency exit
   - Tiered trailing: 8%–15% from high, PSAR-confirmed
   - Stale trade exit: >2h, PnL between -5% and +10%
   - Duplicate position consolidation
   - Re-entry cooldown (shared with buy bot)
   - Liquidity crisis check: REMOVED (was causing false exits)

EXIT STRATEGY SUMMARY:
──────────────────────
Phase 1 — PROTECTION (always active):
  Hard stop -10% | Flash crash -5%/interval

Phase 2 — PARTIAL PROFIT (by entry type):
  standard : +50% → sell 50%
  momentum : +30% → sell 33%, then +60% → sell 50% of remaining
  pullback : +25% → sell 40%, then +50% → sell 33% of remaining

Phase 3 — RUNNER (remaining shares):
  Trailing stop tiers (PSAR-confirmed):
    standard/pullback: +50-75→15%, +75-100→12%, +100-150→10%, +150+→8%
    momentum:          tighter — +50-75→12%, +75-100→10%, +100+→8%
  PSAR bearish + price below EMA9 → exit runner
  EMA9 death-crosses EMA21 → exit runner

Phase 4 — TIME DECAY:
  Position in [-5%, +10%] after 2h → exit
"""

import logging
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import random
from typing import Optional
from dataclasses import dataclass
from collections import defaultdict

from pymongo import MongoClient
from ib_insync import *

import warnings
warnings.filterwarnings("ignore")


# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ─── IBKR ────────────────────────────────────────────────────────────────────
IBKR_HOST      = "127.0.0.1"
IBKR_PORT      = 7497
IBKR_CLIENT_ID = random.randint(3000, 3999)   # Different range from scanner/buy bots

# ─── Emergency / Hard Protection ─────────────────────────────────────────────
HARD_STOP_PCT    = 0.12   # -12% from entry: wider stop in paper mode (was 0.10)
FLASH_CRASH_PCT  = 0.05   # -5% in one 30s interval: emergency
ENABLE_FLASH_CRASH_EXIT = False  # Disabled in paper mode — fewer premature exits

# ─── Profit Schedules by Entry Type (Kimi proposal) ──────────────────────────
PROFIT_SCHEDULE = {
    "standard": {
        # SMX/AIXI: let it run, single partial at 50%
        "partial_1": {"threshold": 0.50, "fraction": 0.50},
        "partial_2": None,
        "runner_trail_tiers": [
            (1.50, 0.08),   # +150%+  → trail 8%
            (1.00, 0.10),   # +100%+  → trail 10%
            (0.75, 0.12),   # +75%+   → trail 12%
            (0.50, 0.15),   # +50%+   → trail 15%
        ],
    },
    "momentum": {
        # FCUV: fast movers — take quick partials
        "partial_1": {"threshold": 0.30, "fraction": 0.33},
        "partial_2": {"threshold": 0.60, "fraction": 0.50},
        "runner_trail_tiers": [
            (1.00, 0.08),   # Tighter: +100%+ → 8%
            (0.75, 0.10),   # +75%+   → 10%
            (0.50, 0.12),   # +50%+   → 12%
        ],
    },
    "pullback": {
        # KPRX: conservative recovery play — quick initial profits
        "partial_1": {"threshold": 0.25, "fraction": 0.40},
        "partial_2": {"threshold": 0.50, "fraction": 0.33},
        "runner_trail_tiers": [
            (1.50, 0.08),
            (1.00, 0.10),
            (0.75, 0.12),
            (0.50, 0.15),
        ],
    },
}
DEFAULT_SCHEDULE    = PROFIT_SCHEDULE["standard"]
DEFAULT_TRAILING_PCT = 0.20    # Before first partial if somehow needed

# ─── Time Decay ───────────────────────────────────────────────────────────────
STALE_TRADE_HOURS   = 3    # Paper mode: give runners more room (was 2)
STALE_TRADE_MIN_PNL = -0.05
STALE_TRADE_MAX_PNL = 0.10

# ─── Technical Exit Signals ───────────────────────────────────────────────────
EMA_FAST_PERIOD = 9
EMA_SLOW_PERIOD = 21

# ─── Re-entry Cooldown ────────────────────────────────────────────────────────
REENTRY_COOLDOWN_MIN = 30

# ─── Monitoring ───────────────────────────────────────────────────────────────
MONITOR_INTERVAL  = 30   # seconds between position checks
EMERGENCY_TIMEOUT = 5    # seconds to wait for limit fill before market

# ─── MongoDB ──────────────────────────────────────────────────────────────────
MONGO_URI           = "mongodb://localhost:27017/"
DB_NAME             = "breakout_db"
TRADES_COL          = "trades_v2"
COOLDOWN_COL        = "cooldowns"


# ══════════════════════════════════════════════════════════════════════════════
# LOGGING
# ══════════════════════════════════════════════════════════════════════════════

class _Utf8SafeStreamHandler(logging.StreamHandler):
    def emit(self, record):
        try:
            super().emit(record)
        except UnicodeEncodeError:
            record.msg  = str(record.msg).encode("ascii", errors="replace").decode("ascii")
            record.args = ()
            try:
                super().emit(record)
            except Exception:
                self.handleError(record)

    def _try_utf8(self):
        try:
            if hasattr(self.stream, "reconfigure"):
                self.stream.reconfigure(encoding="utf-8", errors="replace")
        except Exception:
            pass


def _make_logger() -> logging.Logger:
    fmt = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
    sh  = _Utf8SafeStreamHandler(sys.stdout)
    sh._try_utf8()
    sh.setFormatter(fmt)
    fh  = logging.FileHandler("sell_bot.log", encoding="utf-8")
    fh.setFormatter(fmt)
    logger = logging.getLogger("sell_bot")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    logger.addHandler(sh)
    logger.addHandler(fh)
    logger.propagate = False
    return logger

log = _make_logger()


# ══════════════════════════════════════════════════════════════════════════════
# IBKR CLIENT
# ══════════════════════════════════════════════════════════════════════════════

class IBKRSellClient:
    def __init__(self):
        util.startLoop()
        self.ib = IB()

    def connect(self):
        self.ib.connect(IBKR_HOST, IBKR_PORT, clientId=IBKR_CLIENT_ID)
        log.info(f"IBKR connected | accounts: {self.ib.wrapper.accounts}")

    def disconnect(self):
        self.ib.disconnect()

    # ── Price helpers ─────────────────────────────────────────────────────────

    def get_last_price(self, symbol: str) -> Optional[float]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "106", False, False)
        self.ib.sleep(3)
        self.ib.cancelMktData(contract)
        for label, val in [("last", ticker.last), ("ask", ticker.ask),
                           ("bid", ticker.bid), ("close", ticker.close)]:
            if val and float(val) > 0:
                log.debug(f"{symbol}: price source='{label}' ${float(val):.4f}")
                return float(val)
        log.warning(f"{symbol}: no price available")
        return None

    def get_ticker(self, symbol: str) -> Ticker:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        ticker = self.ib.reqMktData(contract, "", False, False)
        self.ib.sleep(2)
        return ticker

    # ── Historical bars ───────────────────────────────────────────────────────

    def get_bars(self, symbol: str, n: int = 70) -> Optional[pd.DataFrame]:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        for what_to_show in ("TRADES", "MIDPOINT"):
            raw = self.ib.reqHistoricalData(
                contract,
                endDateTime="",
                durationStr="10 D",
                barSizeSetting="5 mins",
                whatToShow=what_to_show,
                useRTH=False,
                keepUpToDate=False,
            )
            if raw:
                df = pd.DataFrame([
                    {"open": b.open, "high": b.high, "low": b.low,
                     "close": b.close, "volume": getattr(b, "volume", 0)}
                    for b in raw
                ])
                return df.tail(n).reset_index(drop=True)
        log.warning(f"{symbol}: no bars returned")
        return None

    # ── Technical exit signals ────────────────────────────────────────────────

    def compute_exit_signals(self, symbol: str) -> dict:
        df = self.get_bars(symbol, n=70)
        if df is None or len(df) < 25:
            log.warning(f"{symbol}: not enough bars for exit signals")
            return {}

        psar_vals = self._compute_psar(df["high"].values, df["low"].values,
                                       df["close"].values)
        ema_fast = df["close"].ewm(span=EMA_FAST_PERIOD, adjust=False).mean()
        ema_slow = df["close"].ewm(span=EMA_SLOW_PERIOD, adjust=False).mean()

        price     = float(df["close"].iloc[-1])
        psar_now  = float(psar_vals[-1])
        ema9_now  = float(ema_fast.iloc[-1])
        ema21_now = float(ema_slow.iloc[-1])
        ema9_prev  = float(ema_fast.iloc[-2])
        ema21_prev = float(ema_slow.iloc[-2])

        psar_bearish     = psar_now > price
        ema_death_cross  = (ema9_prev >= ema21_prev) and (ema9_now < ema21_now)
        price_below_ema9 = price < ema9_now

        signals = {
            "price":             price,
            "psar":              psar_now,
            "ema_9":             ema9_now,
            "ema_21":            ema21_now,
            "psar_bearish":      psar_bearish,
            "ema_death_cross":   ema_death_cross,
            "price_below_ema9":  price_below_ema9,
        }

        log.info(
            f"{symbol} exit signals: PSAR={psar_now:.4f}({'BEAR' if psar_bearish else 'BULL'}) "
            f"EMA9={ema9_now:.4f} EMA21={ema21_now:.4f} "
            f"cross={'YES' if ema_death_cross else 'no'} "
            f"below9={'YES' if price_below_ema9 else 'no'}"
        )
        return signals

    @staticmethod
    def _compute_psar(highs, lows, closes, iaf=0.02, max_af=0.2) -> np.ndarray:
        n    = len(closes)
        psar = closes.copy().astype(float)
        bull = True
        af   = iaf
        hp   = float(highs[0])
        lp   = float(lows[0])

        for i in range(2, n):
            if bull:
                psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
                psar[i] = min(psar[i], lows[i - 1], lows[i - 2])
                if lows[i] < psar[i]:
                    bull = False; psar[i] = hp; lp = lows[i]; af = iaf
                else:
                    if highs[i] > hp:
                        hp = highs[i]; af = min(af + iaf, max_af)
            else:
                psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
                psar[i] = max(psar[i], highs[i - 1], highs[i - 2])
                if highs[i] > psar[i]:
                    bull = True; psar[i] = lp; hp = highs[i]; af = iaf
                else:
                    if lows[i] < lp:
                        lp = lows[i]; af = min(af + iaf, max_af)
        return psar

    # ── Order execution ───────────────────────────────────────────────────────

    def get_avg_fill_price_from_broker(self, symbol: str, order_id: int) -> Optional[float]:
        for trade in self.ib.trades():
            if (trade.contract.symbol == symbol
                    and trade.order.orderId == order_id
                    and trade.orderStatus.avgFillPrice > 0):
                return float(trade.orderStatus.avgFillPrice)

        fills   = self.ib.fills()
        matched = [f for f in fills
                   if f.contract.symbol == symbol and f.execution.orderId == order_id]
        if matched:
            total_qty  = sum(f.execution.shares for f in matched)
            total_cost = sum(f.execution.shares * f.execution.price for f in matched)
            return total_cost / total_qty

        return None

    def place_limit_sell(self, symbol: str, price: float, qty: int,
                         emergency: bool = False) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        if emergency:
            price = price * 0.99
        order = LimitOrder("SELL", qty, round(price, 2))
        order.outsideRth = True
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL LIMIT {symbol} x{qty} @ ${price:.2f} "
                 f"orderId={trade.order.orderId} emergency={emergency}")
        return trade

    def place_market_sell(self, symbol: str, qty: int) -> Trade:
        contract = Stock(symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        order = MarketOrder("SELL", qty)
        trade = self.ib.placeOrder(contract, order)
        self.ib.sleep(1)
        log.info(f"SELL MARKET {symbol} x{qty} orderId={trade.order.orderId}")
        return trade

    def get_sell_fill_price(self, symbol: str, sell_order_id: int,
                            fallback_price: float) -> float:
        self.ib.sleep(3)
        avg = self.get_avg_fill_price_from_broker(symbol, sell_order_id)
        if avg:
            return avg
        log.warning(f"{symbol}: sell fill not confirmed, using fallback ${fallback_price:.4f}")
        return fallback_price


# ══════════════════════════════════════════════════════════════════════════════
# MONGODB HELPERS
# ══════════════════════════════════════════════════════════════════════════════

mongo_client       = MongoClient(MONGO_URI)
db                 = mongo_client[DB_NAME]
trades_collection  = db[TRADES_COL]
cooldown_collection = db[COOLDOWN_COL]


def get_open_trades() -> list:
    return list(trades_collection.find({"status": "open"}))


def get_effective_entry_price(trade: dict, ibkr: IBKRSellClient) -> float:
    if trade.get("avg_fill_price"):
        return float(trade["avg_fill_price"])
    order_id = trade.get("order_id")
    symbol   = trade.get("instrument") or trade.get("symbol")
    if order_id:
        try:
            broker_avg = ibkr.get_avg_fill_price_from_broker(symbol, int(order_id))
        except (ValueError, TypeError):
            broker_avg = None
        if broker_avg:
            trades_collection.update_one(
                {"_id": trade["_id"]},
                {"$set": {"avg_fill_price": broker_avg, "entry_price": broker_avg}},
            )
            return broker_avg
    return float(trade["entry_price"])


def update_trade_field(trade_id, updates: dict):
    updates["updated_at"] = datetime.now(timezone.utc)
    trades_collection.update_one({"_id": trade_id}, {"$set": updates})


def get_profit_schedule(trade: dict) -> dict:
    """Return the correct profit schedule based on entry_type."""
    entry_type = trade.get("entry_type", "standard")
    return PROFIT_SCHEDULE.get(entry_type, DEFAULT_SCHEDULE)


def close_trade(trade: dict, exit_price: float, reason: str, qty_sold: int = None):
    symbol      = trade.get("instrument") or trade.get("symbol")
    entry_price = float(trade.get("avg_fill_price") or trade["entry_price"])
    total_qty   = trade.get("quantity") or trade.get("qty")
    pnl_pct     = (exit_price - entry_price) / (entry_price + 1e-9)

    if qty_sold is None:
        qty_sold = total_qty

    realized_pnl = (exit_price - entry_price) * qty_sold

    if qty_sold >= total_qty:
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "status":         "closed",
                "exit_price":     exit_price,
                "exit_timestamp": datetime.now(timezone.utc),
                "reason":         reason,
                "pnl_pct":        round(pnl_pct * 100, 2),
                "realized_pnl":   realized_pnl,
                "updated_at":     datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"CLOSED {symbol} | entry=${entry_price:.4f} exit=${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | reason={reason}"
        )
        set_cooldown(symbol, reason)
    else:
        remaining = total_qty - qty_sold
        trades_collection.update_one(
            {"_id": trade["_id"]},
            {"$set": {
                "quantity":              remaining,
                "partial_exit_price":    exit_price,
                "partial_exit_qty":      qty_sold,
                "partial_exit_time":     datetime.now(timezone.utc),
                "partial_exit_reason":   reason,
                "partial_realized_pnl":  realized_pnl,
                "phase":                 "runner",
                "updated_at":            datetime.now(timezone.utc),
            }},
        )
        log.info(
            f"PARTIAL CLOSE {symbol} | sold {qty_sold}/{total_qty} @ ${exit_price:.4f} "
            f"pnl={pnl_pct * 100:+.2f}% | ${realized_pnl:+.2f} | "
            f"remaining={remaining} shares → runner mode"
        )


# ══════════════════════════════════════════════════════════════════════════════
# POSITION CONSOLIDATION  (preserved from v2.3)
# ══════════════════════════════════════════════════════════════════════════════

def consolidate_duplicate_positions(open_trades: list) -> list:
    by_symbol = defaultdict(list)
    for t in open_trades:
        sym = t.get("instrument") or t.get("symbol")
        if sym:
            by_symbol[sym].append(t)

    consolidated = []
    for sym, trades in by_symbol.items():
        if len(trades) == 1:
            consolidated.append(trades[0])
            continue

        log.warning(f"{sym}: CONSOLIDATING {len(trades)} duplicate open trades into 1")

        total_qty  = 0
        total_cost = 0.0
        earliest_ts = None
        highest     = 0.0
        keep_trade  = None

        for t in trades:
            qty   = t.get("quantity") or t.get("qty") or 0
            entry = float(t.get("avg_fill_price") or t.get("entry_price") or 0)
            total_qty  += qty
            total_cost += qty * entry

            ts = t.get("entry_timestamp")
            if ts and (earliest_ts is None or ts < earliest_ts):
                earliest_ts = ts

            h = t.get("highest_price", entry)
            if h > highest:
                highest = h

            if keep_trade is None:
                keep_trade = t
            else:
                trades_collection.update_one(
                    {"_id": t["_id"]},
                    {"$set": {"status": "merged", "merged_into": keep_trade["_id"],
                              "updated_at": datetime.now(timezone.utc)}},
                )
                log.info(f"{sym}: merged trade {t['_id']} into {keep_trade['_id']}")

        avg_entry = total_cost / total_qty if total_qty > 0 else 0
        updates = {
            "quantity":           total_qty,
            "avg_fill_price":     avg_entry,
            "entry_price":        avg_entry,
            "highest_price":      highest,
            "consolidated":       True,
            "consolidated_count": len(trades),
        }
        if earliest_ts:
            updates["entry_timestamp"] = earliest_ts

        update_trade_field(keep_trade["_id"], updates)
        keep_trade["quantity"]       = total_qty
        keep_trade["avg_fill_price"] = avg_entry
        keep_trade["entry_price"]    = avg_entry
        keep_trade["highest_price"]  = highest

        log.info(f"{sym}: CONSOLIDATED → {total_qty} shares @ avg ${avg_entry:.4f}")
        consolidated.append(keep_trade)

    return consolidated


# ══════════════════════════════════════════════════════════════════════════════
# RE-ENTRY COOLDOWN
# ══════════════════════════════════════════════════════════════════════════════

def set_cooldown(symbol: str, reason: str):
    expires_at = datetime.now(timezone.utc) + timedelta(minutes=REENTRY_COOLDOWN_MIN)
    cooldown_collection.update_one(
        {"symbol": symbol},
        {"$set": {
            "symbol":       symbol,
            "reason":       reason,
            "closed_at":    datetime.now(timezone.utc),
            "expires_at":   expires_at,
            "cooldown_min": REENTRY_COOLDOWN_MIN,
        }},
        upsert=True,
    )
    log.info(
        f"{symbol}: COOLDOWN SET — no re-entry for {REENTRY_COOLDOWN_MIN} min "
        f"(until {expires_at.strftime('%H:%M:%S')} UTC) | close reason: {reason}"
    )


# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def get_trailing_stop_pct(pnl_pct: float, tiers: list) -> float:
    for threshold, trail in tiers:
        if pnl_pct >= threshold:
            return trail
    return DEFAULT_TRAILING_PCT


def compute_trailing_stop(entry_price: float, highest_price: float,
                          current_pnl_pct: float, tiers: list) -> float:
    trail_pct  = get_trailing_stop_pct(current_pnl_pct, tiers)
    trail_stop = highest_price * (1 - trail_pct)
    hard_stop  = entry_price * (1 - HARD_STOP_PCT)
    return max(trail_stop, hard_stop)


def check_flash_crash(symbol: str, current_price: float, trade: dict) -> Optional[str]:
    last_price = trade.get("last_price")
    update_trade_field(trade["_id"], {
        "last_price":      current_price,
        "last_price_time": datetime.now(timezone.utc),
    })
    if last_price and last_price > 0:
        drop_pct = (current_price - last_price) / last_price
        if drop_pct <= -FLASH_CRASH_PCT:
            log.warning(f"{symbol}: FLASH CRASH {drop_pct * 100:.2f}% in {MONITOR_INTERVAL}s")
            return f"flash_crash_{abs(drop_pct) * 100:.1f}pct"
    return None


def check_stale_trade(trade: dict, pnl_pct: float) -> bool:
    entry_time = trade.get("entry_timestamp")
    if not entry_time:
        return False
    if entry_time.tzinfo is None:
        hours_held = (datetime.now() - entry_time).total_seconds() / 3600
    else:
        hours_held = (datetime.now(timezone.utc) - entry_time).total_seconds() / 3600

    if hours_held >= STALE_TRADE_HOURS:
        if STALE_TRADE_MIN_PNL <= pnl_pct <= STALE_TRADE_MAX_PNL:
            log.info(
                f"{trade.get('instrument') or trade.get('symbol')}: "
                f"stale trade — {hours_held:.1f}h held, pnl={pnl_pct * 100:+.2f}%"
            )
            return True
    return False


# ══════════════════════════════════════════════════════════════════════════════
# EMERGENCY EXIT
# ══════════════════════════════════════════════════════════════════════════════

def emergency_exit(ibkr: IBKRSellClient, symbol: str, qty: int,
                   reason: str) -> tuple[float, str]:
    log.warning(f"{symbol}: EMERGENCY EXIT — {reason}")
    ticker      = ibkr.get_ticker(symbol)
    current_bid = ticker.bid or ticker.last or ticker.close

    if not current_bid:
        log.error(f"{symbol}: no price for emergency exit!")
        return 0.0, "exit_failed_no_price"

    trade    = ibkr.place_limit_sell(symbol, current_bid, qty, emergency=True)
    order_id = trade.order.orderId

    for _ in range(EMERGENCY_TIMEOUT):
        ibkr.ib.sleep(1)
        fill = ibkr.get_avg_fill_price_from_broker(symbol, order_id)
        if fill:
            log.info(f"{symbol}: emergency limit filled @ ${fill:.4f}")
            return fill, reason

    log.warning(f"{symbol}: limit not filled in {EMERGENCY_TIMEOUT}s → MARKET")
    try:
        ibkr.ib.cancelOrder(trade.order)
    except Exception:
        pass

    market_trade = ibkr.place_market_sell(symbol, qty)
    ibkr.ib.sleep(2)
    fill = ibkr.get_avg_fill_price_from_broker(symbol, market_trade.order.orderId)
    if fill:
        return fill, f"{reason}_market"

    return current_bid * 0.98, f"{reason}_estimated"


# ══════════════════════════════════════════════════════════════════════════════
# EXIT DECISION ENGINE
# ══════════════════════════════════════════════════════════════════════════════

@dataclass
class ExitDecision:
    action:      str   # "hold" | "partial_sell" | "full_sell" | "emergency_sell"
    reason:      str
    qty_to_sell: int = 0
    partial_key: str = ""  # "partial_1" | "partial_2" (for flag tracking)


def evaluate_position(trade: dict, current_price: float, entry_price: float,
                      ibkr: IBKRSellClient) -> ExitDecision:
    """
    Master exit logic — evaluates all conditions in priority order.
    v3.0: entry-type aware profit schedule.
    """
    symbol    = trade.get("instrument") or trade.get("symbol")
    total_qty = trade.get("quantity") or trade.get("qty")
    highest   = trade.get("highest_price", entry_price)
    phase     = trade.get("phase", "initial")
    pnl_pct   = (current_price - entry_price) / (entry_price + 1e-9)

    # Track new high
    if current_price > highest:
        highest = current_price
        update_trade_field(trade["_id"], {"highest_price": highest})

    drawdown_from_high = (current_price - highest) / (highest + 1e-9)
    schedule = get_profit_schedule(trade)
    tiers    = schedule["runner_trail_tiers"]

    log.info(
        f"{symbol}: phase={phase} | entry=${entry_price:.4f} now=${current_price:.4f} "
        f"pnl={pnl_pct * 100:+.2f}% | high=${highest:.4f} dd={drawdown_from_high * 100:.2f}% "
        f"qty={total_qty} | type={trade.get('entry_type','standard')}"
    )

    # ── PRIORITY 1: Hard stop ─────────────────────────────────────────────────
    if pnl_pct <= -HARD_STOP_PCT:
        return ExitDecision("emergency_sell", "hard_stop_10pct", total_qty)

    # ── PRIORITY 2: Flash crash ───────────────────────────────────────────────
    if ENABLE_FLASH_CRASH_EXIT:
        flash = check_flash_crash(symbol, current_price, trade)
        if flash:
            return ExitDecision("emergency_sell", flash, total_qty)
    else:
        # Still track last_price even when flash exit is disabled
        check_flash_crash(symbol, current_price, trade)

    # ── PRIORITY 3: Partial profit — level 1 ─────────────────────────────────
    p1 = schedule.get("partial_1")
    if p1 and not trade.get("partial_1_taken", False):
        if pnl_pct >= p1["threshold"]:
            sell_qty = max(1, int(total_qty * p1["fraction"]))
            if sell_qty >= total_qty:
                return ExitDecision("full_sell", f"full_profit_p1_{pnl_pct*100:.1f}pct",
                                    total_qty, "partial_1")
            return ExitDecision("partial_sell", f"partial_1_{pnl_pct*100:.1f}pct",
                                sell_qty, "partial_1")

    # ── PRIORITY 4: Partial profit — level 2 (momentum/pullback) ─────────────
    p2 = schedule.get("partial_2")
    if p2 and not trade.get("partial_2_taken", False) and trade.get("partial_1_taken", False):
        if pnl_pct >= p2["threshold"]:
            sell_qty = max(1, int(total_qty * p2["fraction"]))
            if sell_qty >= total_qty:
                return ExitDecision("full_sell", f"full_profit_p2_{pnl_pct*100:.1f}pct",
                                    total_qty, "partial_2")
            return ExitDecision("partial_sell", f"partial_2_{pnl_pct*100:.1f}pct",
                                sell_qty, "partial_2")

    # ── PRIORITY 5: Trailing stop (PSAR-confirmed) ────────────────────────────
    stop_level = compute_trailing_stop(entry_price, highest, pnl_pct, tiers)

    if stop_level > entry_price * (1 - HARD_STOP_PCT):
        if current_price <= stop_level:
            signals       = ibkr.compute_exit_signals(symbol)
            psar_confirmed = False

            if signals:
                if signals.get("psar_bearish"):
                    psar_confirmed = True
                    log.info(
                        f"{symbol}: trailing stop CONFIRMED — PSAR bearish "
                        f"(PSAR={signals.get('psar', 0):.4f} > price={current_price:.4f})"
                    )
                else:
                    log.info(
                        f"{symbol}: trailing stop breached (${stop_level:.4f}) "
                        f"but PSAR still bullish — HOLDING through pullback"
                    )
            else:
                psar_confirmed = True
                log.warning(f"{symbol}: trailing stop breached, no signal data — safety exit")

            if psar_confirmed:
                trail_pct = get_trailing_stop_pct(pnl_pct, tiers)
                return ExitDecision(
                    "full_sell",
                    f"trailing_stop_{trail_pct*100:.0f}pct_psar_confirmed",
                    total_qty,
                )

    update_trade_field(trade["_id"], {"trailing_stop": stop_level})

    # ── PRIORITY 6: Technical exits (runner phase) ────────────────────────────
    if phase == "runner":
        signals = ibkr.compute_exit_signals(symbol)
        if signals:
            if signals.get("psar_bearish") and signals.get("price_below_ema9"):
                return ExitDecision("full_sell", "psar_bearish_below_ema9", total_qty)
            if signals.get("ema_death_cross"):
                return ExitDecision("full_sell", "ema_9_21_death_cross", total_qty)

    # ── PRIORITY 7: Stale trade ───────────────────────────────────────────────
    if check_stale_trade(trade, pnl_pct):
        return ExitDecision("full_sell", "stale_trade_timeout", total_qty)

    # ── DEFAULT: Hold ─────────────────────────────────────────────────────────
    trail_pct = get_trailing_stop_pct(pnl_pct, tiers)
    log.info(
        f"{symbol}: HOLD | trail={trail_pct*100:.0f}% "
        f"stop=${stop_level:.4f} | phase={phase}"
    )
    return ExitDecision("hold", "holding", 0)


# ══════════════════════════════════════════════════════════════════════════════
# MAIN MONITOR LOOP
# ══════════════════════════════════════════════════════════════════════════════

def monitor_positions(ibkr: IBKRSellClient):
    log.info("=" * 60)
    log.info("SELL BOT v3.0 — Smart Position Manager")
    log.info("  Entry-type aware profit schedules: standard / momentum / pullback")
    log.info("  Liquidity crisis check: DISABLED")
    log.info("  Trail confirmation: PSAR bearish only")
    log.info("  Duplicate positions: auto-consolidated")
    log.info(f"Hard Stop: {HARD_STOP_PCT*100}% | Flash Exit: {'ENABLED' if ENABLE_FLASH_CRASH_EXIT else 'DISABLED (paper mode)'}")
    log.info(f"Schedules:")
    for etype, sched in PROFIT_SCHEDULE.items():
        p1 = sched.get("partial_1")
        p2 = sched.get("partial_2")
        p2_label = (f"{p2['threshold']*100:.0f}%→{p2['fraction']*100:.0f}% sell"
                    if p2 else "none")
        log.info(
            f"  {etype:10s}: "
            f"P1={p1['threshold']*100:.0f}%→{p1['fraction']*100:.0f}% sell | "
            f"P2={p2_label} | "
            f"trail={sched['runner_trail_tiers']}"
        )
    log.info(f"Cooldown: {REENTRY_COOLDOWN_MIN} min | "
             f"Stale: >{STALE_TRADE_HOURS}h in "
             f"[{STALE_TRADE_MIN_PNL*100}%,{STALE_TRADE_MAX_PNL*100}%]")
    log.info("=" * 60)

    while True:
        try:
            open_trades = get_open_trades()
            open_trades = consolidate_duplicate_positions(open_trades)
            log.info(f"--- Checking {len(open_trades)} open position(s) ---")

            for trade in open_trades:
                symbol    = trade.get("instrument") or trade.get("symbol")
                total_qty = trade.get("quantity") or trade.get("qty")

                if not symbol or not total_qty:
                    log.warning(f"Skipping trade {trade['_id']}: missing symbol or qty")
                    continue

                entry_price   = get_effective_entry_price(trade, ibkr)
                current_price = ibkr.get_last_price(symbol)
                if not current_price:
                    log.warning(f"{symbol}: no current price, skipping")
                    continue

                decision = evaluate_position(trade, current_price, entry_price, ibkr)

                if decision.action == "hold":
                    continue

                # ── Execute the decision ──────────────────────────────────────

                if decision.action == "emergency_sell":
                    exit_price, final_reason = emergency_exit(
                        ibkr, symbol, decision.qty_to_sell, decision.reason
                    )
                    close_trade(trade, exit_price, final_reason, decision.qty_to_sell)

                elif decision.action == "partial_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                             current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)
                    # Mark partial as taken so we don't re-trigger
                    if decision.partial_key:
                        update_trade_field(trade["_id"], {
                            f"{decision.partial_key}_taken": True,
                        })

                elif decision.action == "full_sell":
                    sell_trade    = ibkr.place_limit_sell(symbol, current_price,
                                                          decision.qty_to_sell)
                    sell_order_id = sell_trade.order.orderId
                    confirmed     = ibkr.get_sell_fill_price(symbol, sell_order_id,
                                                             current_price)
                    close_trade(trade, confirmed, decision.reason, decision.qty_to_sell)

        except Exception as e:
            log.error(f"Monitor error: {e}", exc_info=True)

        time.sleep(MONITOR_INTERVAL)


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY POINT
# ══════════════════════════════════════════════════════════════════════════════

def main():
    log.info("=== Sell Bot v3.0 Starting ===")
    ibkr = IBKRSellClient()

    try:
        ibkr.connect()
        monitor_positions(ibkr)
    except KeyboardInterrupt:
        log.info("Sell bot stopped by user.")
    except Exception as e:
        log.error(f"Fatal error: {e}", exc_info=True)
    finally:
        ibkr.disconnect()
        log.info("IBKR disconnected.")


if __name__ == "__main__":
    main()
# Out:
# 2026-04-08 12:42:50,373 [INFO] === Sell Bot v3.0 Starting ===
# 2026-04-08 12:42:50,623 [INFO] IBKR connected | accounts: ['DUD087866']
# 2026-04-08 12:42:50,624 [INFO] ============================================================
# 2026-04-08 12:42:50,624 [INFO] SELL BOT v3.0 — Smart Position Manager
# 2026-04-08 12:42:50,625 [INFO]   Entry-type aware profit schedules: standard / momentum / pullback
# 2026-04-08 12:42:50,626 [INFO]   Liquidity crisis check: DISABLED
# 2026-04-08 12:42:50,627 [INFO]   Trail confirmation: PSAR bearish only
# 2026-04-08 12:42:50,628 [INFO]   Duplicate positions: auto-consolidated
# 2026-04-08 12:42:50,628 [INFO] Hard Stop: 12.0% | Flash Exit: DISABLED (paper mode)
# 2026-04-08 12:42:50,629 [INFO] Schedules:
# 2026-04-08 12:42:50,630 [INFO]   standard  : P1=50%→50% sell | P2=none | trail=[(1.5, 0.08), (1.0, 0.1), (0.75, 0.12), (0.5, 0.15)]
# 2026-04-08 12:42:50,631 [INFO]   momentum  : P1=30%→33% sell | P2=60%→50% sell | trail=[(1.0, 0.08), (0.75, 0.1), (0.5, 0.12)]
# 2026-04-08 12:42:50,632 [INFO]   pullback  : P1=25%→40% sell | P2=50%→33% sell | trail=[(1.5, 0.08), (1.0, 0.1), (0.75, 0.12), (0.5, 0.15)]
# 2026-04-08 12:42:50,633 [INFO] Cooldown: 30 min | Stale: >3h in [-5.0%,10.0%]
# 2026-04-08 12:42:50,634 [INFO] ============================================================
# 2026-04-08 12:42:50,639 [INFO] --- Checking 0 open position(s) ---
