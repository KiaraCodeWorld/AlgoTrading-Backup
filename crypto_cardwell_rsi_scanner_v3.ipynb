# %%
# ══════════════════════════════════════════════════════════════════════════════
# INSTALL DEPENDENCIES (run once)
# ══════════════════════════════════════════════════════════════════════════════
import subprocess
for pkg in ['ccxt', 'pymongo', 'pandas', 'numpy', 'colorama', 'tabulate', 'coinbase-advanced-py']:
    subprocess.run(['pip', 'install', pkg, '-q'], check=False)

# ══════════════════════════════════════════════════════════════════════════════
# IMPORTS
# ══════════════════════════════════════════════════════════════════════════════
import time
import warnings
from datetime import datetime, date
from typing import Optional, Tuple

import numpy as np
import pandas as pd
from tabulate import tabulate
from colorama import Fore, Style, init
import ccxt
from pymongo import MongoClient, ASCENDING, DESCENDING
from bson import ObjectId

warnings.filterwarnings('ignore')
init(autoreset=True)
pd.set_option('display.max_rows', 50)
pd.set_option('display.float_format', '{:.6f}'.format)

# ══════════════════════════════════════════════════════════════════════════════
# API CREDENTIALS  ← replace with your own keys
# ══════════════════════════════════════════════════════════════════════════════
COINBASE_API_KEY    = "organizations/27c7ea7f-aced-429b-9667-56bf6ecc5e46/apiKeys/a1154fe6-dfd7-41fc-810a-023e8ad8da09"
COINBASE_API_SECRET = "-----BEGIN EC PRIVATE KEY-----\nMHcCAQEEIECQRBH0VqpXsTTneRLvc6dkFT1sx/uk+wBB6XQzY9zzoAoGCCqGSM49\nAwEHoUQDQgAE1T4Dp+EnQ4dfGnwsv6XRKEbVRPPlmwsleFYkOjGwr6x1LxR0zyx0\nBz9GtqjuFigGz4kIjiMYkVFIy0Ls4vzoSg==\n-----END EC PRIVATE KEY-----\n"

# ══════════════════════════════════════════════════════════════════════════════
# MONGODB
# ══════════════════════════════════════════════════════════════════════════════
MONGO_URI = 'mongodb://localhost:27017/'
DB_NAME   = 'cardwell_crypto_db'

# ══════════════════════════════════════════════════════════════════════════════
# UNIVERSE FILTERS
# ══════════════════════════════════════════════════════════════════════════════
QUOTE_CURRENCIES   = ['USD', 'USDT', 'USDC']
MIN_24H_VOLUME_USD = 500_000
MAX_PAIRS_TO_SCAN  = 100

# ══════════════════════════════════════════════════════════════════════════════
# TIMEFRAMES  (v2: multi-TF)
# ══════════════════════════════════════════════════════════════════════════════
TIMEFRAME      = '15m'
HIGHER_TF      = '1h'   # NEW: intermediate confirmation
DAILY_TF       = '1d'   # NEW: daily trend filter
CANDLES_NEEDED = 400    # increased from 300 for EMA-200

# ══════════════════════════════════════════════════════════════════════════════
# RSI CARDWELL — v2 OPTIMISED PARAMETERS
# ══════════════════════════════════════════════════════════════════════════════
RSI_PERIOD     = 14
TREND_LOOKBACK = 50
REGIME_PCT     = 0.75   # NEW: 75% of bars must be in regime (was 70%)

UP_RSI_FLOOR    = 40    # Cardwell bullish regime: RSI oscillates 40–80
UP_RSI_CEIL     = 80

LONG_ENTRY_LOW  = 42    # TIGHTENED from 40
LONG_ENTRY_HIGH = 48    # TIGHTENED from 50
LONG_EXIT_RSI   = 70    # RAISED from 68 — let crypto trends run

MIN_SIGNAL_SCORE   = 75   # NEW: minimum score gate
VOL_FILTER_ATR_MULT = 1.2 # NEW: ATR must be contracting vs 20-bar avg

# ══════════════════════════════════════════════════════════════════════════════
# INDICATORS
# ══════════════════════════════════════════════════════════════════════════════
EMA_PERIOD        = 50
EMA_TREND_PERIOD  = 200  # NEW: long-term trend anchor
VOLUME_MA_PERIOD  = 20
ATR_PERIOD        = 14

# ══════════════════════════════════════════════════════════════════════════════
# RISK MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════
PAPER_CAPITAL           = 10_000.0
RISK_PER_TRADE_PCT      = 0.01        # 1% risk per trade
REWARD_TO_RISK_RATIO    = 2.0         # 1:2 R:R
STOP_LOSS_ATR_MULT      = 1.5
MAX_SIMULTANEOUS_TRADES = 5
TAKER_FEE_PCT           = 0.0060      # 0.60% Coinbase taker fee

HARD_STOP_LOSS_USD        = -(PAPER_CAPITAL * RISK_PER_TRADE_PCT)
BREAKEVEN_ARM_PNL         = PAPER_CAPITAL * RISK_PER_TRADE_PCT * 1.0
BREAKEVEN_EXIT_PNL        = 0.0
LOCK_PROFIT_ARM_PNL       = PAPER_CAPITAL * RISK_PER_TRADE_PCT * 1.5
LOCK_PROFIT_EXIT_PNL      = PAPER_CAPITAL * RISK_PER_TRADE_PCT * 0.5
TRAILING_ARM_PNL          = PAPER_CAPITAL * RISK_PER_TRADE_PCT * 1.5
TRAILING_GIVEBACK_DOLLARS = PAPER_CAPITAL * RISK_PER_TRADE_PCT * 1.0

# ══════════════════════════════════════════════════════════════════════════════
# SCAN LOOP
# ══════════════════════════════════════════════════════════════════════════════
SCAN_INTERVAL_SECONDS = 300

# ══════════════════════════════════════════════════════════════════════════════
# DATABASE + EXCHANGE CONNECTION
# ══════════════════════════════════════════════════════════════════════════════
mongo_client    = MongoClient(MONGO_URI)
db              = mongo_client[DB_NAME]
trades_col      = db['trades_cardwell_rsi_crypto_v3']
signals_col     = db['signals_cardwell_rsi_crypto_v3']
exclude_col     = db['excluded_pairs_cardwell_rsi_crypto_v3']
performance_col = db['performance_cardwell_rsi_crypto_v3']

trades_col.create_index([('instrument', ASCENDING), ('status', ASCENDING)])
signals_col.create_index([('pair', ASCENDING), ('timestamp', DESCENDING)])
exclude_col.create_index([('pair', ASCENDING), ('date', ASCENDING)], unique=True)

exchange = ccxt.coinbase({
    'apiKey':  COINBASE_API_KEY,
    'secret':  COINBASE_API_SECRET,
    'options': {'defaultType': 'spot'},
    'enableRateLimit': True,
})
exchange.load_markets()

print(f'{Fore.GREEN}✅ MongoDB connected → {DB_NAME}')
print(f'✅ Coinbase connected — {len(exchange.markets)} markets loaded.{Style.RESET_ALL}')
print(f'{Fore.CYAN}📋 Capital: ${PAPER_CAPITAL:,.0f}  |  Risk/trade: {RISK_PER_TRADE_PCT*100:.1f}%  |  '
      f'Hard stop: ${HARD_STOP_LOSS_USD:.0f}  |  Timeframe: {TIMEFRAME}{Style.RESET_ALL}')
print(f'{Fore.CYAN}🔍 Multi-TF: {TIMEFRAME} + {HIGHER_TF} + {DAILY_TF}  |  '
      f'Min score: {MIN_SIGNAL_SCORE}  |  EMA filters: EMA-{EMA_PERIOD} + EMA-{EMA_TREND_PERIOD}{Style.RESET_ALL}')

# ══════════════════════════════════════════════════════════════════════════════
# MONGO HELPERS
# ══════════════════════════════════════════════════════════════════════════════

def sanitize_for_mongo(d: dict) -> dict:
    """Recursively convert numpy types → native Python."""
    out = {}
    for k, v in d.items():
        if isinstance(v, dict):
            out[k] = sanitize_for_mongo(v)
        elif isinstance(v, (np.integer,)):
            out[k] = int(v)
        elif isinstance(v, (np.floating,)):
            out[k] = float(v)
        elif isinstance(v, np.bool_):
            out[k] = bool(v)
        elif hasattr(v, 'item'):
            out[k] = v.item()
        else:
            out[k] = v
    return out


def to_object_id(value) -> ObjectId:
    return value if isinstance(value, ObjectId) else ObjectId(value)


def db_update_trade(trade_id, updates: dict):
    updates['updated_at'] = datetime.now()
    trades_col.update_one({'_id': to_object_id(trade_id)}, {'$set': updates})


def create_trade_doc(pair, entry_price, qty, stop_price, tp_price,
                     rsi_at_entry, regime, ema50, atr, signal_score,
                     ema200=None, higher_regime='UPTREND', reversal=False) -> dict:
    ep  = float(entry_price)
    fee = round(ep * float(qty) * TAKER_FEE_PCT, 6)
    return {
        'instrument':              pair,
        'direction':               'long',
        'entry_price':             ep,
        'quantity':                float(qty),
        'remaining_qty':           float(qty),
        'position_value_at_entry': round(ep * float(qty), 4),
        'stop_price':              float(stop_price),
        'take_profit_price':       float(tp_price),
        'entry_fee_usd':           fee,
        'rsi_at_entry':            float(rsi_at_entry),
        'regime_at_entry':         regime,
        'ema50_at_entry':          float(ema50),
        'ema200_at_entry':         float(ema200) if ema200 is not None else None,  # NEW
        'higher_regime':           higher_regime,                                  # NEW
        'positive_reversal':       bool(reversal),                                 # NEW
        'atr_at_entry':            float(atr),
        'signal_score':            float(signal_score),
        'entry_timestamp':         datetime.now(),
        'order_id':                str(ObjectId()),
        # Live mark-to-market
        'current_price':           ep,
        'current_pnl':             0.0,
        'current_pnl_pct':         0.0,
        'peak_price':              ep,
        'trough_price':            ep,
        'max_unrealized_pnl':      0.0,
        'min_unrealized_pnl':      0.0,
        'last_mark_timestamp':     datetime.now(),
        # Risk rules snapshot
        'risk_rules': {
            'hard_stop_loss_usd':        HARD_STOP_LOSS_USD,
            'breakeven_arm_pnl':         BREAKEVEN_ARM_PNL,
            'breakeven_exit_pnl':        BREAKEVEN_EXIT_PNL,
            'lock_profit_arm_pnl':       LOCK_PROFIT_ARM_PNL,
            'lock_profit_exit_pnl':      LOCK_PROFIT_EXIT_PNL,
            'trailing_arm_pnl':          TRAILING_ARM_PNL,
            'trailing_giveback_dollars': TRAILING_GIVEBACK_DOLLARS,
            'stop_loss_atr_mult':        STOP_LOSS_ATR_MULT,
            'reward_to_risk':            REWARD_TO_RISK_RATIO,
            'taker_fee_pct':             TAKER_FEE_PCT,
        },
        # Exit fields
        'exit_price':     None,
        'exit_timestamp': None,
        'exit_rsi':       None,
        'exit_reason':    None,
        'realized_pnl':   None,
        'exit_fee_usd':   None,
        'net_pnl':        None,
        'status':         'open',
        'created_at':     datetime.now(),
        'updated_at':     datetime.now(),
    }


def log_signal(pair, signal_type, price, rsi, score, indicators):
    signals_col.insert_one(sanitize_for_mongo({
        'pair':       pair,
        'signal':     signal_type,
        'price':      float(price),
        'rsi':        float(rsi),
        'score':      float(score),
        'indicators': indicators,
        'timeframe':  TIMEFRAME,
        'timestamp':  datetime.now(),
    }))
# ══════════════════════════════════════════════════════════════════════════════
# INDICATORS
# ══════════════════════════════════════════════════════════════════════════════

def calc_rsi(series: pd.Series, period: int = RSI_PERIOD) -> pd.Series:
    """Wilder-smoothed RSI."""
    delta = series.diff()
    gain  = delta.clip(lower=0).ewm(alpha=1/period, adjust=False, min_periods=period).mean()
    loss  = (-delta.clip(upper=0)).ewm(alpha=1/period, adjust=False, min_periods=period).mean()
    rs    = gain / (loss + 1e-10)
    return 100 - (100 / (1 + rs))


def calc_atr(df: pd.DataFrame, period: int = ATR_PERIOD) -> pd.Series:
    high, low, close = df['high'], df['low'], df['close']
    tr = pd.concat([
        high - low,
        (high - close.shift()).abs(),
        (low  - close.shift()).abs(),
    ], axis=1).max(axis=1)
    return tr.ewm(alpha=1/period, adjust=False, min_periods=period).mean()


def classify_regime(rsi_series: pd.Series, lookback: int = TREND_LOOKBACK) -> str:
    """
    Cardwell Range Shift regime detection.
    v2: threshold raised to REGIME_PCT (75%) from 70%.
    """
    window = rsi_series.iloc[-lookback:]
    if len(window) < lookback:
        return 'NEUTRAL'
    up_bars   = ((window >= UP_RSI_FLOOR) & (window <= UP_RSI_CEIL)).sum()
    threshold = lookback * REGIME_PCT
    return 'UPTREND' if up_bars >= threshold else 'NEUTRAL'


def detect_positive_reversal(rsi_series: pd.Series, price_series: pd.Series, lookback: int = 5) -> bool:
    """
    NEW (v2): Cardwell Positive Reversal.
    Price makes a higher low while RSI makes a lower low — bullish continuation signal.
    """
    if len(rsi_series) < lookback * 2:
        return False
    recent_price_low = price_series.iloc[-lookback:].min()
    prior_price_low  = price_series.iloc[-lookback*2:-lookback].min()
    recent_rsi_low   = rsi_series.iloc[-lookback:].min()
    prior_rsi_low    = rsi_series.iloc[-lookback*2:-lookback].min()
    return (recent_price_low > prior_price_low) and (recent_rsi_low < prior_rsi_low)


def score_signal(rsi_now, volume_ratio, ema_dist_pct, atr_ratio, reversal: bool = False) -> float:
    """
    Score 0–100 (+ up to 20 bonus for Cardwell positive reversal):
      RSI closeness to entry floor → 40 pts
      Volume spike strength        → 25 pts
      Trend strength vs EMA50      → 20 pts
      Volatility contraction       → 15 pts
      Positive reversal bonus      → +20 pts  (NEW v2)
    """
    rsi_score   = max(0.0, min(40.0, (LONG_ENTRY_HIGH - rsi_now) / (LONG_ENTRY_HIGH - LONG_ENTRY_LOW) * 40))
    vol_score   = max(0.0, min(25.0, (volume_ratio - 1.0) / 2.0 * 25))
    trend_score = max(0.0, min(20.0, ema_dist_pct / 0.05 * 20))
    atr_score   = max(0.0, min(15.0, (1.0 - atr_ratio) * 15 * 2))
    reversal_bonus = 20.0 if reversal else 0.0
    return round(rsi_score + vol_score + trend_score + atr_score + reversal_bonus, 2)

# ══════════════════════════════════════════════════════════════════════════════
# DATA FETCHING
# ══════════════════════════════════════════════════════════════════════════════

def get_tradeable_pairs() -> list:
    """Fetch all active Coinbase spot pairs, filter by quote currency and volume."""
    try:
        tickers = exchange.fetch_tickers()
    except Exception as e:
        print(f'{Fore.RED}⚠ fetch_tickers failed: {e}{Style.RESET_ALL}')
        return []

    pairs = []
    for symbol, ticker in tickers.items():
        market = exchange.markets.get(symbol, {})
        if not market.get('active', False):
            continue
        if market.get('type', 'spot') != 'spot':
            continue
        if market.get('quote', '') not in QUOTE_CURRENCIES:
            continue
        quote_vol = ticker.get('quoteVolume') or 0
        if quote_vol < MIN_24H_VOLUME_USD:
            continue
        pairs.append((symbol, float(quote_vol)))

    pairs.sort(key=lambda x: x[1], reverse=True)
    if MAX_PAIRS_TO_SCAN:
        pairs = pairs[:MAX_PAIRS_TO_SCAN]
    return [p[0] for p in pairs]


def fetch_ohlcv(symbol: str, timeframe: str = TIMEFRAME, limit: int = CANDLES_NEEDED) -> Optional[pd.DataFrame]:
    """Fetch OHLCV bars from Coinbase. Returns None on failure or insufficient data."""
    try:
        raw = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    except Exception:
        return None
    if not raw or len(raw) < RSI_PERIOD + TREND_LOOKBACK + 10:
        return None
    df = pd.DataFrame(raw, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    return df.sort_values('timestamp').reset_index(drop=True)

# ══════════════════════════════════════════════════════════════════════════════
# COMPUTE INDICATORS — v2 ENHANCED (multi-TF + reversal + vol filter + EMA-200)
# ══════════════════════════════════════════════════════════════════════════════

def compute_indicators(symbol: str) -> Optional[dict]:
    """
    Full indicator stack with v2 enhancements:
      1. Fetch 15m bars → RSI, EMA-50, EMA-200, ATR, volume
      2. Fetch 1h bars  → regime filter (must be UPTREND)
      3. Fetch 1d bars  → regime filter (must NOT be SIDEWAYS)
      4. Cardwell positive-reversal detection
      5. ATR contraction gate
      6. Score with reversal bonus; reject if < MIN_SIGNAL_SCORE
    Returns dict of current-bar values, or None.
    """
    # ── 15-minute base frame ──────────────────────────────────────────────
    df15 = fetch_ohlcv(symbol, TIMEFRAME, CANDLES_NEEDED)
    if df15 is None or len(df15) < max(EMA_TREND_PERIOD, TREND_LOOKBACK) + 10:
        return None

    df15 = df15.copy()
    df15['RSI']    = calc_rsi(df15['close'])
    df15['EMA50']  = df15['close'].ewm(span=EMA_PERIOD, adjust=False).mean()
    df15['EMA200'] = df15['close'].ewm(span=EMA_TREND_PERIOD, adjust=False).mean()  # NEW
    df15['VOL_MA'] = df15['volume'].rolling(VOLUME_MA_PERIOD).mean()
    df15['ATR']    = calc_atr(df15)
    df15['ATR_MA'] = df15['ATR'].rolling(20).mean()
    df15.dropna(inplace=True)
    if len(df15) < TREND_LOOKBACK:
        return None

    # ── 1-hour regime filter (NEW v2) ─────────────────────────────────────
    df1h = fetch_ohlcv(symbol, HIGHER_TF, 200)
    if df1h is not None and len(df1h) >= TREND_LOOKBACK:
        df1h['RSI']  = calc_rsi(df1h['close'])
        higher_regime = classify_regime(df1h['RSI'])
    else:
        higher_regime = 'NEUTRAL'

    if higher_regime != 'UPTREND':
        return None  # require 1h to also be in uptrend

    # ── Daily regime filter (NEW v2) ──────────────────────────────────────
    df1d = fetch_ohlcv(symbol, DAILY_TF, 100)
    if df1d is not None and len(df1d) >= TREND_LOOKBACK:
        df1d['RSI'] = calc_rsi(df1d['close'])
        last_daily_rsi = df1d['RSI'].iloc[-1]
        daily_regime = 'SIDEWAYS' if 40 <= last_daily_rsi <= 65 else classify_regime(df1d['RSI'])
    else:
        daily_regime = 'NEUTRAL'

    if daily_regime == 'SIDEWAYS':
        return None  # avoid choppy daily context

    # ── 15m regime ────────────────────────────────────────────────────────
    regime = classify_regime(df15['RSI'])
    if regime != 'UPTREND':
        return None

    last, prev = df15.iloc[-1], df15.iloc[-2]

    price        = float(last['close'])
    rsi_now      = float(last['RSI'])
    rsi_prev     = float(prev['RSI'])
    ema50        = float(last['EMA50'])
    ema200       = float(last['EMA200'])   # NEW
    volume_now   = float(last['volume'])
    vol_ma       = float(last['VOL_MA'])
    atr          = float(last['ATR'])
    atr_ma       = float(last['ATR_MA'])
    volume_ratio = volume_now / (vol_ma + 1e-10)
    ema_dist_pct = (price - ema50) / (ema50 + 1e-10)
    atr_ratio    = atr / (atr_ma + 1e-10)

    # ── ATR contraction gate (NEW v2) ─────────────────────────────────────
    if atr_ratio > VOL_FILTER_ATR_MULT:
        return None  # reject expanding volatility

    # ── Cardwell Positive Reversal (NEW v2) ───────────────────────────────
    reversal = detect_positive_reversal(df15['RSI'], df15['close'])

    score = score_signal(rsi_now, volume_ratio, ema_dist_pct, atr_ratio, reversal)

    if score < MIN_SIGNAL_SCORE:
        return None  # strict score gate

    return {
        'price':         price,
        'rsi_now':       rsi_now,
        'rsi_prev':      rsi_prev,
        'ema50':         ema50,
        'ema200':        ema200,          # NEW
        'volume_now':    volume_now,
        'vol_ma':        vol_ma,
        'volume_ratio':  volume_ratio,
        'atr':           atr,
        'atr_ma':        atr_ma,
        'atr_ratio':     atr_ratio,
        'ema_dist_pct':  ema_dist_pct,
        'reversal':      reversal,        # NEW
        'higher_regime': higher_regime,   # NEW
        'daily_regime':  daily_regime,    # NEW
        'score':         score,
        'regime':        regime,
    }    

# ══════════════════════════════════════════════════════════════════════════════
# POSITION SIZING
# ══════════════════════════════════════════════════════════════════════════════

def calculate_stops(price: float, atr: float) -> Tuple[float, float]:
    """ATR-based stop and take-profit."""
    stop_dist  = atr * STOP_LOSS_ATR_MULT
    stop_price = price - stop_dist
    tp_price   = price + stop_dist * REWARD_TO_RISK_RATIO
    return round(stop_price, 6), round(tp_price, 6)


def calculate_position_size(price: float, stop_price: float) -> float:
    """
    Dollar-risk sizing:
      qty = risk_dollars / risk_per_unit
    Capped at (PAPER_CAPITAL / MAX_SIMULTANEOUS_TRADES) notional.
    """
    if price <= 0 or stop_price >= price:
        return 0.0
    risk_dollars  = PAPER_CAPITAL * RISK_PER_TRADE_PCT
    risk_per_unit = price - stop_price
    qty           = risk_dollars / risk_per_unit
    max_notional  = PAPER_CAPITAL / MAX_SIMULTANEOUS_TRADES
    if qty * price > max_notional:
        qty = max_notional / price
    return round(qty, 6)



# ══════════════════════════════════════════════════════════════════════════════
# POSITION SIZING
# ══════════════════════════════════════════════════════════════════════════════

def calculate_stops(price: float, atr: float) -> Tuple[float, float]:
    """ATR-based stop and take-profit."""
    stop_dist  = atr * STOP_LOSS_ATR_MULT
    stop_price = price - stop_dist
    tp_price   = price + stop_dist * REWARD_TO_RISK_RATIO
    return round(stop_price, 6), round(tp_price, 6)


def calculate_position_size(price: float, stop_price: float) -> float:
    """
    Dollar-risk sizing:
      qty = risk_dollars / risk_per_unit
    Capped at (PAPER_CAPITAL / MAX_SIMULTANEOUS_TRADES) notional.
    """
    if price <= 0 or stop_price >= price:
        return 0.0
    risk_dollars  = PAPER_CAPITAL * RISK_PER_TRADE_PCT
    risk_per_unit = price - stop_price
    qty           = risk_dollars / risk_per_unit
    max_notional  = PAPER_CAPITAL / MAX_SIMULTANEOUS_TRADES
    if qty * price > max_notional:
        qty = max_notional / price
    return round(qty, 6)    



# ══════════════════════════════════════════════════════════════════════════════
# MARK-TO-MARKET
# ══════════════════════════════════════════════════════════════════════════════

def update_trade_marks(trade_doc: dict, current_price: float) -> dict:
    """Recompute and persist live mark-to-market fields."""
    entry_price = float(trade_doc['entry_price'])
    qty         = float(trade_doc['remaining_qty'])
    cp          = float(current_price)

    pnl     = (cp - entry_price) * qty
    pnl_pct = pnl / (entry_price * qty) if entry_price * qty != 0 else 0.0

    new_peak   = max(float(trade_doc.get('peak_price',   entry_price)), cp)
    new_trough = min(float(trade_doc.get('trough_price', entry_price)), cp)
    new_max    = max(float(trade_doc.get('max_unrealized_pnl', 0.0)), pnl)
    new_min    = min(float(trade_doc.get('min_unrealized_pnl', 0.0)), pnl)

    marks = {
        'current_price':       round(cp, 6),
        'current_pnl':         round(pnl, 4),
        'current_pnl_pct':     round(pnl_pct, 6),
        'peak_price':          round(new_peak, 6),
        'trough_price':        round(new_trough, 6),
        'max_unrealized_pnl':  round(new_max, 4),
        'min_unrealized_pnl':  round(new_min, 4),
        'last_mark_timestamp': datetime.now(),
    }
    db_update_trade(trade_doc['_id'], marks)
    return marks    



# ══════════════════════════════════════════════════════════════════════════════
# EXIT MANAGEMENT
# ══════════════════════════════════════════════════════════════════════════════

def evaluate_exit(trade_doc: dict, marks: dict, rsi_now: float,
                  current_price: float) -> Tuple[Optional[str], Optional[str]]:
    """
    3-layer exit management + RSI + price target exits.
    v2: LONG_EXIT_RSI raised to 70 to let crypto trends extend.
    """
    current_pnl = float(marks['current_pnl'])
    max_pnl     = float(marks['max_unrealized_pnl'])
    stop_price  = float(trade_doc.get('stop_price', 0))
    tp_price    = float(trade_doc.get('take_profit_price', 999_999))

    # Layer 1 — hard stop-loss (dollar PnL)
    if current_pnl <= HARD_STOP_LOSS_USD:
        return (
            f'HARD_STOP_LOSS pnl={current_pnl:.2f}',
            f'Hard stop: P&L ${current_pnl:.2f} ≤ ${HARD_STOP_LOSS_USD:.2f}'
        )

    # Layer 1b — price-based ATR stop
    if current_price <= stop_price:
        return (
            f'ATR_STOP_HIT price={current_price:.6f} stop={stop_price:.6f}',
            f'ATR stop: ${current_price:.6f} ≤ ${stop_price:.6f}'
        )

    # Layer 2A — breakeven protection
    if max_pnl >= BREAKEVEN_ARM_PNL and current_pnl <= BREAKEVEN_EXIT_PNL:
        return (
            f'BREAKEVEN_PROTECTION max={max_pnl:.2f} cur={current_pnl:.2f}',
            f'Breakeven: max ${max_pnl:.2f}, now ${current_pnl:.2f} ≤ ${BREAKEVEN_EXIT_PNL:.2f}'
        )

    # Layer 2B — lock-profit
    if max_pnl >= LOCK_PROFIT_ARM_PNL and current_pnl <= LOCK_PROFIT_EXIT_PNL:
        return (
            f'LOCK_PROFIT max={max_pnl:.2f} cur={current_pnl:.2f}',
            f'Lock-profit: peak ${max_pnl:.2f}, now ${current_pnl:.2f} ≤ ${LOCK_PROFIT_EXIT_PNL:.2f}'
        )

    # Layer 3 — trailing giveback
    if max_pnl >= TRAILING_ARM_PNL:
        trail_floor = max_pnl - TRAILING_GIVEBACK_DOLLARS
        if current_pnl <= trail_floor:
            return (
                f'TRAILING_GIVEBACK max={max_pnl:.2f} cur={current_pnl:.2f} floor={trail_floor:.2f}',
                f'Trailing: peak ${max_pnl:.2f}, floor ${trail_floor:.2f}, now ${current_pnl:.2f}'
            )

    # RSI target exit
    if rsi_now >= LONG_EXIT_RSI:
        return (
            f'RSI_TARGET_REACHED rsi={rsi_now:.1f}',
            f'RSI exit: {rsi_now:.1f} ≥ {LONG_EXIT_RSI}'
        )

    # Price take-profit
    if current_price >= tp_price:
        return (
            f'TAKE_PROFIT_HIT price={current_price:.6f} tp={tp_price:.6f}',
            f'Take-profit hit: ${current_price:.6f} ≥ ${tp_price:.6f}'
        )

    return None, None


def close_paper_trade(trade_doc: dict, exit_price: float, rsi_now: float, reason: str):
    """Mark a paper trade closed in MongoDB."""
    entry_price = float(trade_doc['entry_price'])
    qty         = float(trade_doc['remaining_qty'])
    entry_fee   = float(trade_doc.get('entry_fee_usd', 0))
    gross_pnl   = (exit_price - entry_price) * qty
    exit_fee    = exit_price * qty * TAKER_FEE_PCT
    net_pnl     = gross_pnl - entry_fee - exit_fee
    sign        = '+' if net_pnl >= 0 else ''
    color       = Fore.GREEN if net_pnl >= 0 else Fore.RED

    db_update_trade(trade_doc['_id'], {
        'exit_price':     float(exit_price),
        'exit_timestamp': datetime.now(),
        'exit_rsi':       float(rsi_now),
        'exit_reason':    reason,
        'realized_pnl':   round(gross_pnl, 4),
        'exit_fee_usd':   round(exit_fee, 4),
        'net_pnl':        round(net_pnl, 4),
        'status':         'closed',
        'remaining_qty':  0.0,
    })

    print(f'  {color}✅ CLOSE LONG  {trade_doc["instrument"]}')
    print(f'     Exit: ${exit_price:.6f}  RSI={rsi_now:.1f}  [{reason}]')
    print(f'     Net PnL: {sign}${net_pnl:.2f}  (fees: ${entry_fee+exit_fee:.2f}){Style.RESET_ALL}')    


# ══════════════════════════════════════════════════════════════════════════════
# ENTRY LOGIC — v2 ENHANCED
# ══════════════════════════════════════════════════════════════════════════════

def check_entry_conditions(ind: dict) -> bool:
    """
    ALL must be true for a LONG entry (v2 additions marked NEW):
      ✅ Cardwell UPTREND regime on 15m
      ✅ 1h also in UPTREND              (NEW)
      ✅ RSI in 42–48 tightened zone     (tightened)
      ✅ Price above EMA-50
      ✅ Price above EMA-200             (NEW)
      ✅ Volume ≥ 1.2× 20-bar avg        (raised from 1.0×)
      ✅ Cardwell positive reversal      (NEW)
      ✅ Score ≥ MIN_SIGNAL_SCORE        (already gated in compute_indicators)
    """
    return (
        ind['regime']        == 'UPTREND'
        and ind['higher_regime'] == 'UPTREND'
        and LONG_ENTRY_LOW   <= ind['rsi_now'] <= LONG_ENTRY_HIGH
        and ind['price']     >  ind['ema50']
        and ind['price']     >  ind['ema200']
        and ind['volume_ratio'] >= 1.2
        and ind['reversal']
    )


def enter_paper_long(pair: str, ind: dict):
    """Simulate a LONG entry: size position, write MongoDB doc, log signal."""
    price = ind['price']
    atr   = ind['atr']

    stop_price, tp_price = calculate_stops(price, atr)
    qty = calculate_position_size(price, stop_price)

    if qty <= 0:
        print(f'  ⚠ {pair}: invalid position size — skipping.')
        return

    doc = create_trade_doc(
        pair=pair, entry_price=price, qty=qty, stop_price=stop_price,
        tp_price=tp_price, rsi_at_entry=ind['rsi_now'], regime=ind['regime'],
        ema50=ind['ema50'], atr=atr, signal_score=ind['score'],
        ema200=ind['ema200'], higher_regime=ind['higher_regime'], reversal=ind['reversal'],
    )
    trades_col.insert_one(sanitize_for_mongo(doc))
    log_signal(pair, 'BUY_PULLBACK', price, ind['rsi_now'], ind['score'],
               {k: round(float(v), 6) if isinstance(v, (int, float)) else v for k, v in ind.items()})
    exclude_col.update_one(
        {'pair': pair, 'date': date.today().isoformat()},
        {'$setOnInsert': {'pair': pair, 'date': date.today().isoformat(), 'created_at': datetime.now()}},
        upsert=True
    )

    reversal_tag = '  🔄 +REVERSAL' if ind['reversal'] else ''
    print(f'  {Fore.GREEN}🚀 PAPER LONG  {pair}{reversal_tag}')
    print(f'     Entry:  ${price:.6f}  |  Regime=UPTREND (15m+1h)  |  Daily={ind["daily_regime"]}')
    print(f'     Qty:    {qty:.6f}  |  Notional: ${qty*price:.2f}')
    print(f'     Stop:   ${stop_price:.6f}  |  TP: ${tp_price:.6f}')
    print(f'     RSI:    {ind["rsi_now"]:.1f}  (pullback to {LONG_ENTRY_LOW}–{LONG_ENTRY_HIGH} zone)')
    print(f'     EMA50:  ${ind["ema50"]:.6f}  |  EMA200: ${ind["ema200"]:.6f}')
    print(f'     Score:  {ind["score"]:.1f}/100  |  Vol ratio: {ind["volume_ratio"]:.2f}×  |  ATR ratio: {ind["atr_ratio"]:.2f}{Style.RESET_ALL}')



# ══════════════════════════════════════════════════════════════════════════════
# BACKTEST ENGINE  (NEW v2)
# ══════════════════════════════════════════════════════════════════════════════

def backtest_strategy(symbols: list, days: int = 30, exit_bars: int = 10) -> Tuple[float, float]:
    """
    Quick historical backtest over the last N days.
    Simulates RSI pullback entries and fixed-bar exits (simplified).
    Prints a summary table and returns (total_pnl_pct, win_rate_pct).

    Args:
        symbols:   list of pairs to test (up to 10 used)
        days:      history window in days
        exit_bars: bars to hold before exiting (default 10 × 15m = 2.5 h)
    """
    since    = exchange.milliseconds() - days * 24 * 60 * 60 * 1000
    trades   = []
    sym_rows = []

    print(f'\n{"═"*65}')
    print(f'  🔬 BACKTEST  last {days} days  |  exit after {exit_bars} bars')
    print(f'  Entry zone RSI {LONG_ENTRY_LOW}–{LONG_ENTRY_HIGH}  |  Symbols tested: {min(10, len(symbols))}')
    print(f'{"═"*65}')

    for sym in symbols[:10]:
        try:
            raw = exchange.fetch_ohlcv(sym, TIMEFRAME, since=since, limit=2000)
        except Exception:
            continue
        if not raw or len(raw) < RSI_PERIOD + exit_bars + 20:
            continue

        df = pd.DataFrame(raw, columns=['ts', 'open', 'high', 'low', 'close', 'volume'])
        df['RSI'] = calc_rsi(df['close'])
        df.dropna(inplace=True)

        sym_trades = []
        i = RSI_PERIOD
        while i < len(df) - exit_bars:
            rsi = df['RSI'].iloc[i]
            if LONG_ENTRY_LOW <= rsi <= LONG_ENTRY_HIGH:
                entry = df['close'].iloc[i]
                exit_idx = min(i + exit_bars, len(df) - 1)
                # Use RSI-based exit if RSI exceeds LONG_EXIT_RSI before exit_bars
                for j in range(i + 1, exit_idx + 1):
                    if df['RSI'].iloc[j] >= LONG_EXIT_RSI:
                        exit_idx = j
                        break
                exit_px = df['close'].iloc[exit_idx]
                pnl_pct = (exit_px - entry) / entry
                sym_trades.append(pnl_pct)
                trades.append(pnl_pct)
                i = exit_idx + 1  # no overlap
            else:
                i += 1

        if sym_trades:
            wr = len([p for p in sym_trades if p > 0]) / len(sym_trades) * 100
            avg = sum(sym_trades) / len(sym_trades) * 100
            sym_rows.append([sym, len(sym_trades), f'{avg:+.2f}%', f'{wr:.0f}%'])

    if not trades:
        print('  No signals found in backtest window.')
        return 0.0, 0.0

    total_pnl  = sum(trades) / len(trades) * 100
    win_rate   = len([p for p in trades if p > 0]) / len(trades) * 100
    best_trade = max(trades) * 100
    worst_trade= min(trades) * 100

    print(tabulate(sym_rows, headers=['Pair', 'Trades', 'Avg PnL', 'Win%'], tablefmt='rounded_outline'))
    print(f'\n  AGGREGATE  {len(trades)} signals across {len(sym_rows)} pairs')
    print(tabulate([
        ['Avg PnL/trade', f'{total_pnl:+.2f}%'],
        ['Win Rate',      f'{win_rate:.1f}%'],
        ['Best Trade',    f'{best_trade:+.2f}%'],
        ['Worst Trade',   f'{worst_trade:+.2f}%'],
    ], tablefmt='rounded_outline'))
    print(f'{"═"*65}')

    return total_pnl, win_rate    



# ══════════════════════════════════════════════════════════════════════════════
# PERFORMANCE REPORTING
# ══════════════════════════════════════════════════════════════════════════════

def print_performance_summary():
    all_trades = list(trades_col.find({'status': 'closed'}))
    print(f'\n{"═"*65}')
    print(f'  📊 PERFORMANCE SUMMARY  {datetime.now().strftime("%Y-%m-%d %H:%M")}')
    print(f'{"═"*65}')

    if not all_trades:
        print('  No closed trades yet.')
    else:
        df = pd.DataFrame(all_trades)
        df['net_pnl'] = df['net_pnl'].astype(float)
        wins   = df[df['net_pnl'] > 0]
        losses = df[df['net_pnl'] <= 0]
        total  = len(df)
        wr     = len(wins) / total * 100 if total else 0
        pf     = abs(wins['net_pnl'].sum() / losses['net_pnl'].sum()) if not losses.empty and losses['net_pnl'].sum() != 0 else float('inf')
        df_s   = df.sort_values('exit_timestamp')
        cum    = df_s['net_pnl'].cumsum()
        dd     = (cum - cum.cummax()).min()

        # Reversal stats (NEW v2)
        if 'positive_reversal' in df.columns:
            rev_trades = df[df['positive_reversal'] == True]
            rev_wr = len(rev_trades[rev_trades['net_pnl'] > 0]) / len(rev_trades) * 100 if len(rev_trades) else 0
            rev_row = [['Reversal Trades', f'{len(rev_trades)} ({rev_wr:.0f}% WR)']]
        else:
            rev_row = []

        print(tabulate([
            ['Total Trades',      total],
            ['Winners',           f'{len(wins)}  ({wr:.1f}%)'],
            ['Losers',            f'{len(losses)}  ({100-wr:.1f}%)'],
            ['Total Net PnL',     f'${df["net_pnl"].sum():+.2f}'],
            ['Avg Win',           f'${wins["net_pnl"].mean():+.2f}' if not wins.empty else 'n/a'],
            ['Avg Loss',          f'${losses["net_pnl"].mean():+.2f}' if not losses.empty else 'n/a'],
            ['Profit Factor',     f'{pf:.2f}'],
            ['Max Drawdown',      f'${dd:.2f}'],
            ['Return on Capital', f'{df["net_pnl"].sum()/PAPER_CAPITAL*100:+.2f}%'],
            *rev_row,
        ], headers=['Metric', 'Value'], tablefmt='rounded_outline'))

        print('\n  Recent 10 closed trades:')
        cols = ['instrument', 'entry_price', 'exit_price', 'net_pnl', 'exit_reason']
        if 'positive_reversal' in df_s.columns:
            cols.insert(3, 'positive_reversal')
        print(df_s.tail(10)[cols].to_string(index=False))

    open_trades = list(trades_col.find({'status': 'open'}))
    if open_trades:
        print(f'\n  Active positions ({len(open_trades)}):')
        print(tabulate(
            [[t['instrument'], f"${float(t['entry_price']):.6f}", f"${float(t['current_price']):.6f}",
              f"${float(t['current_pnl']):+.2f}", f"{float(t['current_pnl_pct']):+.2%}",
              '✅' if t.get('positive_reversal') else '–']
             for t in open_trades],
            headers=['Pair', 'Entry', 'Current', 'PnL$', 'PnL%', 'Reversal'], tablefmt='rounded_outline'
        ))
    print(f'  Signals logged: {signals_col.count_documents({})}')    



# ══════════════════════════════════════════════════════════════════════════════
# MAIN SCAN CYCLE — v2 ENHANCED
# ══════════════════════════════════════════════════════════════════════════════

def run_scan_cycle():
    """
    One full scan cycle:
      1. Refresh universe
      2. For each pair — manage open trade OR look for new entry
      3. Rank and enter top-scored setups
    v2: passes symbol directly to compute_indicators for multi-TF fetching.
    """
    print(f'\n{"═"*65}')
    print(f'  📡 SCAN CYCLE  {datetime.now().strftime("%Y-%m-%d  %H:%M:%S")}')
    print(f'  Timeframes: {TIMEFRAME} + {HIGHER_TF} + {DAILY_TF}  |  Capital: ${PAPER_CAPITAL:,.0f}')
    print(f'  Entry: RSI {LONG_ENTRY_LOW}–{LONG_ENTRY_HIGH}  |  Exit RSI: {LONG_EXIT_RSI}  |  Min score: {MIN_SIGNAL_SCORE}')
    print(f'{"═"*65}')

    open_count = trades_col.count_documents({'status': 'open'})
    universe   = get_tradeable_pairs()
    print(f'  Open positions: {open_count}/{MAX_SIMULTANEOUS_TRADES}  |  Universe: {len(universe)} pairs\n')

    new_signals = []

    for pair in universe:
        # ── Manage open trade ────────────────────────────────────────────
        open_trade = trades_col.find_one({'instrument': pair, 'status': 'open'})

        if open_trade:
            # For open trade management we still need current price + RSI
            df15 = fetch_ohlcv(pair, TIMEFRAME, 100)
            if df15 is None:
                time.sleep(0.3)
                continue
            df15['RSI'] = calc_rsi(df15['close'])
            df15.dropna(inplace=True)
            price   = float(df15['close'].iloc[-1])
            rsi_now = float(df15['RSI'].iloc[-1])

            marks = update_trade_marks(open_trade, price)
            color = Fore.GREEN if marks['current_pnl'] >= 0 else Fore.RED

            print(f'  {"─"*55}')
            print(f'  {pair}  OPEN LONG  entry=${float(open_trade["entry_price"]):.6f}'
                  f'  [{"🔄 reversal" if open_trade.get("positive_reversal") else "–"}]')
            print(
                f'    Current: ${marks["current_price"]:.6f}  '
                f'{color}P&L={marks["current_pnl_pct"]:+.2%}  '
                f'(${marks["current_pnl"]:+.2f}){Style.RESET_ALL}'
            )
            print(
                f'    Peak:    ${marks["peak_price"]:.6f}  '
                f'MaxProfit=${marks["max_unrealized_pnl"]:+.2f}'
            )

            exit_reason, exit_msg = evaluate_exit(open_trade, marks, rsi_now, price)

            if exit_reason:
                close_paper_trade(open_trade, price, rsi_now, exit_reason)
                log_signal(pair, 'EXIT_LONG', price, rsi_now, 0.0,
                           {'reason': exit_reason, 'exit_msg': exit_msg})
                print(f'  🚨 EXIT: {exit_msg}')
            else:
                print(
                    f'  Holding — RSI={rsi_now:.1f}  '
                    f'stop=${float(open_trade["stop_price"]):.6f}  '
                    f'tp=${float(open_trade["take_profit_price"]):.6f}'
                )

            time.sleep(0.3)
            continue

        # ── Look for new entry ───────────────────────────────────────────
        if open_count >= MAX_SIMULTANEOUS_TRADES:
            continue

        if exclude_col.find_one({'pair': pair, 'date': date.today().isoformat()}):
            continue

        ind = compute_indicators(pair)  # v2: symbol-based, multi-TF inside
        if ind is None:
            time.sleep(0.15)
            continue

        if check_entry_conditions(ind):
            new_signals.append((pair, ind))

        time.sleep(0.2)

    # ── Rank signals and enter top setups ───────────────────────────────
    if new_signals:
        new_signals.sort(key=lambda x: x[1]['score'], reverse=True)

        print(f'\n{"─"*65}')
        print(f'  🏆 TOP LONG SETUPS  ({len(new_signals)} found)')
        print(f'{"─"*65}')
        print(tabulate(
            [
                [r, p,
                 f"{i['score']:.1f}",
                 f"{i['rsi_now']:.1f}",
                 f"{i['price']:.6f}",
                 f"{i['ema_dist_pct']:+.2%}",
                 f"{i['volume_ratio']:.2f}×",
                 f"{i['atr_ratio']:.2f}",
                 '✅' if i['reversal'] else '–']
                for r, (p, i) in enumerate(new_signals, 1)
            ],
            headers=['Rank', 'Pair', 'Score', 'RSI', 'Price', 'vs EMA50', 'Vol', 'ATR ratio', 'Reversal'],
            tablefmt='rounded_outline'
        ))

        open_count = trades_col.count_documents({'status': 'open'})
        slots      = MAX_SIMULTANEOUS_TRADES - open_count
        print(f'\n  → Entering top {min(slots, len(new_signals))} setups...')
        for pair, ind in new_signals[:slots]:
            enter_paper_long(pair, ind)
    else:
        print('\n  No qualifying LONG setups this cycle.')

    print(f'\n{"═"*65}')
    print(f'  Scan complete. Next scan in {SCAN_INTERVAL_SECONDS//60} min.')
    print(f'{"═"*65}')    

# ══════════════════════════════════════════════════════════════════════════════
# RUN
# ══════════════════════════════════════════════════════════════════════════════

# -- Single scan (test) --
run_scan_cycle()
print_performance_summary()

# -- Backtest last 30 days (NEW v2) --
universe = get_tradeable_pairs()
backtest_strategy(universe, days=30)

# -- Continuous loop (uncomment to run live; press ■ to stop) --
try:
    while True:
        run_scan_cycle()
        print(f'  Sleeping {SCAN_INTERVAL_SECONDS}s...')
        time.sleep(SCAN_INTERVAL_SECONDS)
except KeyboardInterrupt:
    print(f'\n{Fore.YELLOW}⛔ Loop stopped.{Style.RESET_ALL}')
    print_performance_summary()
# Out:
# ✅ MongoDB connected → cardwell_crypto_db
# ✅ Coinbase connected — 1159 markets loaded.
# 📋 Capital: $10,000  |  Risk/trade: 1.0%  |  Hard stop: $-100  |  Timeframe: 15m
# 🔍 Multi-TF: 15m + 1h + 1d  |  Min score: 75  |  EMA filters: EMA-50 + EMA-200
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  17:39:56
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#
# ═════════════════════════════════════════════════════════════════
#   📊 PERFORMANCE SUMMARY  2026-04-05 17:40
# ═════════════════════════════════════════════════════════════════
#   No closed trades yet.
#   Signals logged: 0
#
# ═════════════════════════════════════════════════════════════════
#   🔬 BACKTEST  last 30 days  |  exit after 10 bars
#   Entry zone RSI 42–48  |  Symbols tested: 10
# ═════════════════════════════════════════════════════════════════
# ╭──────────┬──────────┬───────────┬────────╮
# │ Pair     │   Trades │ Avg PnL   │ Win%   │
# ├──────────┼──────────┼───────────┼────────┤
# │ BTC/USD  │       15 │ +0.11%    │ 53%    │
# │ BTC/USDC │       15 │ +0.11%    │ 53%    │
# │ ETH/USD  │       16 │ +0.35%    │ 69%    │
# │ ETH/USDC │       16 │ +0.35%    │ 69%    │
# │ XRP/USD  │       17 │ +0.16%    │ 41%    │
# │ XRP/USDC │       17 │ +0.16%    │ 41%    │
# │ SOL/USD  │       14 │ +0.29%    │ 57%    │
# │ SOL/USDC │       14 │ +0.29%    │ 57%    │
# │ L3/USD   │       16 │ +0.33%    │ 56%    │
# │ L3/USDC  │       16 │ +0.33%    │ 56%    │
# ╰──────────┴──────────┴───────────┴────────╯
#
#   AGGREGATE  156 signals across 10 pairs
# ╭───────────────┬────────╮
# │ Avg PnL/trade │ +0.25% │
# │ Win Rate      │ 55.1%  │
# │ Best Trade    │ +3.60% │
# │ Worst Trade   │ -1.50% │
# ╰───────────────┴────────╯
# ═════════════════════════════════════════════════════════════════
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  17:40:49
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  17:46:40
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  17:52:29
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  17:58:21
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:04:12
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:10:02
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:15:59
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:21:51
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:27:44
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:33:35
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:39:25
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:45:14
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:51:05
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  18:56:57
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:02:47
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:08:39
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:14:30
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:20:55
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:26:45
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:32:36
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:39:06
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:44:57
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
#
#
#   No qualifying LONG setups this cycle.
#
# ═════════════════════════════════════════════════════════════════
#   Scan complete. Next scan in 5 min.
# ═════════════════════════════════════════════════════════════════
#   Sleeping 300s...
#
# ═════════════════════════════════════════════════════════════════
#   📡 SCAN CYCLE  2026-04-05  19:51:19
#   Timeframes: 15m + 1h + 1d  |  Capital: $10,000
#   Entry: RSI 42–48  |  Exit RSI: 70  |  Min score: 75
# ═════════════════════════════════════════════════════════════════
#   Open positions: 0/5  |  Universe: 100 pairs
